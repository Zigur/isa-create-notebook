# %% [markdown]
# # Create ISA-API Investigation from Datascriptor Study Design configuration
#
# In this notebook, we will show how to use an **ISA study design configuration** in *JSON format*, as generated by **[DataScriptor](https://gitlab.com/datascriptor/datascriptor)**  to create a fully fledged single-study ISA investigation and then how to serialise it either in JSON or tabular (i.e. CSV) format.
#
# Our study design configuration consists of:
#
# - a `longitudinal intervention study` with 3 compound based `treatments` over 4 (out of 6 possible) `arms` in a `crossover design`.
#
#     - Treatment A: aspirin, 5 mg, 10 days
#     - Treatment B: ibuprofen, 8 mg, 10 days
#     - Treatment C: paracetamol, 10 mg, 10 days
#     - Possible Treatment sequences: ["ABC","ACB","BAC","BCA","CAB","CBA"]
# - each `arm` receives *N=5* `study subjects`
# - each `study subject` is used to collect `samples` (blood and saliva).
#     - blood was collected once (nB=1) at the end of each sequence in the 4 arms used.
#     - saliva was collected four times (nS=4).
# - `samples` are analysed with several distinct `data acquisition modalities`:
#
#     - `metabolite profiling using mass spectrometry`
#
# - `technical replicates` *(n=2)* are obtained for mass spectrometry based acquisitions.
# - no technical replication was performed for nmr spectroscopy based acquisitions.

# %% [markdown]
# ## 1. Getting ready
#
# Let's start by importing all the necessary libraries to perform the tasks.

# %%
from time import time
import os
import json

## ISA-API related imports
from isatools.model import Investigation, Study

## ISA-API create mode related imports
from isatools.create import models
from isatools.create.models import StudyDesign
from isatools.create.connectors import generate_study_design_from_config

# serializer from ISA Investigation to JSON
from isatools.isajson import ISAJSONEncoder

# ISA-Tab serialisation
from isatools import isatab

## ISA-JSON serialisation
from isatools import isajson

# %% [markdown]
# ## 2. Reading the `ISA Study Design JSON configuration` created by DataScriptor
#
# The first step is to read in the study design information saved as JSON by DataScritor

# %%
with open(os.path.abspath(os.path.join("ds-study-design-config", "study-design-3-repeated-treatments-datascriptor.json")), "r") as config_file:
    study_design_config = json.load(config_file)

# %% [markdown]
# Let's now view the content of this variable:

# %%
study_design_config
# Out:
# {'treatmentPlan': {'screen': {'name': 'screen',
#    'duration': None,
#    'durationUnit': ''},
#   'runIn': {'name': 'run-in', 'duration': None, 'durationUnit': ''},
#   'washout': {'name': 'washout', 'duration': '5', 'durationUnit': 'days'},
#   'followUp': {'name': 'follow-up', 'duration': 60, 'durationUnit': 'days'},
#   'treatments': [{'agent': 'ibuprofen',
#     'intensity': 8,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'},
#    {'agent': 'aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'},
#    {'agent': 'paracetamol',
#     'intensity': 10,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'}],
#   'elementParams': {'agents': [],
#    'intensities': [],
#    'intensityUnit': '',
#    'durations': [],
#    'durationUnit': ''}},
#  'generatedStudyDesign': {'name': 'test study',
#   'description': 'this is the verbose description',
#   'type': {'term': 'crossover design',
#    'id': 'OBI:0500003',
#    'iri': 'http://purl.obolibrary.org/obo/OBI_0500003'},
#   'elements': [{'id': '83978887-be4c-4cac-afb6-0faad3d07c86',
#     'name': 'treatment_0',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'ibuprofen',
#     'intensity': 8,
#     'intensityUnit': 'mg'},
#    {'id': 'e283a7c5-955f-4d3b-b99e-0053a2af5a61',
#     'name': 'washout',
#     'duration': 5,
#     'durationUnit': 'days'},
#    {'id': '696a2da4-329a-4b39-a681-e402afb4e89f',
#     'name': 'treatment_1',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg'},
#    {'id': '6bf4662d-852f-44ad-9b46-acff5291c47f',
#     'name': 'treatment_2',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'paracetamol',
#     'intensity': 10,
#     'intensityUnit': 'mg'},
#    {'id': '28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7',
#     'name': 'follow-up',
#     'duration': 60,
#     'durationUnit': 'days'}],
#   'events': [],
#   'arms': [{'id': '#arm/0',
#     'name': 'Arm_0',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/1',
#     'name': 'Arm_1',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/2',
#     'name': 'Arm_2',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/3',
#     'name': 'Arm_3',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/4',
#     'name': 'Arm_4',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/5',
#     'name': 'Arm_5',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]}]},
#  'selectedArms': [{'id': '#arm/0',
#    'name': 'Arm_0',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/2',
#    'name': 'Arm_2',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/4',
#    'name': 'Arm_4',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/3',
#    'name': 'Arm_3',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]}],
#  'samplePlan': [{'sampleType': 'saliva',
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'sampleTypeSizes': {'Arm_0': [1, None, 1, None, 1, 1],
#     'Arm_2': [1, None, 1, None, 1, 1],
#     'Arm_4': [1, None, 1, None, 1, 1],
#     'Arm_3': [1, None, 1, None, 1, 1]}},
#   {'sampleType': 'blood',
#    'selectedCells': {'Arm_0': [False, False, False, False, False, True],
#     'Arm_2': [False, False, False, False, False, True],
#     'Arm_4': [False, False, False, False, False, True],
#     'Arm_3': [False, False, False, False, False, True]},
#    'sampleTypeSizes': {'Arm_0': [None, None, None, None, None, 1],
#     'Arm_2': [None, None, None, None, None, 1],
#     'Arm_4': [None, None, None, None, None, 1],
#     'Arm_3': [None, None, None, None, None, 1]}}],
#  'assayConfigs': [{'id': 0,
#    'name': 'Metabolite Profiling - Mass. Spec.',
#    'icon': 'fa fa-dna',
#    'color': 'green',
#    'measurement_type': 'metabolite profiling',
#    'technology_type': 'mass spectrometry',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['polar fraction',
#         'nonpolar fraction'],
#        'values': ['polar fraction']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['labeling', {'#replicates': {'value': 1}}],
#     ['labeled extract',
#      {'node_type': 'labeled extract',
#       'characteristics_category': 'labelled extract type',
#       'characteristics_value': {'options': ['biotin', 'cy-5', 'cy-3'],
#        'values': ['biotin']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['mass spectrometry',
#      {'#replicates': {'value': 2},
#       'instrument': {'options': ['Agilent QTQF 6510', 'Agilent QTQF 6520A'],
#        'values': ['Agilent QTQF 6510']},
#       'injection_mode': {'options': ['FIA', 'LC'], 'values': ['LC']},
#       'acquisition_mode': {'options': ['positive mode', 'negative mode'],
#        'values': ['positive mode', 'negative mode']}}],
#     ['raw spectral data file',
#      {'node_type': 'data file',
#       'is_input_to_next_protocols': {'value': True}}]],
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'selectedSampleTypes': {'Arm_0': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']],
#     'Arm_2': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_4': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_3': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']]}},
#   {'id': 1,
#    'name': 'Metabolite Profiling - Mass. Spec. (Annotated)',
#    'icon': 'fa fa-dna',
#    'color': 'blue',
#    'measurement_type': {'term': 'metabolite profiling',
#     'iri': 'http://purl.obolibrary.org/obo/OBI_0000366',
#     'source': None},
#    'technology_type': {'term': 'mass spectrometry',
#     'iri': 'http://purl.obolibrary.org/obo/OBI_0000470',
#     'source': None},
#    'workflow': [[{'term': 'extraction',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0302884',
#       'source': None},
#      {'#replicates': {'value': 1}}],
#     [{'term': 'extract', 'iri': 'http://purl.obolibrary.org/obo/OBI_0000423'},
#      {'node_type': 'extract',
#       'characteristics_category': {'term': 'extract type',
#        'iri': None,
#        'source': None},
#       'characteristics_value': {'options': [{'term': 'polar fraction',
#          'iri': None,
#          'source': None},
#         {'term': 'lipids', 'iri': None, 'source': None}],
#        'values': []},
#       'is_input_to_next_protocols': {'value': True}}],
#     [{'term': 'labelling',
#       'iri': 'http://purl.obolibrary.org/obo/CHMO_0001675',
#       'source': None},
#      {'#replicates': {'value': 1}}],
#     [{'term': 'labelled extract',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0000924',
#       'source': None},
#      {'node_type': 'labeled extract',
#       'characteristics_category': {'term': 'labelled extract type',
#        'iri': None,
#        'source': None},
#       'characteristics_value': {'options': [{'term': 'biotin',
#          'iri': None,
#          'source': None},
#         {'term': 'cy-5', 'iri': None, 'source': None},
#         {'term': 'cy-3', 'iri': None, 'source': None}],
#        'values': [{'term': 'cy-3', 'iri': None, 'source': None}]},
#       'is_input_to_next_protocols': {'value': True}}],
#     [{'term': 'mass spectrometry',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0200085',
#       'source': None},
#      {'#replicates': {'value': 1},
#       'instrument': {'options': [{'term': 'Agilent QTQF 6510',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000676',
#          'source': None},
#         {'term': 'Agilent QTQF 6520A',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000677',
#          'source': None}],
#        'values': [{'term': 'Agilent QTQF 6520A',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000677',
#          'source': None}]},
#       'injection_mode': {'options': [{'term': 'FIA',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000058',
#          'source': None},
#         {'term': 'LC', 'iri': None, 'source': None}],
#        'values': []},
#       'acquisition_mode': {'options': [{'term': 'positive mode',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#          'source': None}],
#        'values': [{'term': 'positive mode',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#          'source': None}]}}],
#     [{'term': 'raw spectral data file',
#       'iri': 'http://purl.obolibrary.org/obo/MS_1003083',
#       'source': None},
#      {'node_type': 'data file',
#       'is_input_to_next_protocols': {'value': True}}]],
#    '@context': {'measurement_type': 'http://purl.obolibrary.org/obo/NCIT_C25209',
#     'technology_type': 'http://www.ebi.ac.uk/efo/EFO_0005521',
#     'instrument': 'http://purl.obolibrary.org/obo/MS_1000463',
#     'injection_mode': 'http://purl.obolibrary.org/obo/MS_1000007',
#     'acquisition_mode': 'http://purl.obolibrary.org/obo/MS_1000027'},
#    'selectedCells': {'Arm_0': [False, False, False, False, False, False],
#     'Arm_2': [False, False, False, False, False, False],
#     'Arm_4': [False, False, False, False, False, False],
#     'Arm_3': [False, False, False, False, False, False]},
#    'selectedSampleTypes': {'Arm_0': [[], [], [], [], [], []],
#     'Arm_2': [[], [], [], [], [], []],
#     'Arm_4': [[], [], [], [], [], []],
#     'Arm_3': [[], [], [], [], [], []]}},
#   {'id': 2,
#    'name': 'Metabolite Profiling - NMR',
#    'icon': 'fa fa-atom',
#    'color': 'orange',
#    'measurement_type': 'metabolite profiling',
#    'technology_type': 'NMR spectroscopy',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['supernatant', 'pellet'],
#        'values': ['pellet']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['nmr_spectroscopy',
#      {'#replicates': {'value': 1},
#       'instrument': {'options': ['Bruker AvanceII 1 GHz'],
#        'values': ['Bruker AvanceII 1 GHz']},
#       'acquisition_mode': {'options': ['1D 13C NMR',
#         '1D 1H NMR',
#         '2D 13C-13C NMR'],
#        'values': ['1D 13C NMR']},
#       'pulse_sequence': {'options': ['CPMG', 'TOCSY', 'HOESY', 'watergate'],
#        'values': ['CPMG']}}],
#     ['raw_spectral_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'selectedSampleTypes': {'Arm_0': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']],
#     'Arm_2': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_4': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_3': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']]}}],
#  'selectedAssayTypes': {'Metabolite Profiling - Mass. Spec.': True,
#   'Metabolite Profiling - Mass. Spec. (Annotated)': False,
#   'Metabolite Profiling - NMR': False}}

# %% [markdown]
# ## 3. Generating the `ISA Study Design` objects  from the DataScriptor JSON configuration
# To perform this conversion,  we simply need to invoke the function `generate_isa_study_design_from_config` (name possibly subject to change, should we drop the "isa" and "datascriptor" qualifiers?)

# %%
study_design = generate_study_design_from_config(study_design_config)
assert isinstance(study_design, StudyDesign)

# %%
study_design
# Out:
# isatools.create.models.StudyDesign(name=Study Design, study_arms=[isatools.create.models.StudyArm(name=Arm_0, source_type=human, group_size=5, cells=[isatools.create.models.StudyCell(name=CELL_Arm_0_0, elements=[isatools.create.models.Treatment(type=unspecified intervention, factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value='ibuprofen', unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='days'), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=8, unit='mg')])], ), isatools.create.models.StudyCell(name=CELL_Arm_0_1, elements=[isatools.create.models.NonTreatment(type='washout', duration=isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit='days'))], ), isatools.create.models.StudyCell(name=CELL_Arm_0_2, elements=[isatools.create.models.Treatment(type=unspecified intervention, factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value='aspirin', unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='days'), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit='mg')])], ), isatools.create.models.StudyCell(name=CELL_Arm_0_3, elements=[isatools.create.models.NonTreatment(type='washout', duration=isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit='days'))], ), isatools.create.models.StudyCell(name=CELL_Arm_0_4, elements=[isatools.create.models.Treatment(type=unspecified intervention, factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value='paracetamol', unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='days'), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='mg')])], ), isatools.create.models.StudyCell(name=CELL_Arm_0_5, elements=[isatools.create.models.NonTreatment(type='follow-up', duration=isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=60, unit='days'))], )], sample_assay_plans=[isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_0, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics ...
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_1, sample_plan=[], assay_plan=set(), sample_to_assay_map={}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_2, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_3, sample_plan=[], assay_plan=set(), sample_to_assay_map={}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_4, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_0_5, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=sample_001, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_001, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000'], isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']})]), isatools.create.models.StudyArm(name=Arm_2, source_type=human, group_size=5, cells=[isatools.create.models.StudyCell(name=CELL_Arm_2_0, elements=[isatools.create.models.Treatment(type=unspecified intervention, factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value='aspirin', unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='days'), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit='mg')])], ), isatools.create.models.StudyCell(name=CELL_Arm_2_1, elements=[isatools.create.models.NonTreatment(type='washout', duration=isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit='days'))], ), isatools.create.models.StudyCell(name=CELL_Arm_2_2, elements=[isatools.create.models.Treatment(type=unspecified intervention, factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value='ibuprofen', unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=10, unit='days'), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[ ...
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_2_1, sample_plan=[], assay_plan=set(), sample_to_assay_map={}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_2_2, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_2_3, sample_plan=[], assay_plan=set(), sample_to_assay_map={}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_2_4, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_2_5, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=sample_001, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ...
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_4_3, sample_plan=[], assay_plan=set(), sample_to_assay_map={}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_4_4, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']}), isatools.create.models.SampleAndAssayPlan(name=SA_PLAN_Arm_4_5, sample_plan=[isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=sample_001, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], size=1)], assay_plan={isatools.create.models.AssayGraph(id=ASSAY_GRAPH_000, measurement_type=OntologyAnnotation(
#     term=metabolite profiling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), technology_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), nodes={isatools.create.models.ProductNode(id=extract_000_000, type=extract, name=extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value='polar fraction', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=labeled_extract_000_000, type=labeled extract, name=labeled extract, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='labelled extract type', term_source=None, term_accession='', comments=[]), value='biotin', unit=None, comments=[])], size=1), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_001, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=labeling_000_000, name=labeling, protocol_type=OntologyAnnotation(
#     term=labeling
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProductNode(id=raw_spectral_data_file_000_000, type=data file, name=raw spectral data file, characteristics=[], size=1), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.models.ProtocolNode(id=mass_spectrometry_001_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=mass_spectrometry_000_000, name=mass spectrometry, protocol_type=OntologyAnnotation(
#     term=mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTQF 6510', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='LC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])}, links=[('extract_000_000', 'labeling_000_000'), ('extraction_000', 'extract_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_000_000'), ('labeled_extract_000_000', 'mass_spectrometry_001_000'), ('labeling_000_000', 'labeled_extract_000_000'), ('mass_spectrometry_000_000', 'raw_spectral_data_file_000_000'), ('mass_spectrometry_001_000', 'raw_spectral_data_file_000_001')], quality_control=None)}, sample_to_assay_map={isatools.create.models.ProductNode(id=sample_001, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000'], isatools.create.models.ProductNode(id=sample_000, type=sample, name=sample, characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='saliva', unit=None, comments=[])], size=1): ['ASSAY_GRAPH_000']})])])

# %% [markdown]
# ## 4. Generate the ISA Study from the StudyDesign and embed it into an ISA Investigation
#
# The `StudyDesign.generate_isa_study()` method returns the complete ISA-API `Study` object.

# %%
start = time() #this is simply to estimate how long the process will take so we start the clock

study = study_design.generate_isa_study()

end = time() #we stop the clock

print('The generation of the study design took {:.2f} s.'.format(end - start))
assert isinstance(study, Study)
# Out:
# The generation of the study design took 0.24 s.

# %% [markdown]
# We now simply create an ISA investigation object by adding the newly created study.

# %%
investigation = Investigation(studies=[study])

# %% [markdown]
# ## 5. Writing the generated ISA Investigation to file in ISA-JSON format

# %%
start = time() #this is simply to estimate how long the process will take so we start the clock

inv_json = json.dumps(investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))

end = time()#we stop the clock
print('The JSON serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The JSON serialisation of the ISA investigation took 0.09 s.

# %% [markdown]
# Writing the ISA JSON serialization to file:

# %%
directory = os.path.abspath(os.path.join('output'))
if not os.path.exists(directory):
    os.makedirs(directory)
with open(os.path.abspath(os.path.join('output','isa-investigation-3-arms-ms-only.json')), 'w') as out_fp:
    json.dump(json.loads(inv_json), out_fp)

# %% [markdown]
# ## 6. Writing the same ISA Investigation to file in ISA-TAB format

# %%
start = time()
isatab.dump(investigation, os.path.abspath(os.path.join('output')))
end = time()
print('The Tab serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# 2020-10-31 12:39:22,336 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 100 paths!
# 2020-10-31 12:39:22,346 [INFO]: isatab.py(write_study_table_files:1330) >> Rendered 100 paths
# 2020-10-31 12:39:22,351 [INFO]: isatab.py(write_study_table_files:1337) >> Writing 100 rows
# 2020-10-31 12:39:22,476 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:22,601 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:22,728 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:22,971 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:23,100 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:23,229 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:23,362 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:23,598 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:23,731 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:23,861 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:23,986 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:24,226 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:24,351 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:24,497 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:24,638 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:24,892 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# The Tab serialisation of the ISA investigation took 3.12 s.

# %%
#%debug

# %% [markdown]
# To use them on the notebook we can also dump the tables to pandas DataFrames, using the `dump_tables_to_dataframes` function rather than dump

# %%
dataframes = isatab.dump_tables_to_dataframes(investigation)
# Out:
# 2020-10-31 12:39:25,502 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 100 paths!
# 2020-10-31 12:39:25,509 [INFO]: isatab.py(write_study_table_files:1330) >> Rendered 100 paths
# 2020-10-31 12:39:25,514 [INFO]: isatab.py(write_study_table_files:1337) >> Writing 100 rows
# 2020-10-31 12:39:25,638 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:25,767 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:25,890 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:26,147 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:26,288 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:26,422 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:26,556 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:26,806 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:26,931 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:27,053 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:27,172 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:27,416 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!
# 2020-10-31 12:39:27,543 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:27,666 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:27,788 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 20 paths!
# 2020-10-31 12:39:28,021 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 40 paths!

# %%
len(dataframes)
# Out:
# 17

# %% [markdown]
# ## 7. Check the correctness of the ISA-Tab DataFrames
#
# We have 1 study file and 16 assay files:
# * one isa assay table is currently generated for each `cell` defined in the `arm/epoch` coordinate system.
# * in this design example, 4 arms are used and sampling event occur in 4 distinct epochs
#
# NB: This behavior is being changed and in the future release, all data acquisitions for a given assay type will be grouped in a single ISA assay table.

# %%
for key in dataframes.keys():
    display(key)
# Out:
# 's_study_01.txt'
# 'a_CELL_Arm_4_4_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_0_5_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_3_0_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_4_2_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_3_5_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_0_0_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_0_2_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_3_4_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_4_0_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_0_4_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_4_5_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_3_2_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_2_0_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_2_5_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_2_4_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'
# 'a_CELL_Arm_2_2_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt'

# %% [markdown]
# We have 5 subjects in each arm and 5 samples per subject have been collected (4 saliva samples per subject and 1 blood sample per subject)

# %%
study_frame = dataframes['s_study_01.txt']
# count_control_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'control' in el)])
# count_treatment_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'treatment' in el)])
# print("There are {} samples in the control arm (i.e. group)".format(count_control_samples))
# print("There are {} samples in the treatment arm (i.e. group)".format(count_treatment_samples))

# %% [markdown]
# Each control samples is fractioned and 2 labelled extracts are produced (i.e. biological replicates).
#
# ```
# [
#     "labelling",
#     {
#         "#replicates": 2
#     }
# ]
# ```
#
# There are 2 possible combinations of mass spectrometry acquisition specified in this study design configuration template and 2 technical replicates are produced for each combinations:
#
# ```
# [
#     "mass spectrometry",
#     {
#         "#replicates": 2,
#         "instrument": [
#             "Agilent QTQF 6510"
#         ],
#         "injection_mode": [
#             "FIA",
#             "LC"
#         ],
#         "acquisition_mode": [
#             "positive mode"
#         ]
#     }
# ]
# ```
#
# Two output raw spectral files are produced as the result of reach run
#
# ```
# [
#     "raw spectral data file",
#     [
#         {
#             "node_type": "data file",
#             "size": 2,
#             "is_input_to_next_protocols": false
#         }
#     ]
# ]
# ```
#
# As a total, we expect:
#
# $$ N_{rows} = (N_{subjects} \times N_{sample_type}) \times (N_{biorepl} \times N_{combinations} \times N_{techrepl}) = (5 \times 2) \times (2 \times 1 \times 1 \times 2) = 10 \times 4 = 40 $$
#
# We can verify for the mass spectrometry assay file of the last epoch of the first arm of the study.

# %%
dataframes['a_CELL_Arm_0_5_ASSAY_GRAPH_000_metabolite-profiling_mass-spectrometry.txt']
# Out:
#                                          Sample Name Protocol REF Performer  \
# 0    GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 1    GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 2    GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 3    GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 4   GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 5   GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 6   GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 7   GRP-Arm_0.SBJ-001.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 8    GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 9    GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 10   GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 11   GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 12  GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 13  GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 14  GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 15  GRP-Arm_0.SBJ-002.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 16   GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 17   GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 18   GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 19   GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 20  GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 21  GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 22  GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 23  GRP-Arm_0.SBJ-003.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 24   GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 25   GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 26   GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 27   GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 28  GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 29  GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 30  GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 31  GRP-Arm_0.SBJ-004.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 32   GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 33   GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 34   GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 35   GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.blood.1   extraction  Ellipsis
# 36  GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 37  GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 38  GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
# 39  GRP-Arm_0.SBJ-005.CEL-CELL_Arm_0_5.SMP-.saliva.1   extraction  Ellipsis
#
#    Extract Name Characteristics[extract type] Protocol REF.1 Performer.1  \
# 0   extract_2-1                polar fraction       labeling    Ellipsis
# 1   extract_2-1                polar fraction       labeling    Ellipsis
# 2   extract_2-1                polar fraction       labeling    Ellipsis
# 3   extract_2-1                polar fraction       labeling    Ellipsis
# 4   extract_7-1                polar fraction       labeling    Ellipsis
# 5   extract_7-1                polar fraction       labeling    Ellipsis
# 6   extract_7-1                polar fraction       labeling    Ellipsis
# 7   extract_7-1                polar fraction       labeling    Ellipsis
# 8   extract_3-1                polar fraction       labeling    Ellipsis
# 9   extract_3-1                polar fraction       labeling    Ellipsis
# 10  extract_3-1                polar fraction       labeling    Ellipsis
# 11  extract_3-1                polar fraction       labeling    Ellipsis
# 12  extract_8-1                polar fraction       labeling    Ellipsis
# 13  extract_8-1                polar fraction       labeling    Ellipsis
# 14  extract_8-1                polar fraction       labeling    Ellipsis
# 15  extract_8-1                polar fraction       labeling    Ellipsis
# 16  extract_1-1                polar fraction       labeling    Ellipsis
# 17  extract_1-1                polar fraction       labeling    Ellipsis
# 18  extract_1-1                polar fraction       labeling    Ellipsis
# 19  extract_1-1                polar fraction       labeling    Ellipsis
# 20  extract_6-1                polar fraction       labeling    Ellipsis
# 21  extract_6-1                polar fraction       labeling    Ellipsis
# 22  extract_6-1                polar fraction       labeling    Ellipsis
# 23  extract_6-1                polar fraction       labeling    Ellipsis
# 24  extract_0-1                polar fraction       labeling    Ellipsis
# 25  extract_0-1                polar fraction       labeling    Ellipsis
# 26  extract_0-1                polar fraction       labeling    Ellipsis
# 27  extract_0-1                polar fraction       labeling    Ellipsis
# 28  extract_5-1                polar fraction       labeling    Ellipsis
# 29  extract_5-1                polar fraction       labeling    Ellipsis
# 30  extract_5-1                polar fraction       labeling    Ellipsis
# 31  extract_5-1                polar fraction       labeling    Ellipsis
# 32  extract_4-1                polar fraction       labeling    Ellipsis
# 33  extract_4-1                polar fraction       labeling    Ellipsis
# 34  extract_4-1                polar fraction       labeling    Ellipsis
# 35  extract_4-1                polar fraction       labeling    Ellipsis
# 36  extract_9-1                polar fraction       labeling    Ellipsis
# 37  extract_9-1                polar fraction       labeling    Ellipsis
# 38  extract_9-1                polar fraction       labeling    Ellipsis
# 39  extract_9-1                polar fraction       labeling    Ellipsis
#
#    Labeled Extract Name   Label     Protocol REF.2  \
# 0   labeled extract_2-3  biotin  mass spectrometry
# 1   labeled extract_2-3  biotin  mass spectrometry
# 2   labeled extract_2-3  biotin  mass spectrometry
# 3   labeled extract_2-3  biotin  mass spectrometry
# 4   labeled extract_7-3  biotin  mass spectrometry
# 5   labeled extract_7-3  biotin  mass spectrometry
# 6   labeled extract_7-3  biotin  mass spectrometry
# 7   labeled extract_7-3  biotin  mass spectrometry
# 8   labeled extract_3-3  biotin  mass spectrometry
# 9   labeled extract_3-3  biotin  mass spectrometry
# 10  labeled extract_3-3  biotin  mass spectrometry
# 11  labeled extract_3-3  biotin  mass spectrometry
# 12  labeled extract_8-3  biotin  mass spectrometry
# 13  labeled extract_8-3  biotin  mass spectrometry
# 14  labeled extract_8-3  biotin  mass spectrometry
# 15  labeled extract_8-3  biotin  mass spectrometry
# 16  labeled extract_1-3  biotin  mass spectrometry
# 17  labeled extract_1-3  biotin  mass spectrometry
# 18  labeled extract_1-3  biotin  mass spectrometry
# 19  labeled extract_1-3  biotin  mass spectrometry
# 20  labeled extract_6-3  biotin  mass spectrometry
# 21  labeled extract_6-3  biotin  mass spectrometry
# 22  labeled extract_6-3  biotin  mass spectrometry
# 23  labeled extract_6-3  biotin  mass spectrometry
# 24  labeled extract_0-3  biotin  mass spectrometry
# 25  labeled extract_0-3  biotin  mass spectrometry
# 26  labeled extract_0-3  biotin  mass spectrometry
# 27  labeled extract_0-3  biotin  mass spectrometry
# 28  labeled extract_5-3  biotin  mass spectrometry
# 29  labeled extract_5-3  biotin  mass spectrometry
# 30  labeled extract_5-3  biotin  mass spectrometry
# 31  labeled extract_5-3  biotin  mass spectrometry
# 32  labeled extract_4-3  biotin  mass spectrometry
# 33  labeled extract_4-3  biotin  mass spectrometry
# 34  labeled extract_4-3  biotin  mass spectrometry
# 35  labeled extract_4-3  biotin  mass spectrometry
# 36  labeled extract_9-3  biotin  mass spectrometry
# 37  labeled extract_9-3  biotin  mass spectrometry
# 38  labeled extract_9-3  biotin  mass spectrometry
# 39  labeled extract_9-3  biotin  mass spectrometry
#
#    Parameter Value[instrument] Parameter Value[injection_mode]  \
# 0            Agilent QTQF 6510                              LC
# 1            Agilent QTQF 6510                              LC
# 2            Agilent QTQF 6510                              LC
# 3            Agilent QTQF 6510                              LC
# 4            Agilent QTQF 6510                              LC
# 5            Agilent QTQF 6510                              LC
# 6            Agilent QTQF 6510                              LC
# 7            Agilent QTQF 6510                              LC
# 8            Agilent QTQF 6510                              LC
# 9            Agilent QTQF 6510                              LC
# 10           Agilent QTQF 6510                              LC
# 11           Agilent QTQF 6510                              LC
# 12           Agilent QTQF 6510                              LC
# 13           Agilent QTQF 6510                              LC
# 14           Agilent QTQF 6510                              LC
# 15           Agilent QTQF 6510                              LC
# 16           Agilent QTQF 6510                              LC
# 17           Agilent QTQF 6510                              LC
# 18           Agilent QTQF 6510                              LC
# 19           Agilent QTQF 6510                              LC
# 20           Agilent QTQF 6510                              LC
# 21           Agilent QTQF 6510                              LC
# 22           Agilent QTQF 6510                              LC
# 23           Agilent QTQF 6510                              LC
# 24           Agilent QTQF 6510                              LC
# 25           Agilent QTQF 6510                              LC
# 26           Agilent QTQF 6510                              LC
# 27           Agilent QTQF 6510                              LC
# 28           Agilent QTQF 6510                              LC
# 29           Agilent QTQF 6510                              LC
# 30           Agilent QTQF 6510                              LC
# 31           Agilent QTQF 6510                              LC
# 32           Agilent QTQF 6510                              LC
# 33           Agilent QTQF 6510                              LC
# 34           Agilent QTQF 6510                              LC
# 35           Agilent QTQF 6510                              LC
# 36           Agilent QTQF 6510                              LC
# 37           Agilent QTQF 6510                              LC
# 38           Agilent QTQF 6510                              LC
# 39           Agilent QTQF 6510                              LC
#
#    Parameter Value[acquisition_mode]           MS Assay Name Performer.2  \
# 0                      positive mode   mass spectrometry_2-4    Ellipsis
# 1                      negative mode   mass spectrometry_2-8    Ellipsis
# 2                      negative mode  mass spectrometry_2-10    Ellipsis
# 3                      positive mode   mass spectrometry_2-6    Ellipsis
# 4                      negative mode  mass spectrometry_7-10    Ellipsis
# 5                      positive mode   mass spectrometry_7-4    Ellipsis
# 6                      positive mode   mass spectrometry_7-6    Ellipsis
# 7                      negative mode   mass spectrometry_7-8    Ellipsis
# 8                      positive mode   mass spectrometry_3-4    Ellipsis
# 9                      negative mode   mass spectrometry_3-8    Ellipsis
# 10                     positive mode   mass spectrometry_3-6    Ellipsis
# 11                     negative mode  mass spectrometry_3-10    Ellipsis
# 12                     negative mode   mass spectrometry_8-8    Ellipsis
# 13                     positive mode   mass spectrometry_8-6    Ellipsis
# 14                     positive mode   mass spectrometry_8-4    Ellipsis
# 15                     negative mode  mass spectrometry_8-10    Ellipsis
# 16                     negative mode   mass spectrometry_1-8    Ellipsis
# 17                     positive mode   mass spectrometry_1-4    Ellipsis
# 18                     negative mode  mass spectrometry_1-10    Ellipsis
# 19                     positive mode   mass spectrometry_1-6    Ellipsis
# 20                     positive mode   mass spectrometry_6-4    Ellipsis
# 21                     positive mode   mass spectrometry_6-6    Ellipsis
# 22                     negative mode   mass spectrometry_6-8    Ellipsis
# 23                     negative mode  mass spectrometry_6-10    Ellipsis
# 24                     negative mode   mass spectrometry_0-8    Ellipsis
# 25                     positive mode   mass spectrometry_0-4    Ellipsis
# 26                     positive mode   mass spectrometry_0-6    Ellipsis
# 27                     negative mode  mass spectrometry_0-10    Ellipsis
# 28                     negative mode   mass spectrometry_5-8    Ellipsis
# 29                     positive mode   mass spectrometry_5-6    Ellipsis
# 30                     negative mode  mass spectrometry_5-10    Ellipsis
# 31                     positive mode   mass spectrometry_5-4    Ellipsis
# 32                     positive mode   mass spectrometry_4-4    Ellipsis
# 33                     negative mode   mass spectrometry_4-8    Ellipsis
# 34                     negative mode  mass spectrometry_4-10    Ellipsis
# 35                     positive mode   mass spectrometry_4-6    Ellipsis
# 36                     negative mode  mass spectrometry_9-10    Ellipsis
# 37                     negative mode   mass spectrometry_9-8    Ellipsis
# 38                     positive mode   mass spectrometry_9-4    Ellipsis
# 39                     positive mode   mass spectrometry_9-6    Ellipsis
#
#          Raw Spectral Data File
# 0    raw spectral data file_2-5
# 1    raw spectral data file_2-9
# 2   raw spectral data file_2-11
# 3    raw spectral data file_2-7
# 4   raw spectral data file_7-11
# 5    raw spectral data file_7-5
# 6    raw spectral data file_7-7
# 7    raw spectral data file_7-9
# 8    raw spectral data file_3-5
# 9    raw spectral data file_3-9
# 10   raw spectral data file_3-7
# 11  raw spectral data file_3-11
# 12   raw spectral data file_8-9
# 13   raw spectral data file_8-7
# 14   raw spectral data file_8-5
# 15  raw spectral data file_8-11
# 16   raw spectral data file_1-9
# 17   raw spectral data file_1-5
# 18  raw spectral data file_1-11
# 19   raw spectral data file_1-7
# 20   raw spectral data file_6-5
# 21   raw spectral data file_6-7
# 22   raw spectral data file_6-9
# 23  raw spectral data file_6-11
# 24   raw spectral data file_0-9
# 25   raw spectral data file_0-5
# 26   raw spectral data file_0-7
# 27  raw spectral data file_0-11
# 28   raw spectral data file_5-9
# 29   raw spectral data file_5-7
# 30  raw spectral data file_5-11
# 31   raw spectral data file_5-5
# 32   raw spectral data file_4-5
# 33   raw spectral data file_4-9
# 34  raw spectral data file_4-11
# 35   raw spectral data file_4-7
# 36  raw spectral data file_9-11
# 37   raw spectral data file_9-9
# 38   raw spectral data file_9-5
# 39   raw spectral data file_9-7
