# %% [markdown]
# # Create ISA-API Investigation from Datascriptor Study Design configuration
#
# In this notebook I will show you how you can use a study design configuration is JSON format as produce by datascriptor (https://gitlab.com/datascriptor/datascriptor) to generate a single-study ISA investigation and how you can then serialise it in JSON and tabular (i.e. CSV) format.
#
# Or study design configuration consists of:
# [missing]

# %% [markdown]
# ## 1. Setup
#
# Let's import all the required libraries

# %%
from time import time
import os
import json

## ISA-API related imports
from isatools.model import Investigation, Study

## ISA-API create mode related imports
from isatools.create.models import StudyDesign
from isatools.create.connectors import generate_study_design_from_config

# serializer from ISA Investigation to JSON
from isatools.isajson import ISAJSONEncoder

# ISA-Tab serialisation
from isatools import isatab
# Out:
# LOG: <Logger isatools (DEBUG)>
# /Users/philippe/.pyenv/versions/3.8.0/envs/isa-api-py38/src/isatools/isatools/net/resources/saxon9/saxon9he.jar

# %%
## ISA-API create mode related imports
from isatools.create import models
from isatools import isajson

# %% [markdown]
# ## 2. Load the Study Design JSON configuration
#
# First of all we load the study design configurator

# %%
with open(os.path.abspath(os.path.join(
    "ds-study-design-config", "study-design-3-repeated-treatments-datascriptor.json"
)), "r") as config_file:
    study_design_config = json.load(config_file)
study_design_config
# Out:
# {'treatmentPlan': {'screen': {'name': 'screen',
#    'duration': None,
#    'durationUnit': ''},
#   'runIn': {'name': 'run-in', 'duration': None, 'durationUnit': ''},
#   'washout': {'name': 'washout', 'duration': '5', 'durationUnit': 'days'},
#   'followUp': {'name': 'follow-up', 'duration': 60, 'durationUnit': 'days'},
#   'treatments': [{'agent': 'ibuprofen',
#     'intensity': 8,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'},
#    {'agent': 'aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'},
#    {'agent': 'paracetamol',
#     'intensity': 10,
#     'intensityUnit': 'mg',
#     'duration': 10,
#     'durationUnit': 'days'}],
#   'elementParams': {'agents': [],
#    'intensities': [],
#    'intensityUnit': '',
#    'durations': [],
#    'durationUnit': ''}},
#  'generatedStudyDesign': {'name': 'test study',
#   'description': 'this is the verbose description',
#   'type': {'term': 'crossover design',
#    'id': 'OBI:0500003',
#    'iri': 'http://purl.obolibrary.org/obo/OBI_0500003'},
#   'elements': [{'id': '83978887-be4c-4cac-afb6-0faad3d07c86',
#     'name': 'treatment_0',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'ibuprofen',
#     'intensity': 8,
#     'intensityUnit': 'mg'},
#    {'id': 'e283a7c5-955f-4d3b-b99e-0053a2af5a61',
#     'name': 'washout',
#     'duration': 5,
#     'durationUnit': 'days'},
#    {'id': '696a2da4-329a-4b39-a681-e402afb4e89f',
#     'name': 'treatment_1',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg'},
#    {'id': '6bf4662d-852f-44ad-9b46-acff5291c47f',
#     'name': 'treatment_2',
#     'duration': 10,
#     'durationUnit': 'days',
#     'agent': 'paracetamol',
#     'intensity': 10,
#     'intensityUnit': 'mg'},
#    {'id': '28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7',
#     'name': 'follow-up',
#     'duration': 60,
#     'durationUnit': 'days'}],
#   'events': [],
#   'arms': [{'id': '#arm/0',
#     'name': 'Arm_0',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/1',
#     'name': 'Arm_1',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/2',
#     'name': 'Arm_2',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/3',
#     'name': 'Arm_3',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/4',
#     'name': 'Arm_4',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#    {'id': '#arm/5',
#     'name': 'Arm_5',
#     'subjectType': 'human',
#     'size': 5,
#     'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#       'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#      {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#      {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#      {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]}]},
#  'selectedArms': [{'id': '#arm/0',
#    'name': 'Arm_0',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/2',
#    'name': 'Arm_2',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/4',
#    'name': 'Arm_4',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]},
#   {'id': '#arm/3',
#    'name': 'Arm_3',
#    'subjectType': 'human',
#    'size': 5,
#    'epochs': [{'elements': ['696a2da4-329a-4b39-a681-e402afb4e89f'],
#      'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['6bf4662d-852f-44ad-9b46-acff5291c47f'], 'events': []},
#     {'elements': ['e283a7c5-955f-4d3b-b99e-0053a2af5a61'], 'events': []},
#     {'elements': ['83978887-be4c-4cac-afb6-0faad3d07c86'], 'events': []},
#     {'elements': ['28e829e2-030c-41ad-b9b9-b7a0e1a9b3e7'], 'events': []}]}],
#  'samplePlan': [{'sampleType': 'saliva',
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'sampleTypeSizes': {'Arm_0': [1, None, 1, None, 1, 1],
#     'Arm_2': [1, None, 1, None, 1, 1],
#     'Arm_4': [1, None, 1, None, 1, 1],
#     'Arm_3': [1, None, 1, None, 1, 1]}},
#   {'sampleType': 'blood',
#    'selectedCells': {'Arm_0': [False, False, False, False, False, True],
#     'Arm_2': [False, False, False, False, False, True],
#     'Arm_4': [False, False, False, False, False, True],
#     'Arm_3': [False, False, False, False, False, True]},
#    'sampleTypeSizes': {'Arm_0': [None, None, None, None, None, 1],
#     'Arm_2': [None, None, None, None, None, 1],
#     'Arm_4': [None, None, None, None, None, 1],
#     'Arm_3': [None, None, None, None, None, 1]}}],
#  'assayConfigs': [{'id': 0,
#    'name': 'Metabolite Profiling - Mass. Spec.',
#    'icon': 'fa fa-dna',
#    'color': 'green',
#    'measurement_type': 'metabolite profiling',
#    'technology_type': 'mass spectrometry',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['polar fraction',
#         'nonpolar fraction'],
#        'values': ['polar fraction']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['labeling', {'#replicates': {'value': 1}}],
#     ['labeled extract',
#      {'node_type': 'labeled extract',
#       'characteristics_category': 'labelled extract type',
#       'characteristics_value': {'options': ['biotin', 'cy-5', 'cy-3'],
#        'values': ['biotin']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['mass spectrometry',
#      {'#replicates': {'value': 2},
#       'instrument': {'options': ['Agilent QTQF 6510', 'Agilent QTQF 6520A'],
#        'values': ['Agilent QTQF 6510']},
#       'injection_mode': {'options': ['FIA', 'LC'], 'values': ['LC']},
#       'acquisition_mode': {'options': ['positive mode', 'negative mode'],
#        'values': ['positive mode', 'negative mode']}}],
#     ['raw spectral data file',
#      {'node_type': 'data file',
#       'is_input_to_next_protocols': {'value': True}}]],
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'selectedSampleTypes': {'Arm_0': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']],
#     'Arm_2': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_4': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_3': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']]}},
#   {'id': 1,
#    'name': 'Metabolite Profiling - Mass. Spec. (Annotated)',
#    'icon': 'fa fa-dna',
#    'color': 'blue',
#    'measurement_type': {'term': 'metabolite profiling',
#     'iri': 'http://purl.obolibrary.org/obo/OBI_0000366',
#     'source': None},
#    'technology_type': {'term': 'mass spectrometry',
#     'iri': 'http://purl.obolibrary.org/obo/OBI_0000470',
#     'source': None},
#    'workflow': [[{'term': 'extraction',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0302884',
#       'source': None},
#      {'#replicates': {'value': 1}}],
#     [{'term': 'extract', 'iri': 'http://purl.obolibrary.org/obo/OBI_0000423'},
#      {'node_type': 'extract',
#       'characteristics_category': {'term': 'extract type',
#        'iri': None,
#        'source': None},
#       'characteristics_value': {'options': [{'term': 'polar fraction',
#          'iri': None,
#          'source': None},
#         {'term': 'lipids', 'iri': None, 'source': None}],
#        'values': []},
#       'is_input_to_next_protocols': {'value': True}}],
#     [{'term': 'labelling',
#       'iri': 'http://purl.obolibrary.org/obo/CHMO_0001675',
#       'source': None},
#      {'#replicates': {'value': 1}}],
#     [{'term': 'labelled extract',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0000924',
#       'source': None},
#      {'node_type': 'labeled extract',
#       'characteristics_category': {'term': 'labelled extract type',
#        'iri': None,
#        'source': None},
#       'characteristics_value': {'options': [{'term': 'biotin',
#          'iri': None,
#          'source': None},
#         {'term': 'cy-5', 'iri': None, 'source': None},
#         {'term': 'cy-3', 'iri': None, 'source': None}],
#        'values': [{'term': 'cy-3', 'iri': None, 'source': None}]},
#       'is_input_to_next_protocols': {'value': True}}],
#     [{'term': 'mass spectrometry',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0200085',
#       'source': None},
#      {'#replicates': {'value': 1},
#       'instrument': {'options': [{'term': 'Agilent QTQF 6510',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000676',
#          'source': None},
#         {'term': 'Agilent QTQF 6520A',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000677',
#          'source': None}],
#        'values': [{'term': 'Agilent QTQF 6520A',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000677',
#          'source': None}]},
#       'injection_mode': {'options': [{'term': 'FIA',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1000058',
#          'source': None},
#         {'term': 'LC', 'iri': None, 'source': None}],
#        'values': []},
#       'acquisition_mode': {'options': [{'term': 'positive mode',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#          'source': None}],
#        'values': [{'term': 'positive mode',
#          'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#          'source': None}]}}],
#     [{'term': 'raw spectral data file',
#       'iri': 'http://purl.obolibrary.org/obo/MS_1003083',
#       'source': None},
#      {'node_type': 'data file',
#       'is_input_to_next_protocols': {'value': True}}]],
#    '@context': {'measurement_type': 'http://purl.obolibrary.org/obo/NCIT_C25209',
#     'technology_type': 'http://www.ebi.ac.uk/efo/EFO_0005521',
#     'instrument': 'http://purl.obolibrary.org/obo/MS_1000463',
#     'injection_mode': 'http://purl.obolibrary.org/obo/MS_1000007',
#     'acquisition_mode': 'http://purl.obolibrary.org/obo/MS_1000027'},
#    'selectedCells': {'Arm_0': [False, False, False, False, False, False],
#     'Arm_2': [False, False, False, False, False, False],
#     'Arm_4': [False, False, False, False, False, False],
#     'Arm_3': [False, False, False, False, False, False]},
#    'selectedSampleTypes': {'Arm_0': [[], [], [], [], [], []],
#     'Arm_2': [[], [], [], [], [], []],
#     'Arm_4': [[], [], [], [], [], []],
#     'Arm_3': [[], [], [], [], [], []]}},
#   {'id': 2,
#    'name': 'Metabolite Profiling - NMR',
#    'icon': 'fa fa-atom',
#    'color': 'orange',
#    'measurement_type': 'metabolite profiling',
#    'technology_type': 'NMR spectroscopy',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['supernatant', 'pellet'],
#        'values': ['pellet']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['nmr_spectroscopy',
#      {'#replicates': {'value': 1},
#       'instrument': {'options': ['Bruker AvanceII 1 GHz'],
#        'values': ['Bruker AvanceII 1 GHz']},
#       'acquisition_mode': {'options': ['1D 13C NMR',
#         '1D 1H NMR',
#         '2D 13C-13C NMR'],
#        'values': ['1D 13C NMR']},
#       'pulse_sequence': {'options': ['CPMG', 'TOCSY', 'HOESY', 'watergate'],
#        'values': ['CPMG']}}],
#     ['raw_spectral_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [True, False, True, False, True, True],
#     'Arm_2': [True, False, True, False, True, True],
#     'Arm_4': [True, False, True, False, True, True],
#     'Arm_3': [True, False, True, False, True, True]},
#    'selectedSampleTypes': {'Arm_0': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']],
#     'Arm_2': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_4': [['saliva'], [], ['saliva'], [], ['saliva'], ['saliva', 'blood']],
#     'Arm_3': [['saliva'],
#      [],
#      ['saliva'],
#      [],
#      ['saliva'],
#      ['saliva', 'blood']]}}],
#  'selectedAssayTypes': {'Metabolite Profiling - Mass. Spec.': True,
#   'Metabolite Profiling - Mass. Spec. (Annotated)': False,
#   'Metabolite Profiling - NMR': False}}

# %% [markdown]
# ## 3. Generate the ISA Study Design from the JSON configuration
# To perform the conversion we just need to use the function `generate_isa_study_design_from_config` (name possibly subject to change, should we drop the "isa" and "datascriptor" qualifiers?)

# %%
study_design = generate_study_design_from_config(study_design_config)
assert isinstance(study_design, StudyDesign)

# %% [markdown]
# ## 4. Generate the ISA Study from the StudyDesign and embed it into an ISA Investigation
#
# The `StudyDesign.generate_isa_study()` method returns the complete ISA-API `Study` object.

# %%
start = time()
study = study_design.generate_isa_study()
end = time()
print('The generation of the study design took {:.2f} s.'.format(end - start))
assert isinstance(study, Study)
investigation = Investigation(studies=[study])
# Out:
# The generation of the study design took 0.24 s.

# %% [markdown]
# ## 5. Serialize and save the JSON representation of the generated ISA Investigation

# %%
start = time()
inv_json = json.dumps(investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
end = time()
print('The JSON serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The JSON serialisation of the ISA investigation took 0.14 s.

# %%
directory = os.path.abspath(os.path.join('output'))
if not os.path.exists(directory):
    os.makedirs(directory)
with open(os.path.abspath(os.path.join('output','isa-investigation-2-arms-nmr-ms.json')), 'w') as out_fp:
    json.dump(json.loads(inv_json), out_fp)

# %% [markdown]
# ## 6. Dump the ISA Investigation to ISA-Tab

# %%
start = time()
isatab.dump(investigation, os.path.abspath(os.path.join('output')))
end = time()
print('The Tab serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The Tab serialisation of the ISA investigation took 3.17 s.

# %%
#%debug

# %% [markdown]
# To use them on the notebook we can also dump the tables to pandas DataFrames, using the `dump_tables_to_dataframes` function rather than dump

# %%
dataframes = isatab.dump_tables_to_dataframes(investigation)

# %%
len(dataframes)
# Out:
# 17

# %% [markdown]
# ## 7. Check the correctness of the ISA-Tab DataFrames
#
# We have 1 study file and 5 assay files:
# * 1 assay file for Mass. Spec. (treatmennt arm, third epoch: surgery)
# * 2 assay files for Mass. Spec. (both arms, fourth epoch: follow-up)
# * 2 assay files for NMR (both arms, fourth epoch: follow-up)

# %%
for key in dataframes.keys():
    display(key)
# Out:
# 's_study_01.txt'
# 'a_A0E2_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A1E2_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A1E0_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A0E0_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A3E4_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A2E5_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A2E4_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A3E5_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A3E2_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A2E2_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A2E0_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A3E0_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A0E4_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A1E5_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A1E4_ASSAY0_metabolite-profiling_mass-spectrometry.txt'
# 'a_A0E5_ASSAY0_metabolite-profiling_mass-spectrometry.txt'

# %% [markdown]
# We have 8 subjects in the control arm and 24 samples have been collected (3 blood samples per subject during the follow-up epoch)
#
# We have 10 subjects in the control arm and 40 samples have been collected (3 blood samples per subject during the follow-up epoch and 1 liver sample per subject during the surgery epoch)

# %%
study_frame = dataframes['s_study_01.txt']
count_control_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'control' in el)])
count_treatment_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'treatment' in el)])
print("There are {} samples in the control arm (i.e. group)".format(count_control_samples))
print("There are {} samples in the treatment arm (i.e. group)".format(count_treatment_samples))
# Out:
# There are 0 samples in the control arm (i.e. group)
# There are 0 samples in the treatment arm (i.e. group)

# %% [markdown]
# Each control samples is fractioned and 2 labelled extracts are produced (i.e. biological replicates).
#
# ```
# [
#     "labelling",
#     {
#         "#replicates": 2
#     }
# ]
# ```
#
# There are 2 possible combinations of Mass Spec Assay specified in our configuration template and 2 techincal replicate are produced for each combinations:
#
# ```
# [
#     "mass spectrometry",
#     {
#         "#replicates": 2,
#         "instrument": [
#             "Agilent QTQF 6510"
#         ],
#         "injection_mode": [
#             "FIA",
#             "LC"
#         ],
#         "acquisition_mode": [
#             "positive mode"
#         ]
#     }
# ]
# ```
#
# Two output raw spectral files are produced as the result of reach run
#
# ```
# [
#     "raw spectral data file",
#     [
#         {
#             "node_type": "data file",
#             "size": 2,
#             "is_input_to_next_protocols": false
#         }
#     ]
# ]
# ```
#
# As a total we expect
#
# $$ N_{rows} = (N_{subjects} \times N_{samples}) \times (N_{biorepl} \times N_{combinations} \times N_{techrepl}) = (8 \times 3) \times (2 \times 2 \times 2 \times 2) = 24 \times 16 = 384 $$
#
# Which we can verify for the mass spectrometry assay file of the control group.

# %%
dataframes['a_A0E2_ASSAY0_metabolite-profiling_mass-spectrometry.txt']
# Out:
#                     Sample Name Protocol REF Performer          Extract Name  \
# 0   GRP0_SBJ1_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-3-1
# 1   GRP0_SBJ1_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-3-1
# 2   GRP0_SBJ1_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-3-1
# 3   GRP0_SBJ1_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-3-1
# 4   GRP0_SBJ2_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-4-1
# 5   GRP0_SBJ2_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-4-1
# 6   GRP0_SBJ2_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-4-1
# 7   GRP0_SBJ2_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-4-1
# 8   GRP0_SBJ3_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-2-1
# 9   GRP0_SBJ3_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-2-1
# 10  GRP0_SBJ3_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-2-1
# 11  GRP0_SBJ3_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-2-1
# 12  GRP0_SBJ4_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-1-1
# 13  GRP0_SBJ4_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-1-1
# 14  GRP0_SBJ4_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-1-1
# 15  GRP0_SBJ4_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-1-1
# 16  GRP0_SBJ5_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-0-1
# 17  GRP0_SBJ5_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-0-1
# 18  GRP0_SBJ5_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-0-1
# 19  GRP0_SBJ5_A0E2_SMP-saliva-1   extraction  Ellipsis  EXTR_A0E2_ASSAY0-0-1
#
#    Characteristics[extract type] Protocol REF.1 Performer.1  \
# 0                 polar fraction       labeling    Ellipsis
# 1                 polar fraction       labeling    Ellipsis
# 2                 polar fraction       labeling    Ellipsis
# 3                 polar fraction       labeling    Ellipsis
# 4                 polar fraction       labeling    Ellipsis
# 5                 polar fraction       labeling    Ellipsis
# 6                 polar fraction       labeling    Ellipsis
# 7                 polar fraction       labeling    Ellipsis
# 8                 polar fraction       labeling    Ellipsis
# 9                 polar fraction       labeling    Ellipsis
# 10                polar fraction       labeling    Ellipsis
# 11                polar fraction       labeling    Ellipsis
# 12                polar fraction       labeling    Ellipsis
# 13                polar fraction       labeling    Ellipsis
# 14                polar fraction       labeling    Ellipsis
# 15                polar fraction       labeling    Ellipsis
# 16                polar fraction       labeling    Ellipsis
# 17                polar fraction       labeling    Ellipsis
# 18                polar fraction       labeling    Ellipsis
# 19                polar fraction       labeling    Ellipsis
#
#        Labeled Extract Name   Label     Protocol REF.2  \
# 0   LBLEXTR_A0E2_ASSAY0-3-3  biotin  mass spectrometry
# 1   LBLEXTR_A0E2_ASSAY0-3-3  biotin  mass spectrometry
# 2   LBLEXTR_A0E2_ASSAY0-3-3  biotin  mass spectrometry
# 3   LBLEXTR_A0E2_ASSAY0-3-3  biotin  mass spectrometry
# 4   LBLEXTR_A0E2_ASSAY0-4-3  biotin  mass spectrometry
# 5   LBLEXTR_A0E2_ASSAY0-4-3  biotin  mass spectrometry
# 6   LBLEXTR_A0E2_ASSAY0-4-3  biotin  mass spectrometry
# 7   LBLEXTR_A0E2_ASSAY0-4-3  biotin  mass spectrometry
# 8   LBLEXTR_A0E2_ASSAY0-2-3  biotin  mass spectrometry
# 9   LBLEXTR_A0E2_ASSAY0-2-3  biotin  mass spectrometry
# 10  LBLEXTR_A0E2_ASSAY0-2-3  biotin  mass spectrometry
# 11  LBLEXTR_A0E2_ASSAY0-2-3  biotin  mass spectrometry
# 12  LBLEXTR_A0E2_ASSAY0-1-3  biotin  mass spectrometry
# 13  LBLEXTR_A0E2_ASSAY0-1-3  biotin  mass spectrometry
# 14  LBLEXTR_A0E2_ASSAY0-1-3  biotin  mass spectrometry
# 15  LBLEXTR_A0E2_ASSAY0-1-3  biotin  mass spectrometry
# 16  LBLEXTR_A0E2_ASSAY0-0-3  biotin  mass spectrometry
# 17  LBLEXTR_A0E2_ASSAY0-0-3  biotin  mass spectrometry
# 18  LBLEXTR_A0E2_ASSAY0-0-3  biotin  mass spectrometry
# 19  LBLEXTR_A0E2_ASSAY0-0-3  biotin  mass spectrometry
#
#    Parameter Value[instrument] Parameter Value[injection_mode]  \
# 0            Agilent QTQF 6510                              LC
# 1            Agilent QTQF 6510                              LC
# 2            Agilent QTQF 6510                              LC
# 3            Agilent QTQF 6510                              LC
# 4            Agilent QTQF 6510                              LC
# 5            Agilent QTQF 6510                              LC
# 6            Agilent QTQF 6510                              LC
# 7            Agilent QTQF 6510                              LC
# 8            Agilent QTQF 6510                              LC
# 9            Agilent QTQF 6510                              LC
# 10           Agilent QTQF 6510                              LC
# 11           Agilent QTQF 6510                              LC
# 12           Agilent QTQF 6510                              LC
# 13           Agilent QTQF 6510                              LC
# 14           Agilent QTQF 6510                              LC
# 15           Agilent QTQF 6510                              LC
# 16           Agilent QTQF 6510                              LC
# 17           Agilent QTQF 6510                              LC
# 18           Agilent QTQF 6510                              LC
# 19           Agilent QTQF 6510                              LC
#
#    Parameter Value[acquisition_mode]                       MS Assay Name  \
# 0                      negative mode   mass-spectrometry_A0E2_ASSAY0-3-8
# 1                      positive mode   mass-spectrometry_A0E2_ASSAY0-3-4
# 2                      negative mode  mass-spectrometry_A0E2_ASSAY0-3-10
# 3                      positive mode   mass-spectrometry_A0E2_ASSAY0-3-6
# 4                      negative mode   mass-spectrometry_A0E2_ASSAY0-4-8
# 5                      positive mode   mass-spectrometry_A0E2_ASSAY0-4-6
# 6                      positive mode   mass-spectrometry_A0E2_ASSAY0-4-4
# 7                      negative mode  mass-spectrometry_A0E2_ASSAY0-4-10
# 8                      positive mode   mass-spectrometry_A0E2_ASSAY0-2-6
# 9                      negative mode   mass-spectrometry_A0E2_ASSAY0-2-8
# 10                     positive mode   mass-spectrometry_A0E2_ASSAY0-2-4
# 11                     negative mode  mass-spectrometry_A0E2_ASSAY0-2-10
# 12                     negative mode   mass-spectrometry_A0E2_ASSAY0-1-8
# 13                     positive mode   mass-spectrometry_A0E2_ASSAY0-1-4
# 14                     negative mode  mass-spectrometry_A0E2_ASSAY0-1-10
# 15                     positive mode   mass-spectrometry_A0E2_ASSAY0-1-6
# 16                     positive mode   mass-spectrometry_A0E2_ASSAY0-0-6
# 17                     negative mode  mass-spectrometry_A0E2_ASSAY0-0-10
# 18                     positive mode   mass-spectrometry_A0E2_ASSAY0-0-4
# 19                     negative mode   mass-spectrometry_A0E2_ASSAY0-0-8
#
#    Performer.2                   Raw Spectral Data File
# 0     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-3-9
# 1     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-3-5
# 2     Ellipsis  raw-spectral-data-file_A0E2_ASSAY0-3-11
# 3     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-3-7
# 4     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-4-9
# 5     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-4-7
# 6     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-4-5
# 7     Ellipsis  raw-spectral-data-file_A0E2_ASSAY0-4-11
# 8     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-2-7
# 9     Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-2-9
# 10    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-2-5
# 11    Ellipsis  raw-spectral-data-file_A0E2_ASSAY0-2-11
# 12    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-1-9
# 13    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-1-5
# 14    Ellipsis  raw-spectral-data-file_A0E2_ASSAY0-1-11
# 15    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-1-7
# 16    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-0-7
# 17    Ellipsis  raw-spectral-data-file_A0E2_ASSAY0-0-11
# 18    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-0-5
# 19    Ellipsis   raw-spectral-data-file_A0E2_ASSAY0-0-9
