# %% [markdown]
# # Create ISA-API Investigation from Datascriptor Study Design configuration
# # Observational study on Human students
#
# In this notebook I will show you how you can use a study design configuration is JSON format as produce by datascriptor (https://gitlab.com/datascriptor/datascriptor) to generate a single-study ISA investigation and how you can then serialise it in JSON and tabular (i.e. CSV) format.
#
# Or study design configuration consists of:
# - a 4-arm study design. Each arm has 10 subjects
# - subjects are human, male and female, of three age groups in years (6-10, 10-15, 15-18)
# - two phases: the observational phase and follow-up
# - one sample type colllected: blood
# - two assay types:

# %% [markdown]
# ## 1. Setup
#
# Let's import all the required libraries

# %%
from time import time
import os
import json

# %%
## ISA-API related imports
from isatools.model import Investigation, Study

# %%
## ISA-API create mode related imports
from isatools.create.model import StudyDesign
from isatools.create.connectors import generate_study_design

# serializer from ISA Investigation to JSON
from isatools.isajson import ISAJSONEncoder

# ISA-Tab serialisation
from isatools import isatab

# %%
## ISA-API create mode related imports
from isatools.create import model
from isatools import isajson

# %% [markdown]
# ## 2. Load the Study Design JSON configuration
#
# First of all we load the study design configurator with all the specs defined above

# %%
with open(os.path.abspath(os.path.join(
    "config", "observational-design-students.json"
)), "r") as config_file:
    study_design_config = json.load(config_file)
study_design_config
# Out:
# {'subjectGroups': {'selected': [{'name': 'SubjectGroup_0',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '15-18',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_1',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '10-15',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_2',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '6-10',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_3',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '15-18',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_4',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '10-15',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_5',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'name': 'age group',
#       'value': '6-10',
#       'unit': 'years',
#       'isQuantitative': True}]}],
#   'unselected': []},
#  'treatmentPlan': {'observationPeriod': {'name': 'observation period',
#    'duration': 90,
#    'durationUnit': 'days'},
#   'screen': {'selected': False,
#    'name': 'screen',
#    'duration': None,
#    'durationUnit': ''},
#   'runIn': {'selected': False,
#    'name': 'run-in',
#    'duration': None,
#    'durationUnit': ''},
#   'washout': {'selected': False,
#    'name': 'washout',
#    'duration': None,
#    'durationUnit': ''},
#   'followUp': {'selected': True,
#    'name': 'follow-up',
#    'duration': 180,
#    'durationUnit': 'days'},
#   'elementParams': {'agents': [],
#    'intensities': [],
#    'durations': [],
#    'interventionType': None,
#    'intensityUnit': '',
#    'durationUnit': ''},
#   'treatments': [{'_id': '60648e78f3eccab7f53da5a5',
#     'interventionType': None,
#     'agent': None,
#     'intensity': None,
#     'intensityUnit': '',
#     'duration': None,
#     'durationUnit': ''},
#    {'_id': '60648e78f3eccab7f53da5a6',
#     'interventionType': None,
#     'agent': None,
#     'intensity': None,
#     'intensityUnit': '',
#     'duration': None,
#     'durationUnit': ''}]},
#  'arms': {'unselected': [],
#   'selected': [{'_id': '60648e78f3eccab7f53da5a9',
#     'id': '0',
#     'name': 'Arm_0',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5aa',
#       'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5ab',
#       'name': 'age group',
#       'value': '15-18',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5ac'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5ad'}]},
#    {'_id': '60648e78f3eccab7f53da5ae',
#     'id': '1',
#     'name': 'Arm_1',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5af',
#       'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5b0',
#       'name': 'age group',
#       'value': '10-15',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5b1'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5b2'}]},
#    {'_id': '60648e78f3eccab7f53da5b3',
#     'id': '2',
#     'name': 'Arm_2',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5b4',
#       'name': 'sex',
#       'value': 'M',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5b5',
#       'name': 'age group',
#       'value': '6-10',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5b6'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5b7'}]},
#    {'_id': '60648e78f3eccab7f53da5b8',
#     'id': '3',
#     'name': 'Arm_3',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5b9',
#       'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5ba',
#       'name': 'age group',
#       'value': '15-18',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5bb'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5bc'}]},
#    {'_id': '60648e78f3eccab7f53da5bd',
#     'id': '4',
#     'name': 'Arm_4',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5be',
#       'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5bf',
#       'name': 'age group',
#       'value': '10-15',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5c0'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5c1'}]},
#    {'_id': '60648e78f3eccab7f53da5c2',
#     'id': '5',
#     'name': 'Arm_5',
#     'observationalFactors': [{'_id': '60648e78f3eccab7f53da5c3',
#       'name': 'sex',
#       'value': 'F',
#       'unit': None,
#       'isQuantitative': False},
#      {'_id': '60648e78f3eccab7f53da5c4',
#       'name': 'age group',
#       'value': '6-10',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 100,
#     'epochs': [{'elements': ['5de2c40f-9320-422f-8fc8-b1bb80ba5adf'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5c5'},
#      {'elements': ['007d1ff8-5e16-401c-b847-5eaf6ba61436'],
#       'events': [],
#       '_id': '60648e78f3eccab7f53da5c6'}]}]},
#  'observationalFactors': [{'name': 'sex',
#    'values': ['M', 'F'],
#    'isQuantitative': False,
#    'unit': None},
#   {'name': 'age group',
#    'values': ['6-10', '10-15', '15-18'],
#    'isQuantitative': True,
#    'unit': 'years'}],
#  'samplePlan': [{'sampleType': 'blood',
#    'selectedCells': {'Arm_0': [True, True],
#     'Arm_1': [True, True],
#     'Arm_2': [True, True],
#     'Arm_3': [True, True],
#     'Arm_4': [True, True],
#     'Arm_5': [True, True]},
#    'sampleTypeSizes': {'Arm_0': [3, 6],
#     'Arm_1': [3, 6],
#     'Arm_2': [3, 6],
#     'Arm_3': [3, 6],
#     'Arm_4': [3, 6],
#     'Arm_5': [3, 6]}}],
#  'assayPlan': [{'id': 8,
#    'name': 'genome sequencing by nucleotide sequencing',
#    'icon': 'fa fa-dna',
#    'color': 'purple',
#    'measurement_type': 'genome sequencing',
#    'technology_type': 'nucleic acid sequencing',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['gDNA', 'DNA'], 'values': ['DNA']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['library_preparation',
#      {'#replicates': {'value': 2},
#       'instrument': {'options': ['MinION',
#         'GridION',
#         'PromethION',
#         'Illumina HiSeq 4000',
#         'Illumina NovaSeq 6000',
#         'AB 3730xL Genetic Analyzer'],
#        'values': ['Illumina NovaSeq 6000']},
#       'library_orientation': {'options': ['single', 'paired'],
#        'values': ['single', 'paired']},
#       'library_strategy': {'options': ['AMPLICON',
#         'CLONE',
#         'WGA',
#         'WGS',
#         'WXS',
#         'OTHER'],
#        'values': ['WGA']}}],
#     ['raw_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [True, False],
#     'Arm_1': [True, False],
#     'Arm_2': [True, False],
#     'Arm_3': [True, False],
#     'Arm_4': [True, False],
#     'Arm_5': [True, False]},
#    'selectedSampleTypes': {'Arm_0': [['blood'], ['blood']],
#     'Arm_1': [['blood'], ['blood']],
#     'Arm_2': [['blood'], ['blood']],
#     'Arm_3': [['blood'], ['blood']],
#     'Arm_4': [['blood'], ['blood']],
#     'Arm_5': [['blood'], ['blood']]}},
#   {'id': 10,
#    'name': 'clinical chemistry by marker panel',
#    'icon': 'fa fa-flask',
#    'color': 'yellow',
#    'measurement_type': 'clinical chemistry',
#    'technology_type': 'marker panel',
#    'workflow': [['sample preparation', {'#replicates': {'value': 1}}],
#     ['raw_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [False, True],
#     'Arm_1': [False, True],
#     'Arm_2': [False, True],
#     'Arm_3': [False, True],
#     'Arm_4': [False, True],
#     'Arm_5': [False, True]},
#    'selectedSampleTypes': {'Arm_0': [['blood'], ['blood']],
#     'Arm_1': [['blood'], ['blood']],
#     'Arm_2': [['blood'], ['blood']],
#     'Arm_3': [['blood'], ['blood']],
#     'Arm_4': [['blood'], ['blood']],
#     'Arm_5': [['blood'], ['blood']]}}],
#  'subjectType': 'Homo sapiens',
#  'subjectSize': 100,
#  'designType': {'term': 'observational design',
#   'id': 'NCIT:C147138',
#   'iri': 'http://purl.obolibrary.org/obo/NCIT_C147138',
#   'label': 'Study subjects do not receive treatments',
#   'value': 'observational'},
#  'elements': [{'_id': '60648e78f3eccab7f53da5a7',
#    'id': '5de2c40f-9320-422f-8fc8-b1bb80ba5adf',
#    'name': 'observation period',
#    'duration': 90,
#    'durationUnit': 'days'},
#   {'_id': '60648e78f3eccab7f53da5a8',
#    'id': '007d1ff8-5e16-401c-b847-5eaf6ba61436',
#    'name': 'follow-up',
#    'duration': 180,
#    'durationUnit': 'days'}],
#  'events': [],
#  '_id': '60648e78f3eccab7f53da5a4',
#  'name': "Student's study v2",
#  'description': 'In an observational study, the investigator simply records observations and analyzes data, without administration of an intervention or alteration of the care people receive. These studies may focus on risk factors, natural history, variations in disease progression or disease treatment without delivering an intervention. They often assess specific health characteristics of the enrolled human subjects by collecting medical/dental history, exposure, or clinical data; obtaining biospecimens (e.g., for biomarker or genomic analyses); or obtaining photographic, radiographic or other images from research subjects.',
#  'identifier': 's_dbd4a1e5-35d8-4c6c-aa8b-60c86f3388a7'}

# %% [markdown]
# ## 3. Generate the ISA Study Design from the JSON configuration
# To perform the conversion we just need to use the function `generate_isa_study_design()` (name possibly subject to change, should we drop the "isa" and "datascriptor" qualifiers?)

# %%
study_design = generate_study_design(study_design_config)
assert isinstance(study_design, StudyDesign)

# %% [markdown]
# ## 4. Generate the ISA Study from the StudyDesign and embed it into an ISA Investigation
#
# The `StudyDesign.generate_isa_study()` method returns the complete ISA-API `Study` object.

# %%
start = time()
study = study_design.generate_isa_study()
end = time()
print('The generation of the study from the design took {:.2f} s.'.format(end - start))
assert isinstance(study, Study)
investigation = Investigation(identifier='inv01', studies=[study])
# Out:
# The generation of the study from the design took 3.56 s.

# %% [markdown]
# ## 5. Serialize and save the JSON representation of the generated ISA Investigation

# %%
start = time()
inv_json = json.dumps(investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
end = time()
print('The JSON serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The JSON serialisation of the ISA investigation took 2.21 s.

# %%
directory = os.path.abspath(os.path.join('output', 'observational-design-students'))
os.makedirs(directory, exist_ok=True)
with open(os.path.abspath(os.path.join(directory, 'isa-investigation-observational-design-students.json')), 'w') as out_fp:
    json.dump(json.loads(inv_json), out_fp)

# %% [markdown]
# ## 6. Dump the ISA Investigation to ISA-Tab

# %%
start = time()
isatab.dump(investigation, directory)
end = time()
print('The Tab serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The Tab serialisation of the ISA investigation took 123.83 s.

# %% [markdown]
# To use them on the notebook we can also dump the tables to pandas DataFrames, using the `dump_tables_to_dataframes` function rather than dump

# %%
dataframes = isatab.dump_tables_to_dataframes(investigation)

# %%
len(dataframes)
# Out:
# 3

# %% [markdown]
# ## 7. Check the correctness of the ISA-Tab DataFrames
#
# We have 1 study file and 2 assay files (one for MS and one for NMR). Let's check the names:

# %%
for key in dataframes.keys():
    display(key)
# Out:
# 's_study_01.txt'
# 'a_AT10_clinical-chemistry_marker-panel.txt'
# 'a_AT8_genome-sequencing_nucleic-acid-sequencing.txt'

# %% [markdown]
# ### 7.1 Count of subjects and samples
#
# We have 10 subjects in the each of the six arms for a total of 60 subjects. 5 blood samples per subject are collected (1 in treatment 1 phase, 1 in treatment, and 3 in the follow-up phase) for a total of 300 blood samples. These will undergo the NMR assay. We have 4 saliva samples per subject (1 during screen and 3 during follow-up) for a total of 240 saliva samples. These will undergo the "mass spcetrometry" assay.

# %%
study_frame = dataframes['s_study_01.txt']
count_arm0_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP0' in el)])
count_arm1_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP1' in el)])
count_arm3_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP3' in el)])
print("There are {} samples in the GRP0 arm (i.e. group)".format(count_arm0_samples))
print("There are {} samples in the GRP1 arm (i.e. group)".format(count_arm1_samples))
print("There are {} samples in the GRP2 arm (i.e. group)".format(count_arm2_samples))
print("There are {} samples in the GRP3 arm (i.e. group)".format(count_arm3_samples))
# Out:
# There are 900 samples in the GRP0 arm (i.e. group)
# There are 900 samples in the GRP1 arm (i.e. group)
# There are 900 samples in the GRP2 arm (i.e. group)
# There are 900 samples in the GRP3 arm (i.e. group)

# %%
study_frame
# Out:
#       Source Name Characteristics[Study Subject] Characteristics[age group]  \
# 0     GRP0_SBJ001                   Homo sapiens                      15-18
# 1     GRP0_SBJ001                   Homo sapiens                      15-18
# 2     GRP0_SBJ001                   Homo sapiens                      15-18
# 3     GRP0_SBJ001                   Homo sapiens                      15-18
# 4     GRP0_SBJ001                   Homo sapiens                      15-18
# ...           ...                            ...                        ...
# 5395  GRP5_SBJ100                   Homo sapiens                       6-10
# 5396  GRP5_SBJ100                   Homo sapiens                       6-10
# 5397  GRP5_SBJ100                   Homo sapiens                       6-10
# 5398  GRP5_SBJ100                   Homo sapiens                       6-10
# 5399  GRP5_SBJ100                   Homo sapiens                       6-10
#
#      Characteristics[sex]       Protocol REF Parameter Value[Sampling order]  \
# 0                       M  sample collection                             769
# 1                       M  sample collection                             237
# 2                       M  sample collection                             235
# 3                       M  sample collection                             772
# 4                       M  sample collection                             773
# ...                   ...                ...                             ...
# 5395                    F  sample collection                            4891
# 5396                    F  sample collection                            4896
# 5397                    F  sample collection                            4893
# 5398                    F  sample collection                            4546
# 5399                    F  sample collection                            4892
#
#      Parameter Value[Study cell]        Date Performer  \
# 0                           A0E1  2021-03-31   Unknown
# 1                           A0E0  2021-03-31   Unknown
# 2                           A0E0  2021-03-31   Unknown
# 3                           A0E1  2021-03-31   Unknown
# 4                           A0E1  2021-03-31   Unknown
# ...                          ...         ...       ...
# 5395                        A5E1  2021-03-31   Unknown
# 5396                        A5E1  2021-03-31   Unknown
# 5397                        A5E1  2021-03-31   Unknown
# 5398                        A5E0  2021-03-31   Unknown
# 5399                        A5E1  2021-03-31   Unknown
#
#                        Sample Name Characteristics[organism part]  \
# 0     GRP0_SBJ001_A0E1_SMP-blood-1                          blood
# 1     GRP0_SBJ001_A0E0_SMP-blood-3                          blood
# 2     GRP0_SBJ001_A0E0_SMP-blood-1                          blood
# 3     GRP0_SBJ001_A0E1_SMP-blood-4                          blood
# 4     GRP0_SBJ001_A0E1_SMP-blood-5                          blood
# ...                            ...                            ...
# 5395  GRP5_SBJ100_A5E1_SMP-blood-1                          blood
# 5396  GRP5_SBJ100_A5E1_SMP-blood-6                          blood
# 5397  GRP5_SBJ100_A5E1_SMP-blood-3                          blood
# 5398  GRP5_SBJ100_A5E0_SMP-blood-1                          blood
# 5399  GRP5_SBJ100_A5E1_SMP-blood-2                          blood
#
#      Comment[Treatment?] Factor Value[Sequence Order] Factor Value[DURATION]  \
# 0                     NO                            1                    180
# 1                     NO                            0                     90
# 2                     NO                            0                     90
# 3                     NO                            1                    180
# 4                     NO                            1                    180
# ...                  ...                          ...                    ...
# 5395                  NO                            1                    180
# 5396                  NO                            1                    180
# 5397                  NO                            1                    180
# 5398                  NO                            0                     90
# 5399                  NO                            1                    180
#
#       Unit
# 0     days
# 1     days
# 2     days
# 3     days
# 4     days
# ...    ...
# 5395  days
# 5396  days
# 5397  days
# 5398  days
# 5399  days
#
# [5400 rows x 15 columns]

# %%
dataframes['a_AT10_clinical-chemistry_marker-panel.txt']
# Out:
#                        Sample Name Comment[Treatment?]        Protocol REF  \
# 0     GRP0_SBJ001_A0E1_SMP-blood-1                  NO  sample preparation
# 1     GRP0_SBJ001_A0E1_SMP-blood-2                  NO  sample preparation
# 2     GRP0_SBJ001_A0E1_SMP-blood-3                  NO  sample preparation
# 3     GRP0_SBJ001_A0E1_SMP-blood-4                  NO  sample preparation
# 4     GRP0_SBJ001_A0E1_SMP-blood-5                  NO  sample preparation
# ...                            ...                 ...                 ...
# 3595  GRP5_SBJ100_A5E1_SMP-blood-2                  NO  sample preparation
# 3596  GRP5_SBJ100_A5E1_SMP-blood-3                  NO  sample preparation
# 3597  GRP5_SBJ100_A5E1_SMP-blood-4                  NO  sample preparation
# 3598  GRP5_SBJ100_A5E1_SMP-blood-5                  NO  sample preparation
# 3599  GRP5_SBJ100_A5E1_SMP-blood-6                  NO  sample preparation
#
#      Performer                Raw Data File
# 0      Unknown   AT10-S469-raw_data_file-R1
# 1      Unknown   AT10-S470-raw_data_file-R1
# 2      Unknown   AT10-S471-raw_data_file-R1
# 3      Unknown   AT10-S472-raw_data_file-R1
# 4      Unknown   AT10-S473-raw_data_file-R1
# ...        ...                          ...
# 3595   Unknown  AT10-S3092-raw_data_file-R1
# 3596   Unknown  AT10-S3093-raw_data_file-R1
# 3597   Unknown  AT10-S3094-raw_data_file-R1
# 3598   Unknown  AT10-S3095-raw_data_file-R1
# 3599   Unknown  AT10-S3096-raw_data_file-R1
#
# [3600 rows x 5 columns]

# %%
dataframes['a_AT8_genome-sequencing_nucleic-acid-sequencing.txt']
# Out:
#                        Sample Name Comment[Treatment?] Protocol REF Performer  \
# 0     GRP0_SBJ001_A0E0_SMP-blood-1                  NO   extraction   Unknown
# 1     GRP0_SBJ001_A0E0_SMP-blood-1                  NO   extraction   Unknown
# 2     GRP0_SBJ001_A0E0_SMP-blood-1                  NO   extraction   Unknown
# 3     GRP0_SBJ001_A0E0_SMP-blood-1                  NO   extraction   Unknown
# 4     GRP0_SBJ001_A0E0_SMP-blood-2                  NO   extraction   Unknown
# ...                            ...                 ...          ...       ...
# 7195  GRP5_SBJ100_A5E0_SMP-blood-2                  NO   extraction   Unknown
# 7196  GRP5_SBJ100_A5E0_SMP-blood-3                  NO   extraction   Unknown
# 7197  GRP5_SBJ100_A5E0_SMP-blood-3                  NO   extraction   Unknown
# 7198  GRP5_SBJ100_A5E0_SMP-blood-3                  NO   extraction   Unknown
# 7199  GRP5_SBJ100_A5E0_SMP-blood-3                  NO   extraction   Unknown
#
#               Extract Name Characteristics[extract type]       Protocol REF.1  \
# 0      AT8-S235-Extract-R1                           DNA  library_preparation
# 1      AT8-S235-Extract-R1                           DNA  library_preparation
# 2      AT8-S235-Extract-R1                           DNA  library_preparation
# 3      AT8-S235-Extract-R1                           DNA  library_preparation
# 4      AT8-S236-Extract-R1                           DNA  library_preparation
# ...                    ...                           ...                  ...
# 7195  AT8-S1547-Extract-R1                           DNA  library_preparation
# 7196  AT8-S1548-Extract-R1                           DNA  library_preparation
# 7197  AT8-S1548-Extract-R1                           DNA  library_preparation
# 7198  AT8-S1548-Extract-R1                           DNA  library_preparation
# 7199  AT8-S1548-Extract-R1                           DNA  library_preparation
#
#      Parameter Value[instrument] Parameter Value[library_orientation]  \
# 0          Illumina NovaSeq 6000                               single
# 1          Illumina NovaSeq 6000                               paired
# 2          Illumina NovaSeq 6000                               paired
# 3          Illumina NovaSeq 6000                               single
# 4          Illumina NovaSeq 6000                               single
# ...                          ...                                  ...
# 7195       Illumina NovaSeq 6000                               single
# 7196       Illumina NovaSeq 6000                               paired
# 7197       Illumina NovaSeq 6000                               single
# 7198       Illumina NovaSeq 6000                               single
# 7199       Illumina NovaSeq 6000                               paired
#
#      Parameter Value[library_strategy] Performer.1  \
# 0                                  WGA     Unknown
# 1                                  WGA     Unknown
# 2                                  WGA     Unknown
# 3                                  WGA     Unknown
# 4                                  WGA     Unknown
# ...                                ...         ...
# 7195                               WGA     Unknown
# 7196                               WGA     Unknown
# 7197                               WGA     Unknown
# 7198                               WGA     Unknown
# 7199                               WGA     Unknown
#
#                        Raw Data File
# 0      AT8-S235-raw_data_file-R3.raw
# 1      AT8-S235-raw_data_file-R1.raw
# 2      AT8-S235-raw_data_file-R2.raw
# 3      AT8-S235-raw_data_file-R4.raw
# 4      AT8-S236-raw_data_file-R3.raw
# ...                              ...
# 7195  AT8-S1547-raw_data_file-R4.raw
# 7196  AT8-S1548-raw_data_file-R2.raw
# 7197  AT8-S1548-raw_data_file-R4.raw
# 7198  AT8-S1548-raw_data_file-R3.raw
# 7199  AT8-S1548-raw_data_file-R1.raw
#
# [7200 rows x 12 columns]

# %% [markdown]
# ### Overview of the Clinical Chemistry Marker Panel
#
# For the mass. spec. assay table, we have 160 (derma) samples, 160 extracts (1 per  sample, "polar" fraction), 320 labeled extracts (2 per extract, as "#replicates" is  2) and 640 mass spec protocols + 640 output files (2 per labeled extract as we do 1 technical replicate with 2 protocol parameter combinations `["Agilent QTQF 6510", "FIA", "positive mode"]` and `["Agilent QTQF 6510", "LC", "positive mode"]`).

# %%
dataframes['a_AT8_genome-sequencing_nucleic-acid-sequencing.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                             1800
# Comment[Treatment?]                        1
# Protocol REF                               1
# Performer                                  1
# Extract Name                            1800
# Characteristics[extract type]              1
# Protocol REF.1                             1
# Parameter Value[instrument]                1
# Parameter Value[library_orientation]       2
# Parameter Value[library_strategy]          1
# Performer.1                                1
# Raw Data File                           7200
# dtype: int64

# %% [markdown]
# ### Overview of the Genome Sequencing assay table
#
# For the NMR assay table, we have 360 (blood) samples, 720 extracts (2 per  sample, a single replicate of the "supernatant" and "pellet" fractions) and 2880 NMR protocols + 4800 output files (4 per extract as we do 2 technical replicates with 2 protocol parameter combinations `["Bruker Avance II 1 GHz", "1D 1H NMR", "CPGM"]` and `["Bruker Avance II 1 GHz", "1D 1H NMR", "TOCSY"]`).

# %%
dataframes['a_AT8_genome-sequencing_nucleic-acid-sequencing.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                             1800
# Comment[Treatment?]                        1
# Protocol REF                               1
# Performer                                  1
# Extract Name                            1800
# Characteristics[extract type]              1
# Protocol REF.1                             1
# Parameter Value[instrument]                1
# Parameter Value[library_orientation]       2
# Parameter Value[library_strategy]          1
# Performer.1                                1
# Raw Data File                           7200
# dtype: int64
