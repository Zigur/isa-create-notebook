# %% [markdown]
# # Create ISA-API Investigation from Datascriptor Study Design configuration
# # Factorial Study on Painkillers in Humans
#
# In this notebook I will show you how you can use a study design configuration is JSON format as produce by datascriptor (https://gitlab.com/datascriptor/datascriptor) to generate a single-study ISA investigation and how you can then serialise it in JSON and tabular (i.e. CSV) format.
#
# Or study design configuration consists of:
# - a 6-arm study design. Each arm has 10 subjects
# - subjects are humans divided in two groups: <50 years, and 50+ years
# - a single-treatment factorial design. Three drugs are being supplied (painkillers: tramadol, acetaminophen, oxycodone) at three different dosages (5, 10, 15 mg/day)), for three different durations (20, 30, 40 days)
# - a follow-up phase after treatment
# - two sample types colllected: adipose tissue, blood
# - two assay types:
#     - NMR for adipose tissue
#     - cell counting for blood samples

# %% [markdown]
# ## 1. Setup
#
# Let's import all the required libraries

# %%
from time import time
import os
import json

# %%
## ISA-API related imports
from isatools.model import Investigation, Study

# %%
## ISA-API create mode related imports
from isatools.create.model import StudyDesign
from isatools.create.connectors import generate_study_design

# serializer from ISA Investigation to JSON
from isatools.isajson import ISAJSONEncoder

# ISA-Tab serialisation
from isatools import isatab

# %%
## ISA-API create mode related imports
from isatools.create import model
from isatools import isajson

# %% [markdown]
# ## 2. Load the Study Design JSON configuration
#
# First of all we load the study design configurator with all the specs defined above

# %%
with open(os.path.abspath(os.path.join(
    "config", "painkillers-factorial-study-design.json"
)), "r") as config_file:
    study_design_config = json.load(config_file)
study_design_config
# Out:
# {'name': 'Factorial Study on 3 Painkillers',
#  'description': 'Example of a 3x3x3  factorial design.  We have human subjects with two age groups (>50 years, 50+ years). Three drugs are being supplied (painkillers: tramadol, acetaminophen, oxycodone) at three different dosages (5, 10, 15 mg/day)), for three different durations (20, 30, 40 days). Only 6  study groups (i.e. arms) are extracted from the full factorial study design. Two sample types are collected: adipose tissue and blood sample. The first one undergoes an NMR assay, while cell counting with cytofluorimetry is run on the blood sample cells.',
#  'subjectType': 'Homo sapiens',
#  'subjectSize': 8,
#  'designType': {'term': 'full factorial design',
#   'id': 'STATO:0000270',
#   'iri': 'http://purl.obolibrary.org/obo/STATO_0000270',
#   'label': 'Study subjects receive a single treatment',
#   'value': 'fullFactorial'},
#  'observationalFactors': [{'name': 'age group',
#    'values': ['<50', '50+'],
#    'isQuantitative': True,
#    'unit': 'years'}],
#  'subjectGroups': {'selected': [{'name': 'SubjectGroup_0',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}]},
#    {'name': 'SubjectGroup_1',
#     'type': 'Homo sapiens',
#     'characteristics': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}]}],
#   'unselected': []},
#  'treatmentPlan': {'screen': {'selected': False,
#    'name': 'screen',
#    'duration': None,
#    'durationUnit': ''},
#   'runIn': {'selected': False,
#    'name': 'run-in',
#    'duration': None,
#    'durationUnit': ''},
#   'washout': {'selected': False,
#    'name': 'washout',
#    'duration': None,
#    'durationUnit': ''},
#   'followUp': {'selected': True,
#    'name': 'follow-up',
#    'duration': 60,
#    'durationUnit': 'days'},
#   'treatments': [{'interventionType': None,
#     'agent': None,
#     'intensity': None,
#     'intensityUnit': '',
#     'duration': None,
#     'durationUnit': ''},
#    {'interventionType': None,
#     'agent': None,
#     'intensity': None,
#     'intensityUnit': '',
#     'duration': None,
#     'durationUnit': ''}],
#   'elementParams': {'interventionType': {'id': 'ero:class:http://purl.obolibrary.org/obo/ERO_0000600',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600',
#     'short_form': 'ERO_0000600',
#     'obo_id': 'ERO:0000600',
#     'label': 'drug intervention',
#     'ontology_name': 'ero',
#     'ontology_prefix': 'ERO',
#     'type': 'class'},
#    'agents': ['tramadol', 'acetaminophen', 'oxycodone'],
#    'intensities': [5, 10, 15],
#    'intensityUnit': 'mg/day',
#    'durations': [20, 30, 40],
#    'durationUnit': 'days'}},
#  'elements': [{'id': '7747a6ff-9237-4ac7-a73a-7a313dae1c98',
#    'name': 'treatment_0',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': '27abab7a-a974-4337-a1be-a079333ec0db',
#    'name': 'follow-up',
#    'duration': 20,
#    'durationUnit': 'days'},
#   {'id': 1,
#    'name': 'treatment_1',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 2,
#    'name': 'treatment_2',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 3,
#    'name': 'treatment_3',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 4,
#    'name': 'treatment_4',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 5,
#    'name': 'treatment_5',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 6,
#    'name': 'treatment_6',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 7,
#    'name': 'treatment_7',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 8,
#    'name': 'treatment_8',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'tramadol',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 9,
#    'name': 'treatment_9',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 10,
#    'name': 'treatment_10',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 11,
#    'name': 'treatment_11',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 12,
#    'name': 'treatment_12',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 13,
#    'name': 'treatment_13',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 14,
#    'name': 'treatment_14',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 15,
#    'name': 'treatment_15',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 16,
#    'name': 'treatment_16',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 17,
#    'name': 'treatment_17',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'acetaminophen',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 18,
#    'name': 'treatment_18',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 19,
#    'name': 'treatment_19',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 20,
#    'name': 'treatment_20',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 15,
#    'intensityUnit': 'mg/day'},
#   {'id': 21,
#    'name': 'treatment_21',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 22,
#    'name': 'treatment_22',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 23,
#    'name': 'treatment_23',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 10,
#    'intensityUnit': 'mg/day'},
#   {'id': 24,
#    'name': 'treatment_24',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 20,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 25,
#    'name': 'treatment_25',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 30,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'},
#   {'id': 26,
#    'name': 'treatment_26',
#    'interventionType': {'term': 'drug intervention',
#     'iri': 'http://purl.obolibrary.org/obo/ERO_0000600'},
#    'duration': 40,
#    'durationUnit': 'days',
#    'agent': 'oxycodone',
#    'intensity': 5,
#    'intensityUnit': 'mg/day'}],
#  'arms': {'selected': [{'id': 0,
#     'name': 'Arm_0',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': ['7747a6ff-9237-4ac7-a73a-7a313dae1c98'],
#       'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 12,
#     'name': 'Arm_12',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [12], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 24,
#     'name': 'Arm_24',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [24], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 38,
#     'name': 'Arm_38',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [11], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 49,
#     'name': 'Arm_49',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [22], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 29,
#     'name': 'Arm_29',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [2], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]}],
#   'unselected': [{'id': 48,
#     'name': 'Arm_48',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [21], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 6,
#     'name': 'Arm_6',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [6], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 1,
#     'name': 'Arm_1',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [1], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 2,
#     'name': 'Arm_2',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [2], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 3,
#     'name': 'Arm_3',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [3], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 4,
#     'name': 'Arm_4',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [4], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 5,
#     'name': 'Arm_5',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [5], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 7,
#     'name': 'Arm_7',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [7], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 8,
#     'name': 'Arm_8',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [8], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 9,
#     'name': 'Arm_9',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [9], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 10,
#     'name': 'Arm_10',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [10], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 11,
#     'name': 'Arm_11',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [11], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 13,
#     'name': 'Arm_13',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [13], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 14,
#     'name': 'Arm_14',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [14], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 15,
#     'name': 'Arm_15',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [15], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 16,
#     'name': 'Arm_16',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [16], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 17,
#     'name': 'Arm_17',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [17], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 18,
#     'name': 'Arm_18',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [18], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 19,
#     'name': 'Arm_19',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [19], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 20,
#     'name': 'Arm_20',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [20], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 21,
#     'name': 'Arm_21',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [21], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 22,
#     'name': 'Arm_22',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [22], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 23,
#     'name': 'Arm_23',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [23], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 25,
#     'name': 'Arm_25',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [25], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 26,
#     'name': 'Arm_26',
#     'observationalFactors': [{'name': 'age group',
#       'value': '<50',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [26], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 27,
#     'name': 'Arm_27',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': ['7747a6ff-9237-4ac7-a73a-7a313dae1c98'],
#       'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 28,
#     'name': 'Arm_28',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [1], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 30,
#     'name': 'Arm_30',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [3], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 31,
#     'name': 'Arm_31',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [4], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 32,
#     'name': 'Arm_32',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [5], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 33,
#     'name': 'Arm_33',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [6], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 34,
#     'name': 'Arm_34',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [7], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 35,
#     'name': 'Arm_35',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [8], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 36,
#     'name': 'Arm_36',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [9], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 37,
#     'name': 'Arm_37',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [10], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 39,
#     'name': 'Arm_39',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [12], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 40,
#     'name': 'Arm_40',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [13], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 41,
#     'name': 'Arm_41',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [14], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 42,
#     'name': 'Arm_42',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [15], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 43,
#     'name': 'Arm_43',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [16], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 44,
#     'name': 'Arm_44',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [17], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 45,
#     'name': 'Arm_45',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [18], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 46,
#     'name': 'Arm_46',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [19], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 47,
#     'name': 'Arm_47',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [20], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 50,
#     'name': 'Arm_50',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [23], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 51,
#     'name': 'Arm_51',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [24], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 52,
#     'name': 'Arm_52',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [25], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]},
#    {'id': 53,
#     'name': 'Arm_53',
#     'observationalFactors': [{'name': 'age group',
#       'value': '50+',
#       'unit': 'years',
#       'isQuantitative': True}],
#     'size': 8,
#     'epochs': [{'elements': [26], 'events': []},
#      {'elements': ['27abab7a-a974-4337-a1be-a079333ec0db'], 'events': []}]}]},
#  'samplePlan': [{'sampleType': 'Adipose Tissue',
#    'selectedCells': {'Arm_0': [True, False],
#     'Arm_12': [True, False],
#     'Arm_24': [True, False],
#     'Arm_38': [True, False],
#     'Arm_49': [True, False],
#     'Arm_29': [True, False]},
#    'sampleTypeSizes': {'Arm_0': [1, None],
#     'Arm_12': [1, None],
#     'Arm_24': [1, None],
#     'Arm_38': [1, None],
#     'Arm_49': [1, None],
#     'Arm_29': [1, None]}},
#   {'sampleType': 'Blood Sample',
#    'selectedCells': {'Arm_0': [True, True],
#     'Arm_12': [True, True],
#     'Arm_24': [True, True],
#     'Arm_38': [True, True],
#     'Arm_49': [True, True],
#     'Arm_29': [True, True]},
#    'sampleTypeSizes': {'Arm_0': [1, 2],
#     'Arm_12': [1, 2],
#     'Arm_24': [1, 2],
#     'Arm_38': [1, 2],
#     'Arm_49': [1, 2],
#     'Arm_29': [1, 2]}}],
#  'assayPlan': [{'id': 2,
#    'name': 'metabolite profiling using NMR spectroscopy',
#    'icon': 'fas fa-atom',
#    'color': 'orange',
#    'measurement_type': 'metabolite profiling',
#    'technology_type': 'NMR spectroscopy',
#    'workflow': [['extraction', {'#replicates': {'value': 1}}],
#     ['extract',
#      {'node_type': 'extract',
#       'characteristics_category': 'extract type',
#       'characteristics_value': {'options': ['supernatant', 'pellet'],
#        'values': ['supernatant', 'pellet']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['nmr_spectroscopy',
#      {'#replicates': {'value': 1},
#       'instrument': {'options': ['Bruker Avance II 1 GHz'],
#        'values': ['Bruker Avance II 1 GHz']},
#       'acquisition_mode': {'options': ['1D 13C NMR',
#         '1D 1H NMR',
#         '2D 13C-13C NMR'],
#        'values': ['1D 1H NMR']},
#       'pulse_sequence': {'options': ['CPMG', 'TOCSY', 'HOESY', 'watergate'],
#        'values': ['watergate', 'TOCSY']}}],
#     ['raw_spectral_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [True, False],
#     'Arm_12': [True, False],
#     'Arm_24': [True, False],
#     'Arm_38': [True, False],
#     'Arm_49': [True, False],
#     'Arm_29': [True, False]},
#    'selectedSampleTypes': {'Arm_0': [['Adipose Tissue'], ['Blood Sample']],
#     'Arm_12': [['Adipose Tissue'], ['Blood Sample']],
#     'Arm_24': [['Adipose Tissue'], ['Blood Sample']],
#     'Arm_38': [['Adipose Tissue'], ['Blood Sample']],
#     'Arm_49': [['Adipose Tissue'], ['Blood Sample']],
#     'Arm_29': [['Adipose Tissue'], ['Blood Sample']]}},
#   {'id': 15,
#    'name': 'cell counting using flow cytometry',
#    'icon': 'fa fa-filter',
#    'color': 'orange',
#    'measurement_type': 'cell counting',
#    'technology_type': 'flow cytometry',
#    'workflow': [[{'term': 'labeling',
#       'iri': 'http://purl.obolibrary.org/obo/CHMO_0001675',
#       'source': None},
#      {'#replicates': {'value': 1}}],
#     [{'term': 'labeled extract',
#       'iri': 'http://purl.obolibrary.org/obo/OBI_0000924',
#       'source': None},
#      {'node_type': 'labeled extract',
#       'characteristics_category': {'term': 'labeled extract type',
#        'iri': None,
#        'source': None},
#       'characteristics_value': {'options': ['Biotin', 'Cy-3', 'Cy-5'],
#        'values': ['Biotin', 'Cy-3']},
#       'is_input_to_next_protocols': {'value': True}}],
#     ['data collection',
#      {'#replicates': {'value': 1},
#       'instrument': {'options': ['Becton Dickinson',
#         'Beckman Coulter',
#         'Other'],
#        'values': ['Beckman Coulter']},
#       'optical_path': {'options': ['', 'NA'], 'values': ['NA']},
#       'detector voltage': {'options': ['', 'NA'], 'values': ['NA']}}],
#     ['raw_data_file',
#      {'node_type': 'data file',
#       'size': 1,
#       'is_input_to_next_protocols': {'value': False}}]],
#    'selectedCells': {'Arm_0': [True, True],
#     'Arm_12': [True, True],
#     'Arm_24': [True, True],
#     'Arm_38': [True, True],
#     'Arm_49': [True, True],
#     'Arm_29': [True, True]},
#    'selectedSampleTypes': {'Arm_0': [['Blood Sample'], ['Blood Sample']],
#     'Arm_12': [['Blood Sample'], ['Blood Sample']],
#     'Arm_24': [['Blood Sample'], ['Blood Sample']],
#     'Arm_38': [['Blood Sample'], ['Blood Sample']],
#     'Arm_49': [['Blood Sample'], ['Blood Sample']],
#     'Arm_29': [['Blood Sample'], ['Blood Sample']]}}]}

# %% [markdown]
# ## 3. Generate the ISA Study Design from the JSON configuration
# To perform the conversion we just need to use the function `generate_isa_study_design()` (name possibly subject to change, should we drop the "isa" and "datascriptor" qualifiers?)

# %%
study_design = generate_study_design(study_design_config)
assert isinstance(study_design, StudyDesign)

# %% [markdown]
# ## 4. Generate the ISA Study from the StudyDesign and embed it into an ISA Investigation
#
# The `StudyDesign.generate_isa_study()` method returns the complete ISA-API `Study` object.

# %%
start = time()
study = study_design.generate_isa_study()
end = time()
print('The generation of the study design took {:.2f} s.'.format(end - start))
assert isinstance(study, Study)
investigation = Investigation(identifier='inv01', studies=[study])
# Out:
# The generation of the study design took 0.47 s.

# %% [markdown]
# ## 5. Serialize and save the JSON representation of the generated ISA Investigation

# %%
start = time()
inv_json = json.dumps(investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
end = time()
print('The JSON serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The JSON serialisation of the ISA investigation took 0.12 s.

# %%
directory = os.path.abspath(os.path.join('output', 'painkillers-factorial-dt'))
os.makedirs(directory, exist_ok=True)
with open(os.path.abspath(os.path.join(directory, 'isa-investigation-painkillers-factorial.json')), 'w') as out_fp:
    json.dump(json.loads(inv_json), out_fp)

# %% [markdown]
# ## 6. Dump the ISA Investigation to ISA-Tab

# %%
start = time()
isatab.dump(investigation, directory)
end = time()
print('The Tab serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The Tab serialisation of the ISA investigation took 4.14 s.

# %% [markdown]
# To use them on the notebook we can also dump the tables to pandas DataFrames, using the `dump_tables_to_dataframes` function rather than dump

# %%
dataframes = isatab.dump_tables_to_dataframes(investigation)

# %%
len(dataframes)
# Out:
# 3

# %% [markdown]
# ## 7. Check the correctness of the ISA-Tab DataFrames
#
# We have 1 study file and 2 assay files (one for MS and one for NMR). Let's check the names:

# %%
for key in dataframes.keys():
    display(key)
# Out:
# 's_study_01.txt'
# 'a_AT15_cell-counting_flow-cytometry.txt'
# 'a_AT2_metabolite-profiling_NMR-spectroscopy.txt'

# %% [markdown]
# ### 7.1 Count of subjects and samples
#
# We have 10 subjects in the each of the six arms for a total of 60 subjects. 5 blood samples per subject are collected (1 in treatment 1 phase, 1 in treatment, and 3 in the follow-up phase) for a total of 300 blood samples. These will undergo the NMR assay. We have 4 saliva samples per subject (1 during screen and 3 during follow-up) for a total of 240 saliva samples. These will undergo the "mass spcetrometry" assay.

# %%
study_frame = dataframes['s_study_01.txt']
count_arm0_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP0' in el)])
count_arm1_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP1' in el)])
count_arm2_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP2' in el)])
count_arm3_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP3' in el)])
print("There are {} samples in the GRP0 arm (i.e. group)".format(count_arm0_samples))
print("There are {} samples in the GRP1 arm (i.e. group)".format(count_arm1_samples))
print("There are {} samples in the GRP2 arm (i.e. group)".format(count_arm2_samples))
print("There are {} samples in the GRP3 arm (i.e. group)".format(count_arm3_samples))
# Out:
# There are 32 samples in the GRP0 arm (i.e. group)
# There are 32 samples in the GRP1 arm (i.e. group)
# There are 64 samples in the GRP2 arm (i.e. group)
# There are 32 samples in the GRP3 arm (i.e. group)

# %%
study_frame
# Out:
#     Source Name Characteristics[Study Subject] Characteristics[age group]  \
# 0     GRP0_SBJ1                   Homo sapiens                        <50
# 1     GRP0_SBJ1                   Homo sapiens                        <50
# 2     GRP0_SBJ1                   Homo sapiens                        <50
# 3     GRP0_SBJ1                   Homo sapiens                        <50
# 4     GRP0_SBJ2                   Homo sapiens                        <50
# ..          ...                            ...                        ...
# 187  GRP49_SBJ7                   Homo sapiens                        50+
# 188  GRP49_SBJ8                   Homo sapiens                        50+
# 189  GRP49_SBJ8                   Homo sapiens                        50+
# 190  GRP49_SBJ8                   Homo sapiens                        50+
# 191  GRP49_SBJ8                   Homo sapiens                        50+
#
#           Protocol REF Parameter Value[run order] Parameter Value[study cell]  \
# 0    sample collection                        013                        A0E0
# 1    sample collection                        025                        A0E1
# 2    sample collection                        026                        A0E1
# 3    sample collection                        005                        A0E0
# 4    sample collection                        012                        A0E0
# ..                 ...                        ...                         ...
# 187  sample collection                        190                        A4E1
# 188  sample collection                        184                        A4E1
# 189  sample collection                        183                        A4E1
# 190  sample collection                        172                        A4E0
# 191  sample collection                        164                        A4E0
#
#            Date Performer                           Sample Name  \
# 0    2021-03-15       Bob     GRP0_SBJ1_A0E0_SMP-Blood-Sample-1
# 1    2021-03-15       Bob     GRP0_SBJ1_A0E1_SMP-Blood-Sample-1
# 2    2021-03-15       Bob     GRP0_SBJ1_A0E1_SMP-Blood-Sample-2
# 3    2021-03-15       Bob   GRP0_SBJ1_A0E0_SMP-Adipose-Tissue-1
# 4    2021-03-15       Bob     GRP0_SBJ2_A0E0_SMP-Blood-Sample-1
# ..          ...       ...                                   ...
# 187  2021-03-15       Bob    GRP49_SBJ7_A4E1_SMP-Blood-Sample-2
# 188  2021-03-15       Bob    GRP49_SBJ8_A4E1_SMP-Blood-Sample-2
# 189  2021-03-15       Bob    GRP49_SBJ8_A4E1_SMP-Blood-Sample-1
# 190  2021-03-15       Bob    GRP49_SBJ8_A4E0_SMP-Blood-Sample-1
# 191  2021-03-15       Bob  GRP49_SBJ8_A4E0_SMP-Adipose-Tissue-1
#
#     Characteristics[organism part] Factor Value[AGENT] Factor Value[DURATION]  \
# 0                     Blood Sample            tramadol                     20
# 1                     Blood Sample                                         20
# 2                     Blood Sample                                         20
# 3                   Adipose Tissue            tramadol                     20
# 4                     Blood Sample            tramadol                     20
# ..                             ...                 ...                    ...
# 187                   Blood Sample                                         20
# 188                   Blood Sample                                         20
# 189                   Blood Sample                                         20
# 190                   Blood Sample           oxycodone                     30
# 191                 Adipose Tissue           oxycodone                     30
#
#      Unit Factor Value[INTENSITY]  Unit.1
# 0    days                    15.0  mg/day
# 1    days
# 2    days
# 3    days                    15.0  mg/day
# 4    days                    15.0  mg/day
# ..    ...                     ...     ...
# 187  days
# 188  days
# 189  days
# 190  days                    10.0  mg/day
# 191  days                    10.0  mg/day
#
# [192 rows x 15 columns]

# %%
dataframes['a_AT15_cell-counting_flow-cytometry.txt']
# Out:
#                             Sample Name Protocol REF Performer  \
# 0     GRP0_SBJ1_A0E0_SMP-Blood-Sample-1     labeling   Unknown
# 1     GRP0_SBJ1_A0E0_SMP-Blood-Sample-1     labeling   Unknown
# 2     GRP0_SBJ1_A0E1_SMP-Blood-Sample-1     labeling   Unknown
# 3     GRP0_SBJ1_A0E1_SMP-Blood-Sample-1     labeling   Unknown
# 4     GRP0_SBJ1_A0E1_SMP-Blood-Sample-2     labeling   Unknown
# ..                                  ...          ...       ...
# 283  GRP49_SBJ8_A4E0_SMP-Blood-Sample-1     labeling   Unknown
# 284  GRP49_SBJ8_A4E1_SMP-Blood-Sample-1     labeling   Unknown
# 285  GRP49_SBJ8_A4E1_SMP-Blood-Sample-1     labeling   Unknown
# 286  GRP49_SBJ8_A4E1_SMP-Blood-Sample-2     labeling   Unknown
# 287  GRP49_SBJ8_A4E1_SMP-Blood-Sample-2     labeling   Unknown
#
#     Labeled Extract Name   Label   Protocol REF.1 Parameter Value[instrument]  \
# 0          AT15-S5-LE-R1  Biotin  data collection             Beckman Coulter
# 1          AT15-S5-LE-R2    Cy-3  data collection             Beckman Coulter
# 2         AT15-S17-LE-R2    Cy-3  data collection             Beckman Coulter
# 3         AT15-S17-LE-R1  Biotin  data collection             Beckman Coulter
# 4         AT15-S18-LE-R2    Cy-3  data collection             Beckman Coulter
# ..                   ...     ...              ...                         ...
# 283      AT15-S124-LE-R1  Biotin  data collection             Beckman Coulter
# 284      AT15-S135-LE-R1  Biotin  data collection             Beckman Coulter
# 285      AT15-S135-LE-R2    Cy-3  data collection             Beckman Coulter
# 286      AT15-S136-LE-R2    Cy-3  data collection             Beckman Coulter
# 287      AT15-S136-LE-R1  Biotin  data collection             Beckman Coulter
#
#     Parameter Value[optical_path] Parameter Value[detector voltage]  \
# 0
# 1
# 2
# 3
# 4
# ..                            ...                               ...
# 283
# 284
# 285
# 286
# 287
#
#                                     Scan Name Performer.1  \
# 0      AT15-S5-data-collection-Acquisition-R1     Unknown
# 1      AT15-S5-data-collection-Acquisition-R2     Unknown
# 2     AT15-S17-data-collection-Acquisition-R2     Unknown
# 3     AT15-S17-data-collection-Acquisition-R1     Unknown
# 4     AT15-S18-data-collection-Acquisition-R2     Unknown
# ..                                        ...         ...
# 283  AT15-S124-data-collection-Acquisition-R1     Unknown
# 284  AT15-S135-data-collection-Acquisition-R1     Unknown
# 285  AT15-S135-data-collection-Acquisition-R2     Unknown
# 286  AT15-S136-data-collection-Acquisition-R2     Unknown
# 287  AT15-S136-data-collection-Acquisition-R1     Unknown
#
#                       Raw Data File
# 0      AT15-S5-raw_data_file-R1.raw
# 1      AT15-S5-raw_data_file-R2.raw
# 2     AT15-S17-raw_data_file-R2.raw
# 3     AT15-S17-raw_data_file-R1.raw
# 4     AT15-S18-raw_data_file-R2.raw
# ..                              ...
# 283  AT15-S124-raw_data_file-R1.raw
# 284  AT15-S135-raw_data_file-R1.raw
# 285  AT15-S135-raw_data_file-R2.raw
# 286  AT15-S136-raw_data_file-R2.raw
# 287  AT15-S136-raw_data_file-R1.raw
#
# [288 rows x 12 columns]

# %%
dataframes['a_AT2_metabolite-profiling_NMR-spectroscopy.txt']
# Out:
#                               Sample Name Protocol REF Performer  \
# 0     GRP0_SBJ1_A0E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 1     GRP0_SBJ1_A0E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 2     GRP0_SBJ1_A0E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 3     GRP0_SBJ1_A0E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 4     GRP0_SBJ2_A0E0_SMP-Adipose-Tissue-1   extraction   Unknown
# ..                                    ...          ...       ...
# 187  GRP49_SBJ7_A4E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 188  GRP49_SBJ8_A4E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 189  GRP49_SBJ8_A4E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 190  GRP49_SBJ8_A4E0_SMP-Adipose-Tissue-1   extraction   Unknown
# 191  GRP49_SBJ8_A4E0_SMP-Adipose-Tissue-1   extraction   Unknown
#
#            Extract Name Characteristics[extract type]    Protocol REF.1  \
# 0     AT2-S5-Extract-R1                   supernatant  nmr_spectroscopy
# 1     AT2-S5-Extract-R2                        pellet  nmr_spectroscopy
# 2     AT2-S5-Extract-R1                   supernatant  nmr_spectroscopy
# 3     AT2-S5-Extract-R2                        pellet  nmr_spectroscopy
# 4     AT2-S4-Extract-R2                        pellet  nmr_spectroscopy
# ..                  ...                           ...               ...
# 187  AT2-S47-Extract-R2                        pellet  nmr_spectroscopy
# 188  AT2-S44-Extract-R2                        pellet  nmr_spectroscopy
# 189  AT2-S44-Extract-R1                   supernatant  nmr_spectroscopy
# 190  AT2-S44-Extract-R2                        pellet  nmr_spectroscopy
# 191  AT2-S44-Extract-R1                   supernatant  nmr_spectroscopy
#
#     Parameter Value[instrument] Parameter Value[acquisition_mode]  \
# 0        Bruker Avance II 1 GHz                         1D 1H NMR
# 1        Bruker Avance II 1 GHz                         1D 1H NMR
# 2        Bruker Avance II 1 GHz                         1D 1H NMR
# 3        Bruker Avance II 1 GHz                         1D 1H NMR
# 4        Bruker Avance II 1 GHz                         1D 1H NMR
# ..                          ...                               ...
# 187      Bruker Avance II 1 GHz                         1D 1H NMR
# 188      Bruker Avance II 1 GHz                         1D 1H NMR
# 189      Bruker Avance II 1 GHz                         1D 1H NMR
# 190      Bruker Avance II 1 GHz                         1D 1H NMR
# 191      Bruker Avance II 1 GHz                         1D 1H NMR
#
#     Parameter Value[pulse_sequence] Performer.1  \
# 0                             TOCSY     Unknown
# 1                         watergate     Unknown
# 2                         watergate     Unknown
# 3                             TOCSY     Unknown
# 4                             TOCSY     Unknown
# ..                              ...         ...
# 187                           TOCSY     Unknown
# 188                       watergate     Unknown
# 189                       watergate     Unknown
# 190                           TOCSY     Unknown
# 191                           TOCSY     Unknown
#
#             Free Induction Decay Data File
# 0     AT2-S5-raw_spectral_data_file-R1.raw
# 1     AT2-S5-raw_spectral_data_file-R4.raw
# 2     AT2-S5-raw_spectral_data_file-R2.raw
# 3     AT2-S5-raw_spectral_data_file-R3.raw
# 4     AT2-S4-raw_spectral_data_file-R3.raw
# ..                                     ...
# 187  AT2-S47-raw_spectral_data_file-R3.raw
# 188  AT2-S44-raw_spectral_data_file-R4.raw
# 189  AT2-S44-raw_spectral_data_file-R2.raw
# 190  AT2-S44-raw_spectral_data_file-R3.raw
# 191  AT2-S44-raw_spectral_data_file-R1.raw
#
# [192 rows x 11 columns]

# %% [markdown]
# ### 7.1 Overview of the Flow Cytometry assay table

# %%
dataframes['a_AT15_cell-counting_flow-cytometry.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                          144
# Protocol REF                           1
# Performer                              1
# Labeled Extract Name                 288
# Label                                  2
# Protocol REF.1                         1
# Parameter Value[instrument]            1
# Parameter Value[optical_path]          1
# Parameter Value[detector voltage]      1
# Scan Name                            288
# Performer.1                            1
# Raw Data File                        288
# dtype: int64

# %% [markdown]
# ### Overview of the NMR assay table

# %%
dataframes['a_AT2_metabolite-profiling_NMR-spectroscopy.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                           48
# Protocol REF                           1
# Performer                              1
# Extract Name                          96
# Characteristics[extract type]          2
# Protocol REF.1                         1
# Parameter Value[instrument]            1
# Parameter Value[acquisition_mode]      1
# Parameter Value[pulse_sequence]        2
# Performer.1                            1
# Free Induction Decay Data File       192
# dtype: int64

# %%
from isatools import isatab
isatab.dump(investigation1, './')

from isatools.isatab import dump_tables_to_dataframes as dumpdf
dataframes = dumpdf(investigation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7c69156f3c5e> in <module>
#       1 from isatools import isatab
# ----> 2 isatab.dump(investigation1, './')
#       3
#       4 from isatools.isatab import dump_tables_to_dataframes as dumpdf
#       5 dataframes = dumpdf(investigation)
#
# NameError: name 'investigation1' is not defined
