# %% [markdown]
# # Create ISA-API Investigation from Datascriptor Study Design configuration
#
# # Factorial Study without observational factors
#
# In this notebook I will show you how you can use a study design configuration is JSON format as produce by datascriptor (https://gitlab.com/datascriptor/datascriptor) to generate a single-study ISA investigation and how you can then serialise it in JSON and tabular (i.e. CSV) format.
#
# Or study design configuration consists of:
# - a 6-arm study design. Each arm has 12 subjects
# - Patients were randomised to one of 4 groups – intravenous streptokinase, oral aspirin, both or neither – and mortality was measured. at three different dosages (5, 10 mg/day)), for three different durations (30, 60 days)
# - a screen phase before treatment (7 days)
# - a follow-up phase after treatment (90 days)
# - two sample types colllected: unspecified tissue, blood
# - two assay types:
#     - Metabolite Profiling with Mass Spectrometry for unspecified tissue
#     - Metabolite Profiling with NMR Spectroscopy for blood sample

# %% [markdown]
# ## 1. Setup
#
# Let's import all the required libraries

# %%
from time import time
import os
import json

# %%
## ISA-API related imports
from isatools.model import Investigation, Study

# %%
## ISA-API create mode related imports
from isatools.create.model import StudyDesign
from isatools.create.connectors import generate_study_design

# serializer from ISA Investigation to JSON
from isatools.isajson import ISAJSONEncoder

# ISA-Tab serialisation
from isatools import isatab

# %%
## ISA-API create mode related imports
from isatools.create import model
from isatools import isajson

# %% [markdown]
# ## 2. Load the Study Design JSON configuration
#
# First of all we load the study design configurator with all the specs defined above

# %%
with open(os.path.abspath(os.path.join(
    "config", "factorial-study-human-4-treatments.json"
)), "r") as config_file:
    study_design_config = json.load(config_file)
study_design_config
# Out:
# {'_id': '60d8b601b832df0008a19abc',
#  'name': '4-treatments factorial study',
#  'description': 'Patients were randomised to one of 4 groups – intravenous streptokinase, oral aspirin, both or neither – and mortality was measured. (Lancet 1988;ii:349-60 )',
#  'design': {'subjectType': {'term': 'Homo sapiens',
#    'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_9606'},
#   'subjectSize': 12,
#   'designType': {'term': 'full factorial design',
#    'id': 'STATO:0000270',
#    'iri': 'http://purl.obolibrary.org/obo/STATO_0000270',
#    'label': 'Study subjects receive a single treatment',
#    'value': 'fullFactorial'},
#   'observationalFactors': [],
#   'subjectGroups': {'selected': [{'name': 'SubjectGroup_0',
#      'type': {'term': 'Homo sapiens',
#       'iri': 'http://purl.obolibrary.org/obo/NCBITaxon_9606'},
#      'characteristics': []}],
#    'unselected': []},
#   'treatmentPlan': {'observationPeriod': {'name': 'observation period',
#     'duration': None,
#     'durationUnit': ''},
#    'screen': {'selected': True,
#     'name': 'screen',
#     'duration': 7,
#     'durationUnit': 'days'},
#    'runIn': {'selected': False,
#     'name': 'run-in',
#     'duration': None,
#     'durationUnit': ''},
#    'washout': {'selected': False,
#     'name': 'washout',
#     'duration': None,
#     'durationUnit': ''},
#    'followUp': {'selected': True,
#     'name': 'follow-up',
#     'duration': 90,
#     'durationUnit': 'days'},
#    'elementParams': {'agents': ['intravenous streptokinase',
#      'oral aspirin',
#      'intravenous streptokinase + oral aspirin',
#      'placebo'],
#     'intensities': [5, 10],
#     'durations': [30, 60],
#     'interventionType': {'id': 'ero:class:http://purl.obolibrary.org/obo/ERO_0000600',
#      'iri': 'http://purl.obolibrary.org/obo/ERO_0000600',
#      'short_form': 'ERO_0000600',
#      'obo_id': 'ERO:0000600',
#      'label': 'drug intervention',
#      'ontology_name': 'ero',
#      'ontology_prefix': 'ERO',
#      'type': 'class'},
#     'intensityUnit': 'mg/day',
#     'durationUnit': 'days'},
#    'treatments': [{'_id': '60d8b601b832df0008a19a90',
#      'interventionType': None,
#      'agent': None,
#      'intensity': None,
#      'intensityUnit': '',
#      'duration': None,
#      'durationUnit': ''},
#     {'_id': '60d8b601b832df0008a19a91',
#      'interventionType': None,
#      'agent': None,
#      'intensity': None,
#      'intensityUnit': '',
#      'duration': None,
#      'durationUnit': ''}]},
#   'elements': [{'_id': '60d8b601b832df0008a19a92',
#     'id': 'a1ee2795-92fa-4c89-99e0-05b7c1159f33',
#     'name': 'screen',
#     'duration': 7,
#     'durationUnit': 'days'},
#    {'_id': '60d8b601b832df0008a19a93',
#     'id': 'f6e66807-ac7b-49ef-93cc-1e250e94ed15',
#     'name': 'treatment_0',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a94',
#     'id': '39dc612f-9a40-4ca1-a798-cdb6cea5b59d',
#     'name': 'follow-up',
#     'duration': 90,
#     'durationUnit': 'days'},
#    {'_id': '60d8b601b832df0008a19a95',
#     'id': '1',
#     'name': 'treatment_1',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a96',
#     'id': '2',
#     'name': 'treatment_2',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a97',
#     'id': '3',
#     'name': 'treatment_3',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a98',
#     'id': '4',
#     'name': 'treatment_4',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'oral aspirin',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a99',
#     'id': '5',
#     'name': 'treatment_5',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'oral aspirin',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9a',
#     'id': '6',
#     'name': 'treatment_6',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'oral aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9b',
#     'id': '7',
#     'name': 'treatment_7',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'oral aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9c',
#     'id': '8',
#     'name': 'treatment_8',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase + oral aspirin',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9d',
#     'id': '9',
#     'name': 'treatment_9',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase + oral aspirin',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9e',
#     'id': '10',
#     'name': 'treatment_10',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase + oral aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19a9f',
#     'id': '11',
#     'name': 'treatment_11',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'intravenous streptokinase + oral aspirin',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19aa0',
#     'id': '12',
#     'name': 'treatment_12',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'placebo',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19aa1',
#     'id': '13',
#     'name': 'treatment_13',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'placebo',
#     'intensity': 10,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19aa2',
#     'id': '14',
#     'name': 'treatment_14',
#     'duration': 30,
#     'durationUnit': 'days',
#     'agent': 'placebo',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'},
#    {'_id': '60d8b601b832df0008a19aa3',
#     'id': '15',
#     'name': 'treatment_15',
#     'duration': 60,
#     'durationUnit': 'days',
#     'agent': 'placebo',
#     'intensity': 5,
#     'intensityUnit': 'mg/day'}],
#   'arms': {'unselected': [{'id': 0,
#      'name': 'Arm_0',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': ['f6e66807-ac7b-49ef-93cc-1e250e94ed15'], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 1,
#      'name': 'Arm_1',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [1], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 3,
#      'name': 'Arm_3',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [3], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 6,
#      'name': 'Arm_6',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [6], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 7,
#      'name': 'Arm_7',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [7], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 8,
#      'name': 'Arm_8',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [8], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 9,
#      'name': 'Arm_9',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [9], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 11,
#      'name': 'Arm_11',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [11], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 14,
#      'name': 'Arm_14',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [14], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]},
#     {'id': 15,
#      'name': 'Arm_15',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        'events': []},
#       {'elements': [15], 'events': []},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'], 'events': []}]}],
#    'selected': [{'_id': '60d8b601b832df0008a19aa4',
#      'id': '2',
#      'name': 'Arm_2',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19aa5'},
#       {'elements': ['2'], '_id': '60d8b601b832df0008a19aa6'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19aa7'}]},
#     {'_id': '60d8b601b832df0008a19aa8',
#      'id': '5',
#      'name': 'Arm_5',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19aa9'},
#       {'elements': ['5'], '_id': '60d8b601b832df0008a19aaa'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19aab'}]},
#     {'_id': '60d8b601b832df0008a19aac',
#      'id': '4',
#      'name': 'Arm_4',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19aad'},
#       {'elements': ['4'], '_id': '60d8b601b832df0008a19aae'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19aaf'}]},
#     {'_id': '60d8b601b832df0008a19ab0',
#      'id': '10',
#      'name': 'Arm_10',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19ab1'},
#       {'elements': ['10'], '_id': '60d8b601b832df0008a19ab2'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19ab3'}]},
#     {'_id': '60d8b601b832df0008a19ab4',
#      'id': '12',
#      'name': 'Arm_12',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19ab5'},
#       {'elements': ['12'], '_id': '60d8b601b832df0008a19ab6'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19ab7'}]},
#     {'_id': '60d8b601b832df0008a19ab8',
#      'id': '13',
#      'name': 'Arm_13',
#      'observationalFactors': [],
#      'size': 12,
#      'epochs': [{'elements': ['a1ee2795-92fa-4c89-99e0-05b7c1159f33'],
#        '_id': '60d8b601b832df0008a19ab9'},
#       {'elements': ['13'], '_id': '60d8b601b832df0008a19aba'},
#       {'elements': ['39dc612f-9a40-4ca1-a798-cdb6cea5b59d'],
#        '_id': '60d8b601b832df0008a19abb'}]}]},
#   'samplePlan': [{'sampleType': {'term': 'Blood Sample',
#      'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'},
#     'selectedCells': {'Arm_2': [True, True, True],
#      'Arm_5': [True, True, True],
#      'Arm_4': [True, True, True],
#      'Arm_10': [True, True, True],
#      'Arm_12': [True, True, True],
#      'Arm_13': [True, True, True]},
#     'sampleTypeSizes': {'Arm_2': [1, 1, 3],
#      'Arm_5': [1, 1, 3],
#      'Arm_4': [1, 1, 3],
#      'Arm_10': [1, 1, 3],
#      'Arm_12': [1, 1, 3],
#      'Arm_13': [1, 1, 3]}},
#    {'sampleType': {'term': 'Unspecified Tissue',
#      'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'},
#     'selectedCells': {'Arm_2': [False, True, False],
#      'Arm_5': [False, True, False],
#      'Arm_4': [False, True, False],
#      'Arm_10': [False, True, False],
#      'Arm_12': [False, True, False],
#      'Arm_13': [False, True, False]},
#     'sampleTypeSizes': {'Arm_2': [None, 1, None],
#      'Arm_5': [None, 1, None],
#      'Arm_4': [None, 1, None],
#      'Arm_10': [None, 1, None],
#      'Arm_12': [None, 1, None],
#      'Arm_13': [None, 1, None]}}],
#   'assayPlan': [{'id': 1,
#     'name': 'metabolite profiling - mass spectrometry (ontology annotated)',
#     'icon': 'fas fa-chart-bar',
#     'color': 'blue',
#     'measurement_type': {'term': 'metabolite profiling',
#      'iri': 'http://purl.obolibrary.org/obo/OBI_0000366',
#      'source': None},
#     'technology_type': {'term': 'mass spectrometry',
#      'iri': 'http://purl.obolibrary.org/obo/OBI_0000470',
#      'source': None},
#     'workflow': [[{'term': 'extraction',
#        'iri': 'http://purl.obolibrary.org/obo/OBI_0302884',
#        'source': None},
#       {'#replicates': {'value': 2}}],
#      [{'term': 'extract', 'iri': 'http://purl.obolibrary.org/obo/OBI_0000423'},
#       {'node_type': 'extract',
#        'characteristics_category': {'term': 'extract type',
#         'iri': 'http://purl.obolibrary.org/obo/OBI_0000423',
#         'source': 'OBI'},
#        'characteristics_value': {'options': [{'term': 'polar fraction',
#           'iri': 'polar fraction',
#           'source': None},
#          {'term': 'lipids', 'iri': 'lipids', 'source': None}],
#         'values': [{'term': 'polar fraction',
#           'iri': 'polar fraction',
#           'source': None},
#          {'term': 'lipids', 'iri': 'lipids', 'source': None}]},
#        'is_input_to_next_protocols': {'value': True}}],
#      [{'term': 'labeling',
#        'iri': 'http://purl.obolibrary.org/obo/CHMO_0001675',
#        'source': None},
#       {'#replicates': {'value': 1}}],
#      [{'term': 'labeled extract',
#        'iri': 'http://purl.obolibrary.org/obo/OBI_0000924',
#        'source': None},
#       {'node_type': 'labeled extract',
#        'characteristics_category': {'term': 'labeled extract type',
#         'iri': 'http://purl.obolibrary.org/obo/OBI_0000924',
#         'source': None},
#        'characteristics_value': {'options': ['label_0', 'label_1'],
#         'values': ['label_0']},
#        'is_input_to_next_protocols': {'value': True}}],
#      [{'term': 'mass spectrometry',
#        'iri': 'http://purl.obolibrary.org/obo/OBI_0200085',
#        'source': None},
#       {'#replicates': {'value': 2},
#        'instrument': {'options': [{'term': 'Agilent QTQF 6510',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1000676',
#           'source': None},
#          {'term': 'Agilent QTQF 6520A',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1000677',
#           'source': None}],
#         'values': [{'term': 'Agilent QTQF 6510',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1000676',
#           'source': None}]},
#        'injection_mode': {'options': [{'term': 'FIA',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1000058',
#           'source': None},
#          {'term': 'LC', 'iri': None, 'source': None}],
#         'values': [{'term': 'FIA',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1000058',
#           'source': None},
#          {'term': 'LC', 'iri': None, 'source': None}]},
#        'acquisition_mode': {'options': [{'term': 'positive mode',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#           'source': None}],
#         'values': [{'term': 'positive mode',
#           'iri': 'http://purl.obolibrary.org/obo/MS_1002807',
#           'source': None}]}}],
#      [{'term': 'raw spectral data file',
#        'iri': 'http://purl.obolibrary.org/obo/MS_1003083',
#        'source': None},
#       {'node_type': 'data file',
#        'is_input_to_next_protocols': {'value': True}}]],
#     '@context': {'measurement_type': 'http://purl.obolibrary.org/obo/NCIT_C25209',
#      'technology_type': 'http://www.ebi.ac.uk/efo/EFO_0005521',
#      'instrument': 'http://purl.obolibrary.org/obo/MS_1000463',
#      'injection_mode': 'http://purl.obolibrary.org/obo/MS_1000007',
#      'acquisition_mode': 'http://purl.obolibrary.org/obo/MS_1000027'},
#     'selectedCells': {'Arm_2': [False, True, False],
#      'Arm_5': [False, True, False],
#      'Arm_4': [False, True, False],
#      'Arm_10': [False, True, False],
#      'Arm_12': [False, True, False],
#      'Arm_13': [False, True, False]},
#     'selectedSampleTypes': {'Arm_2': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_5': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_4': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_10': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_12': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_13': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Unspecified Tissue',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C132256'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]]}},
#    {'id': 2,
#     'name': 'metabolite profiling using NMR spectroscopy',
#     'icon': 'fas fa-atom',
#     'color': 'orange',
#     'measurement_type': 'metabolite profiling',
#     'technology_type': 'NMR spectroscopy',
#     'workflow': [['extraction', {'#replicates': {'value': 2}}],
#      ['extract',
#       {'node_type': 'extract',
#        'characteristics_category': 'extract type',
#        'characteristics_value': {'options': ['supernatant', 'pellet'],
#         'values': ['supernatant', 'pellet']},
#        'is_input_to_next_protocols': {'value': True}}],
#      ['nmr_spectroscopy',
#       {'#replicates': {'value': 1},
#        'instrument': {'options': ['Bruker Avance II 1 GHz'],
#         'values': ['Bruker Avance II 1 GHz']},
#        'acquisition_mode': {'options': ['1D 13C NMR',
#          '1D 1H NMR',
#          '2D 13C-13C NMR'],
#         'values': ['2D 13C-13C NMR']},
#        'pulse_sequence': {'options': ['CPMG', 'TOCSY', 'HOESY', 'watergate'],
#         'values': ['TOCSY', 'watergate']}}],
#      ['raw_spectral_data_file',
#       {'node_type': 'data file',
#        'size': 1,
#        'is_input_to_next_protocols': {'value': False}}]],
#     'selectedCells': {'Arm_2': [True, True, True],
#      'Arm_5': [True, True, True],
#      'Arm_4': [True, True, True],
#      'Arm_10': [True, True, True],
#      'Arm_12': [True, True, True],
#      'Arm_13': [True, True, True]},
#     'selectedSampleTypes': {'Arm_2': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_5': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_4': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_10': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_12': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]],
#      'Arm_13': [[{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}],
#       [{'term': 'Blood Sample',
#         'iri': 'http://purl.obolibrary.org/obo/NCIT_C17610'}]]}}]}}

# %% [markdown]
# ## 3. Generate the ISA Study Design from the JSON configuration
# To perform the conversion we just need to use the function `generate_isa_study_design()` (name possibly subject to change, should we drop the "isa" and "datascriptor" qualifiers?)

# %%
study_design = generate_study_design(study_design_config)
assert isinstance(study_design, StudyDesign)

# %% [markdown]
# ## 4. Generate the ISA Study from the StudyDesign and embed it into an ISA Investigation
#
# The `StudyDesign.generate_isa_study()` method returns the complete ISA-API `Study` object.

# %%
start = time()
study = study_design.generate_isa_study()
end = time()
print('The generation of the study design took {:.2f} s.'.format(end - start))
assert isinstance(study, Study)
investigation = Investigation(identifier='inv01', studies=[study])
# Out:
# The generation of the study design took 3.91 s.

# %% [markdown]
# ## 5. Serialize and save the JSON representation of the generated ISA Investigation

# %%
start = time()
inv_json = json.dumps(investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
end = time()
print('The JSON serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The JSON serialisation of the ISA investigation took 0.96 s.

# %%
directory = os.path.abspath(os.path.join('output', 'factorial-study-human-4-treatments'))
os.makedirs(directory, exist_ok=True)
with open(os.path.abspath(os.path.join(directory, 'isa-investigation-human-factorial.json')), 'w') as out_fp:
    json.dump(json.loads(inv_json), out_fp)

# %% [markdown]
# ## 6. Dump the ISA Investigation to ISA-Tab

# %%
start = time()
isatab.dump(investigation, directory)
end = time()
print('The Tab serialisation of the ISA investigation took {:.2f} s.'.format(end - start))
# Out:
# The Tab serialisation of the ISA investigation took 43.63 s.

# %% [markdown]
# To use them on the notebook we can also dump the tables to pandas DataFrames, using the `dump_tables_to_dataframes` function rather than dump

# %%
dataframes = isatab.dump_tables_to_dataframes(investigation)

# %%
len(dataframes)
# Out:
# 3

# %% [markdown]
# ## 7. Check the correctness of the ISA-Tab DataFrames
#
# We have 1 study file and 2 assay files (one for MS and one for NMR). Let's check the names:

# %%
for key in dataframes.keys():
    display(key)
# Out:
# 's_study_01.txt'
# 'a_AT2_metabolite-profiling_NMR-spectroscopy.txt'
# 'a_AT1_metabolite-profiling_mass-spectrometry.txt'

# %% [markdown]
# ### 7.1 Count of subjects and samples
#
# We have 12 subjects in the each of the six arms for a total of 72 subjects. 5 blood samples per subject are collected (1 in the screen 1 phase, 1 in treatment, and 3 in the follow-up phase) for a total of 60 * 6 blood samples. These will undergo the NMR assay. We have 1 unspecified tissue sample per subject (1 during treatment) for a total of 12 * 6 saliva samples. These will undergo the "mass spcetrometry" assay.

# %%
study_frame = dataframes['s_study_01.txt']
count_arm2_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP2' in el)])
count_arm4_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP4' in el)])
count_arm5_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP5' in el)])
count_arm10_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP10' in el)])
count_arm12_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP12' in el)])
count_arm13_samples = len(study_frame[study_frame['Source Name'].apply(lambda el: 'GRP13' in el)])
print("There are {} samples in the GRP2 arm (i.e. group)".format(count_arm2_samples))
print("There are {} samples in the GRP4 arm (i.e. group)".format(count_arm4_samples))
print("There are {} samples in the GRP5 arm (i.e. group)".format(count_arm5_samples))
print("There are {} samples in the GRP10 arm (i.e. group)".format(count_arm10_samples))
print("There are {} samples in the GRP12 arm (i.e. group)".format(count_arm12_samples))
print("There are {} samples in the GRP13 arm (i.e. group)".format(count_arm13_samples))
# Out:
# There are 72 samples in the GRP2 arm (i.e. group)
# There are 72 samples in the GRP4 arm (i.e. group)
# There are 72 samples in the GRP5 arm (i.e. group)
# There are 72 samples in the GRP10 arm (i.e. group)
# There are 72 samples in the GRP12 arm (i.e. group)
# There are 72 samples in the GRP13 arm (i.e. group)

# %% [markdown]
# ###  Study Table overview

# %%
study_frame
# Out:
#      Source Name Characteristics[Study Subject]  \
# 0    GRP10_SBJ01                   Homo sapiens
# 1    GRP10_SBJ01                   Homo sapiens
# 2    GRP10_SBJ01                   Homo sapiens
# 3    GRP10_SBJ01                   Homo sapiens
# 4    GRP10_SBJ01                   Homo sapiens
# ..           ...                            ...
# 427   GRP5_SBJ12                   Homo sapiens
# 428   GRP5_SBJ12                   Homo sapiens
# 429   GRP5_SBJ12                   Homo sapiens
# 430   GRP5_SBJ12                   Homo sapiens
# 431   GRP5_SBJ12                   Homo sapiens
#
#                              Term Accession Number       Protocol REF  \
# 0    http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 1    http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 2    http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 3    http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 4    http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# ..                                             ...                ...
# 427  http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 428  http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 429  http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 430  http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
# 431  http://purl.obolibrary.org/obo/NCBITaxon_9606  sample collection
#
#     Parameter Value[Sampling order] Parameter Value[Study cell]        Date  \
# 0                               032                        A3E1  2021-07-13
# 1                               060                        A3E2  2021-07-13
# 2                               059                        A3E2  2021-07-13
# 3                               008                        A3E0  2021-07-13
# 4                               058                        A3E2  2021-07-13
# ..                              ...                         ...         ...
# 427                             401                        A1E2  2021-07-13
# 428                             386                        A1E1  2021-07-13
# 429                             374                        A1E1  2021-07-13
# 430                             362                        A1E0  2021-07-13
# 431                             402                        A1E2  2021-07-13
#
#     Performer                               Sample Name  \
# 0     Unknown       GRP10_SBJ01_A3E1_SMP-Blood-Sample-1
# 1     Unknown       GRP10_SBJ01_A3E2_SMP-Blood-Sample-3
# 2     Unknown       GRP10_SBJ01_A3E2_SMP-Blood-Sample-2
# 3     Unknown       GRP10_SBJ01_A3E0_SMP-Blood-Sample-1
# 4     Unknown       GRP10_SBJ01_A3E2_SMP-Blood-Sample-1
# ..        ...                                       ...
# 427   Unknown        GRP5_SBJ12_A1E2_SMP-Blood-Sample-2
# 428   Unknown        GRP5_SBJ12_A1E1_SMP-Blood-Sample-1
# 429   Unknown  GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
# 430   Unknown        GRP5_SBJ12_A1E0_SMP-Blood-Sample-1
# 431   Unknown        GRP5_SBJ12_A1E2_SMP-Blood-Sample-3
#
#     Characteristics[organism part]  \
# 0                     Blood Sample
# 1                     Blood Sample
# 2                     Blood Sample
# 3                     Blood Sample
# 4                     Blood Sample
# ..                             ...
# 427                   Blood Sample
# 428                   Blood Sample
# 429             Unspecified Tissue
# 430                   Blood Sample
# 431                   Blood Sample
#
#                          Term Accession Number.1  \
# 0     http://purl.obolibrary.org/obo/NCIT_C17610
# 1     http://purl.obolibrary.org/obo/NCIT_C17610
# 2     http://purl.obolibrary.org/obo/NCIT_C17610
# 3     http://purl.obolibrary.org/obo/NCIT_C17610
# 4     http://purl.obolibrary.org/obo/NCIT_C17610
# ..                                           ...
# 427   http://purl.obolibrary.org/obo/NCIT_C17610
# 428   http://purl.obolibrary.org/obo/NCIT_C17610
# 429  http://purl.obolibrary.org/obo/NCIT_C132256
# 430   http://purl.obolibrary.org/obo/NCIT_C17610
# 431   http://purl.obolibrary.org/obo/NCIT_C17610
#
#     Comment[study step with treatment] Factor Value[Sequence Order]  \
# 0                                  YES                            1
# 1                                   NO                            2
# 2                                   NO                            2
# 3                                   NO                            0
# 4                                   NO                            2
# ..                                 ...                          ...
# 427                                 NO                            2
# 428                                YES                            1
# 429                                YES                            1
# 430                                 NO                            0
# 431                                 NO                            2
#
#     Factor Value[INTENSITY]    Unit Factor Value[DURATION] Unit.1  \
# 0                       5.0  mg/day                     30   days
# 1                                                       90   days
# 2                                                       90   days
# 3                                                        7   days
# 4                                                       90   days
# ..                      ...     ...                    ...    ...
# 427                                                     90   days
# 428                    10.0  mg/day                     60   days
# 429                    10.0  mg/day                     60   days
# 430                                                      7   days
# 431                                                     90   days
#
#                           Factor Value[AGENT]
# 0    intravenous streptokinase + oral aspirin
# 1
# 2
# 3
# 4
# ..                                        ...
# 427
# 428                              oral aspirin
# 429                              oral aspirin
# 430
# 431
#
# [432 rows x 18 columns]

# %% [markdown]
# ###  First Assay: Metabolite Profiling using NMR spectroscopy
#
# This assay takes blood samples as input

# %%
dataframes['a_AT2_metabolite-profiling_NMR-spectroscopy.txt']
# Out:
#                               Sample Name Comment[study step with treatment]  \
# 0     GRP10_SBJ01_A3E0_SMP-Blood-Sample-1                                 NO
# 1     GRP10_SBJ01_A3E0_SMP-Blood-Sample-1                                 NO
# 2     GRP10_SBJ01_A3E0_SMP-Blood-Sample-1                                 NO
# 3     GRP10_SBJ01_A3E0_SMP-Blood-Sample-1                                 NO
# 4     GRP10_SBJ01_A3E0_SMP-Blood-Sample-1                                 NO
# ...                                   ...                                ...
# 2875   GRP5_SBJ12_A1E2_SMP-Blood-Sample-3                                 NO
# 2876   GRP5_SBJ12_A1E2_SMP-Blood-Sample-3                                 NO
# 2877   GRP5_SBJ12_A1E2_SMP-Blood-Sample-3                                 NO
# 2878   GRP5_SBJ12_A1E2_SMP-Blood-Sample-3                                 NO
# 2879   GRP5_SBJ12_A1E2_SMP-Blood-Sample-3                                 NO
#
#      Protocol REF Performer         Extract Name  \
# 0      extraction   Unknown   AT2-S15-Extract-R1
# 1      extraction   Unknown   AT2-S15-Extract-R2
# 2      extraction   Unknown   AT2-S15-Extract-R1
# 3      extraction   Unknown   AT2-S16-Extract-R2
# 4      extraction   Unknown   AT2-S15-Extract-R2
# ...           ...       ...                  ...
# 2875   extraction   Unknown  AT2-S659-Extract-R1
# 2876   extraction   Unknown  AT2-S660-Extract-R1
# 2877   extraction   Unknown  AT2-S659-Extract-R2
# 2878   extraction   Unknown  AT2-S659-Extract-R1
# 2879   extraction   Unknown  AT2-S660-Extract-R2
#
#      Characteristics[extract type]    Protocol REF.1  \
# 0                           pellet  nmr_spectroscopy
# 1                      supernatant  nmr_spectroscopy
# 2                           pellet  nmr_spectroscopy
# 3                      supernatant  nmr_spectroscopy
# 4                      supernatant  nmr_spectroscopy
# ...                            ...               ...
# 2875                        pellet  nmr_spectroscopy
# 2876                        pellet  nmr_spectroscopy
# 2877                   supernatant  nmr_spectroscopy
# 2878                        pellet  nmr_spectroscopy
# 2879                   supernatant  nmr_spectroscopy
#
#      Parameter Value[instrument] Parameter Value[acquisition_mode]  \
# 0         Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 1         Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 2         Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 3         Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 4         Bruker Avance II 1 GHz                    2D 13C-13C NMR
# ...                          ...                               ...
# 2875      Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 2876      Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 2877      Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 2878      Bruker Avance II 1 GHz                    2D 13C-13C NMR
# 2879      Bruker Avance II 1 GHz                    2D 13C-13C NMR
#
#      Parameter Value[pulse_sequence] Performer.1  \
# 0                              TOCSY     Unknown
# 1                          watergate     Unknown
# 2                          watergate     Unknown
# 3                          watergate     Unknown
# 4                              TOCSY     Unknown
# ...                              ...         ...
# 2875                           TOCSY     Unknown
# 2876                       watergate     Unknown
# 2877                       watergate     Unknown
# 2878                       watergate     Unknown
# 2879                       watergate     Unknown
#
#               Free Induction Decay Data File
# 0      AT2-S15-raw_spectral_data_file-R1.raw
# 1      AT2-S15-raw_spectral_data_file-R4.raw
# 2      AT2-S15-raw_spectral_data_file-R2.raw
# 3      AT2-S16-raw_spectral_data_file-R4.raw
# 4      AT2-S15-raw_spectral_data_file-R3.raw
# ...                                      ...
# 2875  AT2-S659-raw_spectral_data_file-R1.raw
# 2876  AT2-S660-raw_spectral_data_file-R2.raw
# 2877  AT2-S659-raw_spectral_data_file-R4.raw
# 2878  AT2-S659-raw_spectral_data_file-R2.raw
# 2879  AT2-S660-raw_spectral_data_file-R4.raw
#
# [2880 rows x 12 columns]

# %% [markdown]
# #### Overview of the NMR assay table

# %%
dataframes['a_AT2_metabolite-profiling_NMR-spectroscopy.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                            360
# Comment[study step with treatment]       2
# Protocol REF                             1
# Performer                                1
# Extract Name                          1440
# Characteristics[extract type]            2
# Protocol REF.1                           1
# Parameter Value[instrument]              1
# Parameter Value[acquisition_mode]        1
# Parameter Value[pulse_sequence]          2
# Performer.1                              1
# Free Induction Decay Data File        2880
# dtype: int64

# %% [markdown]
# ###  Second Assay: Metabolite Profiling using MS spectrometry
#
# This assay takes blood samples as input

# %%
dataframes['a_AT1_metabolite-profiling_mass-spectrometry.txt']
# Out:
#                                     Sample Name  \
# 0     GRP10_SBJ01_A3E1_SMP-Unspecified-Tissue-1
# 1     GRP10_SBJ01_A3E1_SMP-Unspecified-Tissue-1
# 2     GRP10_SBJ01_A3E1_SMP-Unspecified-Tissue-1
# 3     GRP10_SBJ01_A3E1_SMP-Unspecified-Tissue-1
# 4     GRP10_SBJ01_A3E1_SMP-Unspecified-Tissue-1
# ...                                         ...
# 1147   GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
# 1148   GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
# 1149   GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
# 1150   GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
# 1151   GRP5_SBJ12_A1E1_SMP-Unspecified-Tissue-1
#
#      Comment[study step with treatment] Protocol REF Performer  \
# 0                                   YES   extraction   Unknown
# 1                                   YES   extraction   Unknown
# 2                                   YES   extraction   Unknown
# 3                                   YES   extraction   Unknown
# 4                                   YES   extraction   Unknown
# ...                                 ...          ...       ...
# 1147                                YES   extraction   Unknown
# 1148                                YES   extraction   Unknown
# 1149                                YES   extraction   Unknown
# 1150                                YES   extraction   Unknown
# 1151                                YES   extraction   Unknown
#
#              Extract Name Characteristics[extract type] Term Accession Number  \
# 0      AT1-S16-Extract-R2                        lipids                lipids
# 1      AT1-S16-Extract-R1                polar fraction        polar fraction
# 2      AT1-S15-Extract-R2                        lipids                lipids
# 3      AT1-S15-Extract-R1                polar fraction        polar fraction
# 4      AT1-S15-Extract-R2                        lipids                lipids
# ...                   ...                           ...                   ...
# 1147  AT1-S124-Extract-R1                polar fraction        polar fraction
# 1148  AT1-S123-Extract-R2                        lipids                lipids
# 1149  AT1-S124-Extract-R2                        lipids                lipids
# 1150  AT1-S123-Extract-R1                polar fraction        polar fraction
# 1151  AT1-S123-Extract-R2                        lipids                lipids
#
#      Protocol REF.1 Performer.1 Labeled Extract Name  ...     Protocol REF.2  \
# 0          labeling     Unknown        AT1-S16-LE-R2  ...  mass spectrometry
# 1          labeling     Unknown        AT1-S16-LE-R1  ...  mass spectrometry
# 2          labeling     Unknown        AT1-S15-LE-R2  ...  mass spectrometry
# 3          labeling     Unknown        AT1-S15-LE-R1  ...  mass spectrometry
# 4          labeling     Unknown        AT1-S15-LE-R2  ...  mass spectrometry
# ...             ...         ...                  ...  ...                ...
# 1147       labeling     Unknown       AT1-S124-LE-R1  ...  mass spectrometry
# 1148       labeling     Unknown       AT1-S123-LE-R2  ...  mass spectrometry
# 1149       labeling     Unknown       AT1-S124-LE-R2  ...  mass spectrometry
# 1150       labeling     Unknown       AT1-S123-LE-R1  ...  mass spectrometry
# 1151       labeling     Unknown       AT1-S123-LE-R2  ...  mass spectrometry
#
#      Parameter Value[instrument]                    Term Accession Number.1  \
# 0              Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 1              Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 2              Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 3              Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 4              Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# ...                          ...                                        ...
# 1147           Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 1148           Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 1149           Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 1150           Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
# 1151           Agilent QTQF 6510  http://purl.obolibrary.org/obo/MS_1000676
#
#      Parameter Value[injection_mode]  \
# 0                                 LC
# 1                                 LC
# 2                                 LC
# 3                                 LC
# 4                                FIA
# ...                              ...
# 1147                              LC
# 1148                             FIA
# 1149                             FIA
# 1150                              LC
# 1151                             FIA
#
#                         Term Accession Number.2  \
# 0
# 1
# 2
# 3
# 4     http://purl.obolibrary.org/obo/MS_1000058
# ...                                         ...
# 1147
# 1148  http://purl.obolibrary.org/obo/MS_1000058
# 1149  http://purl.obolibrary.org/obo/MS_1000058
# 1150
# 1151  http://purl.obolibrary.org/obo/MS_1000058
#
#      Parameter Value[acquisition_mode]  \
# 0                        positive mode
# 1                        positive mode
# 2                        positive mode
# 3                        positive mode
# 4                        positive mode
# ...                                ...
# 1147                     positive mode
# 1148                     positive mode
# 1149                     positive mode
# 1150                     positive mode
# 1151                     positive mode
#
#                         Term Accession Number.3  \
# 0     http://purl.obolibrary.org/obo/MS_1002807
# 1     http://purl.obolibrary.org/obo/MS_1002807
# 2     http://purl.obolibrary.org/obo/MS_1002807
# 3     http://purl.obolibrary.org/obo/MS_1002807
# 4     http://purl.obolibrary.org/obo/MS_1002807
# ...                                         ...
# 1147  http://purl.obolibrary.org/obo/MS_1002807
# 1148  http://purl.obolibrary.org/obo/MS_1002807
# 1149  http://purl.obolibrary.org/obo/MS_1002807
# 1150  http://purl.obolibrary.org/obo/MS_1002807
# 1151  http://purl.obolibrary.org/obo/MS_1002807
#
#                                   MS Assay Name Performer.2  \
# 0      AT1-S16-mass-spectrometry-Acquisition-R6     Unknown
# 1      AT1-S16-mass-spectrometry-Acquisition-R4     Unknown
# 2      AT1-S15-mass-spectrometry-Acquisition-R6     Unknown
# 3      AT1-S15-mass-spectrometry-Acquisition-R3     Unknown
# 4      AT1-S15-mass-spectrometry-Acquisition-R7     Unknown
# ...                                         ...         ...
# 1147  AT1-S124-mass-spectrometry-Acquisition-R4     Unknown
# 1148  AT1-S123-mass-spectrometry-Acquisition-R8     Unknown
# 1149  AT1-S124-mass-spectrometry-Acquisition-R7     Unknown
# 1150  AT1-S123-mass-spectrometry-Acquisition-R4     Unknown
# 1151  AT1-S123-mass-spectrometry-Acquisition-R7     Unknown
#
#                       Raw Spectral Data File
# 0      AT1-S16-raw-spectral-data-file-R6.raw
# 1      AT1-S16-raw-spectral-data-file-R4.raw
# 2      AT1-S15-raw-spectral-data-file-R6.raw
# 3      AT1-S15-raw-spectral-data-file-R3.raw
# 4      AT1-S15-raw-spectral-data-file-R7.raw
# ...                                      ...
# 1147  AT1-S124-raw-spectral-data-file-R4.raw
# 1148  AT1-S123-raw-spectral-data-file-R8.raw
# 1149  AT1-S124-raw-spectral-data-file-R7.raw
# 1150  AT1-S123-raw-spectral-data-file-R4.raw
# 1151  AT1-S123-raw-spectral-data-file-R7.raw
#
# [1152 rows x 21 columns]

# %% [markdown]
# #### Overview of the MS assay table

# %%
dataframes['a_AT1_metabolite-profiling_mass-spectrometry.txt'].nunique(axis=0, dropna=True)
# Out:
# Sample Name                             72
# Comment[study step with treatment]       1
# Protocol REF                             1
# Performer                                1
# Extract Name                           288
# Characteristics[extract type]            2
# Term Accession Number                    2
# Protocol REF.1                           1
# Performer.1                              1
# Labeled Extract Name                   288
# Label                                    1
# Protocol REF.2                           1
# Parameter Value[instrument]              1
# Term Accession Number.1                  1
# Parameter Value[injection_mode]          2
# Term Accession Number.2                  2
# Parameter Value[acquisition_mode]        1
# Term Accession Number.3                  1
# MS Assay Name                         1152
# Performer.2                              1
# Raw Spectral Data File                1152
# dtype: int64
