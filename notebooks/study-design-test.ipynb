# %% [markdown]
# ```
# graph Arm_0 id_0(" screen ") --> id_1(" run-in ") --> id_2(" treatment_0 ") --> id_3(" washout ") --> id_4(" treatment_1 ") --> id_5(" follow-up "); end
# ```

# %%
from isatools.model import *
from isatools.create.models import *
from isatools import isatab
from isatools import isajson

# %%
NAME = 'name'
FACTORS_0_VALUE = OntologyAnnotation(term='nitroglycerin')
FACTORS_0_VALUE_ALT = OntologyAnnotation(term='alcohol')
FACTORS_0_VALUE_THIRD = OntologyAnnotation(term='water')
FACTORS_1_VALUE = 5
FACTORS_1_UNIT = OntologyAnnotation(term='kg/m^3')
FACTORS_2_VALUE = 100.0
FACTORS_2_VALUE_ALT = 50.0
FACTORS_2_UNIT = OntologyAnnotation(term='s')

TEST_EPOCH_0_NAME = 'test epoch 0'
TEST_EPOCH_1_NAME = 'test epoch 1'
TEST_EPOCH_2_NAME = 'test epoch 2'

TEST_STUDY_ARM_NAME_00 = 'test arm'
TEST_STUDY_ARM_NAME_01 = 'another arm'
TEST_STUDY_ARM_NAME_02 = 'yet another arm'

TEST_STUDY_DESIGN_NAME = 'test study design'

TEST_EPOCH_0_RANK = 0

SCREEN_DURATION_VALUE = 100
FOLLOW_UP_DURATION_VALUE = 5*366
WASHOUT_DURATION_VALUE = 30
DURATION_UNIT = OntologyAnnotation(term='day')

# %%
sample_list = [
        {
            'node_type': SAMPLE,
            'characteristics_category': OntologyAnnotation(term='organism part'),
            'characteristics_value': 'liver',
            'size': 1,
            'technical_replicates': None,
            'is_input_to_next_protocols': True
        },
        {
            'node_type': SAMPLE,
            'characteristics_category': OntologyAnnotation(term='organism part'),
            'characteristics_value': 'blood',
            'size': 5,
            'technical_replicates': None,
            'is_input_to_next_protocols': True
        },
        {
            'node_type': SAMPLE,
            'characteristics_category': OntologyAnnotation(term='organism part'),
            'characteristics_value': 'heart',
            'size': 1,
            'technical_replicates': None,
            'is_input_to_next_protocols': True
        }
]

ms_assay_dict = OrderedDict([
    ('measurement_type', OntologyAnnotation(term='metabolite profiling')),
    ('technology_type', OntologyAnnotation(term='mass spectrometry')),
    ('extraction', {}),
    ('extract', [
        {
            'node_type': EXTRACT,
            'characteristics_category': OntologyAnnotation(term='extract type'),
            'characteristics_value': OntologyAnnotation(term='polar fraction'),
            'size': 1,
            'is_input_to_next_protocols': True
        },
        {
            'node_type': EXTRACT,
            'characteristics_category': OntologyAnnotation(term='extract type'),
            'characteristics_value': OntologyAnnotation(term='lipids'),
            'size': 1,
            'is_input_to_next_protocols': True
        }
    ]),
    ('labelling', {
        '#replicates': 2
    }),
    ('labelled extract', [
        {
            'node_type': LABELED_EXTRACT,
            'characteristics_category': OntologyAnnotation(term='labelled extract type'),
            'characteristics_value': '',
            'size': 1,
            'is_input_to_next_protocols': True
        }
    ]),
    ('mass spectrometry', {
        '#replicates': 2,
        'instrument': ['Agilent QTQF §'],
        'injection_mode': ['FIA', 'LC'],
        'acquisition_mode': ['positive mode']
    }),
    ('raw spectral data file', [
        {
            'node_type': DATA_FILE,
            'size': 2,
            'is_input_to_next_protocols': False
        }
    ])
])

phti_assay_dict = OrderedDict([
    ('measurement_type', 'phenotyping'),
    ('technology_type', 'high-throughput imaging'),
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': EXTRACT,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'supernatant',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                },
                {
                    'node_type': EXTRACT,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'pellet',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('phenotyping by high throughput imaging', {
                'instrument': ['lemnatech gigant'],
                'acquisition_mode': ['UV light','near-IR light','far-IR light','visible light'],
                'camera position': ['top','120 degree','240 degree','360 degree'],
                'imaging daily schedule': ['06.00','19.00']
            }),
            ('raw_spectral_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 2,
                    'is_input_to_next_protocols': False
                }
            ])
        ])

lcdad_assay_dict = OrderedDict([
    ('measurement_type', 'metabolite identification'),
    ('technology_type', 'liquid chromatography diode-array detector'),
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': EXTRACT,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'supernatant',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                },
                {
                    'node_type': EXTRACT,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'pellet',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('lcdad_spectroscopy', {
                'instrument': ['Shimadzu DAD 400'],
            }),
            ('raw_spectral_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 2,
                    'is_input_to_next_protocols': False
                }
            ])
        ])

nmr_assay_dict = OrderedDict([
    ('measurement_type', OntologyAnnotation(term='metabolite profiling')),
    ('technology_type', OntologyAnnotation(term='nmr spectroscopy')),
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': EXTRACT,
                    'characteristics_category':  OntologyAnnotation(term='extract type'),
                    'characteristics_value': OntologyAnnotation(term='supernatant'),
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                },
                {
                    'node_type': EXTRACT,
                    'characteristics_category':  OntologyAnnotation(term='extract type'),
                    'characteristics_value': OntologyAnnotation(term='pellet'),
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('nmr_spectroscopy', {
                OntologyAnnotation(term='instrument'): [OntologyAnnotation(term='Bruker AvanceII 1 GHz')],
                OntologyAnnotation(term='acquisition_mode'): [OntologyAnnotation(term='1D 13C NMR')],
                OntologyAnnotation(term='pulse_sequence'): [OntologyAnnotation(term='CPMG')]
            }),
            ('raw_spectral_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 2,
                    'is_input_to_next_protocols': False
                }
            ])
        ])

# %%
first_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))
second_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_ALT),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))
third_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_ALT),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE_ALT, unit=FACTORS_2_UNIT)
))
fourth_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_THIRD),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))
screen = NonTreatment(element_type=SCREEN, duration_value=SCREEN_DURATION_VALUE, duration_unit=DURATION_UNIT)
run_in = NonTreatment(element_type=RUN_IN, duration_value=WASHOUT_DURATION_VALUE, duration_unit=DURATION_UNIT)
washout = NonTreatment(element_type=WASHOUT, duration_value=WASHOUT_DURATION_VALUE, duration_unit=DURATION_UNIT)
follow_up = NonTreatment(element_type=FOLLOW_UP, duration_value=FOLLOW_UP_DURATION_VALUE, duration_unit=DURATION_UNIT)
potential_concomitant_washout = NonTreatment(element_type=WASHOUT, duration_value=FACTORS_2_VALUE,
                                                          duration_unit=FACTORS_2_UNIT)
cell_screen = StudyCell(SCREEN, elements=(screen,))
cell_run_in = StudyCell(RUN_IN, elements=(run_in,))
cell_other_run_in = StudyCell('OTHER RUN-IN', elements=(run_in,))
cell_screen_and_run_in = StudyCell('SCREEN AND RUN-IN', elements=[screen, run_in])
cell_concomitant_treatments = StudyCell('CONCOMITANT TREATMENTS',
                                                     elements=([{second_treatment, fourth_treatment}]))
cell_washout_00 = StudyCell(WASHOUT, elements=(washout,))
cell_washout_01 = StudyCell('ANOTHER WASHOUT', elements=(washout,))
cell_single_treatment_00 = StudyCell('SINGLE TREATMENT FIRST', elements=[first_treatment])
cell_single_treatment_01 = StudyCell('SINGLE TREATMENT SECOND', elements=[second_treatment])
cell_single_treatment_02 = StudyCell('SINGLE TREATMENT THIRD', elements=[third_treatment])
cell_multi_elements = StudyCell('MULTI ELEMENTS',
                                             elements=[{first_treatment, second_treatment,
                                                        fourth_treatment}, washout, second_treatment])
cell_multi_elements_padded = StudyCell('MULTI ELEMENTS PADDED',
                                                    elements=[first_treatment, washout, {
                                                        second_treatment,
                                                        fourth_treatment
                                                    }, washout, third_treatment, washout])
cell_follow_up = StudyCell(FOLLOW_UP, elements=(follow_up,))
cell_follow_up_01 = StudyCell('ANOTHER FOLLOW_UP', elements=(follow_up,))
qc = QualityControl()

ms_sample_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict("ms_sap", sample_list, ms_assay_dict)
nmr_sample_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict("nmr_sap", sample_list, nmr_assay_dict)

first_arm = StudyArm(name=TEST_STUDY_ARM_NAME_00, group_size=10, arm_map=OrderedDict([
    (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_00, ms_sample_assay_plan),
    (cell_follow_up, ms_sample_assay_plan)
]))
second_arm = StudyArm(name=TEST_STUDY_ARM_NAME_01, group_size=25, arm_map=OrderedDict([
    (cell_screen, None), (cell_run_in, None),
    (cell_multi_elements, ms_sample_assay_plan),
    (cell_follow_up, ms_sample_assay_plan)
]))
third_arm = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=20, arm_map=OrderedDict([
    (cell_screen, None), (cell_run_in, None),
    (cell_multi_elements_padded, ms_sample_assay_plan),
    (cell_follow_up, ms_sample_assay_plan)
]))
third_arm_no_run_in = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=20, arm_map=OrderedDict([
    (cell_screen, None),
    (cell_multi_elements_padded, ms_sample_assay_plan),
    (cell_follow_up, ms_sample_assay_plan)
]))
arm_same_name_as_third = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=10, arm_map=OrderedDict([
    (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_01, ms_sample_assay_plan),
    (cell_follow_up, ms_sample_assay_plan)
]))
        # Sample QC (for mass spectroscopy and other)
pre_run_sample_type = ProductNode(
    id_='pre/00', node_type=SAMPLE, name='water', size=5, characteristics=(
        Characteristic(category='dilution', value=10, unit='mg/L'),
    )
)
post_run_sample_type = ProductNode(
    id_='post/00', node_type=SAMPLE, name='ethanol', size=5, characteristics=(
        Characteristic(category='dilution', value=1000, unit='mg/L'),
        Characteristic(category='dilution', value=100, unit='mg/L'),
        Characteristic(category='dilution', value=10, unit='mg/L'),
        Characteristic(category='dilution', value=1, unit='mg/L'),
        Characteristic(category='dilution', value=0.1, unit='mg/L')
    ))
dummy_sample_type = ProductNode(id_='dummy/01', node_type=SAMPLE, name='dummy')
more_dummy_sample_type = ProductNode(id_='dummy/02', node_type=SAMPLE, name='more dummy')
interspersed_sample_types = [(dummy_sample_type, 20)]
qc = QualityControl(
    interspersed_sample_type=interspersed_sample_types,
    pre_run_sample_type=pre_run_sample_type,
    post_run_sample_type=post_run_sample_type
)
# Out:
# {}
# pv_combination: ()
# count: 0, prev_node: extraction_000
# count: 0, prev_node: extraction_000
# {}
# pv_combination: ()
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# count: 0, prev_node: labelling_000_000
# count: 1, prev_node: labelling_000_001
# {'instrument': ['Agilent QTQF §'], 'injection_mode': ['FIA', 'LC'], 'acquisition_mode': ['positive mode']}
# pv_combination: ('Agilent QTQF §', 'FIA', 'positive mode')
# count: 0, prev_node: labelled extract_000_000
# count: 1, prev_node: labelled extract_000_001
# pv_combination: ('Agilent QTQF §', 'LC', 'positive mode')
# count: 0, prev_node: labelled extract_000_000
# count: 1, prev_node: labelled extract_000_001
# count: 0, prev_node: mass spectrometry_000_000
# count: 1, prev_node: mass spectrometry_000_001
# count: 2, prev_node: mass spectrometry_001_000
# count: 3, prev_node: mass spectrometry_001_001
# {}
# pv_combination: ()
# count: 0, prev_node: extraction_000
# count: 0, prev_node: extraction_000
# {isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]): [isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[])], isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]): [isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[])], isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]): [isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[])]}
# pv_combination: (isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]))
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# count: 0, prev_node: nmr_spectroscopy_000_000
# count: 1, prev_node: nmr_spectroscopy_000_001

# %%
import os
import yaml
with open(os.path.join(os.getcwd(), '..', 'study-creator-config.yaml')) as yaml_file:
    config = yaml.load(yaml_file)

# %%
single_arm = StudyArm(name=TEST_STUDY_ARM_NAME_00, group_size=10, arm_map=OrderedDict([
    (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_00, nmr_sample_assay_plan),
    (cell_follow_up, nmr_sample_assay_plan)
]))
study_design = StudyDesign(study_arms=(single_arm,))
study = study_design.generate_isa_study()
# Out:
# Sampling protocol is Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# )

# %%
study
# Out:
# isatools.model.Study(filename='s_study_01.txt', identifier='', title='', description='', submission_date='', public_release_date='', contacts=[], design_descriptors=[], publications=[], factors=[isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[])], protocols=[isatools.model.Protocol(name='sample collection', protocol_type=isatools.model.OntologyAnnotation(term='sample_collection', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='run order', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='study cell', term_source=None, term_accession='', comments=[]), comments=[])], components=[], comments=[]), isatools.create.models.ProtocolNode(id=nmr_spectroscopy_000_000, name=nmr_spectroscopy, protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=nmr_spectroscopy_000_001, name=nmr_spectroscopy, protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])]), isatools.create.models.ProtocolNode(id=extraction_000, name=extraction, protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[])], assays=[isatools.model.Assay(measurement_type=isatools.model.OntologyAnnotation(term='metabolite profiling', term_source=None, term_accession='', comments=[]), technology_type=isatools.model.OntologyAnnotation(term='nmr spectroscopy', term_source=None, term_accession='', comments=[]), technology_platform='', filename='a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt', data_files=[isatools.model.RawDataFile(filename='raw_spectral_data_file_0-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_0-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_1-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_1-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_2-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_2-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_3-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_3-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_4-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_4-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_5-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_5-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_6-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_6-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_7-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_7-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_8-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_8-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_9-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_9-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_10-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_10-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_11-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_11-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_12-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_12-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_13-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_13-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_14-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_14-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_15-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_15-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_16-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_16-6', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectral_data_file_17-3', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='raw_spectr ...
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-003', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_0-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_0-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_0-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_0-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_0-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_0-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_0-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_0-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_1-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-003', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_1-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_1-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_1-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_1-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_1-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_1-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_1-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_1-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_2-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-003', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_2-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_2-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_2-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_2-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_2-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_2-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_2-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_2-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_3-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-003', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_3-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_3-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_3-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_3-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_3-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_3-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_3-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_3-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_4-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-003', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_4-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_4-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_4-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_4-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_4-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_4-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_4-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_4-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_5-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-009', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_5-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_5-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_5-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_5-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_5-3', generated_from=[], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_5-5", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_000,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
#     term=nmr_spectroscopy
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='Bruker AvanceII 1 GHz', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='1D 13C NMR', term_source=None, term_accession='', comments=[]), unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='pulse_sequence', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='CPMG', term_source=None, term_accession='', comments=[]), unit=None, comments=[])])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Extract(name='extract_5-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.RawDataFile(filename='raw_spectral_data_file_5-6', generated_from=[], comments=[])]), isatools.model.Process(id="". name="extraction_6-0", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=extraction,
#         protocol_type=OntologyAnnotation(
#     term=extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Ellipsis", inputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='blood', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-009', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])], outputs=[isatools.model.Extract(name='extract_6-1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='pellet', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[]), isatools.model.Extract(name='extract_6-4', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='supernatant', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="nmr_spectroscopy_6-2", executes_protocol=ProtocolNode(
#         id=nmr_spectroscopy_000_001,
#         name=nmr_spectroscopy,
#         protocol_type=OntologyAnnotation(
# ...
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-005', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-005.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-005', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-006', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-006.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-006', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-002', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-002.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-002', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-007', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-007.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-007', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-008', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-008.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-008', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-004', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-004.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-004', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2020-01-10", performer="Bob", inputs=[isatools.model.Source(name='GRP-test_arm.SBJ-001', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP-test_arm.SBJ-001.CEL-follow-up.SMP-.heart.1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value='heart', unit=None, comments=[])], factor_values=[], derives_from=[isatools.model.Source(name='GRP-test_arm.SBJ-001', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[])])], other_material=[], characteristic_categories=[], comments=[], units=[])

# %%
treatment_assay = next(iter(study.assays))

# %%
treatment_assay.graph
# Out:
# 2020-01-10 16:20:56,088 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )

# %%
import networkx as nx
import numpy as np
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
[(process.name, getattr(process.prev_process, 'name', None), getattr(process.next_process, 'name', None)) for process in treatment_assay.process_sequence]
# Out:
# [('extraction_0-0', None, 'nmr_spectroscopy_0-5'),
#  ('nmr_spectroscopy_0-2', 'extraction_0-0', None),
#  ('nmr_spectroscopy_0-5', 'extraction_0-0', None),
#  ('extraction_1-0', None, 'nmr_spectroscopy_1-5'),
#  ('nmr_spectroscopy_1-2', 'extraction_1-0', None),
#  ('nmr_spectroscopy_1-5', 'extraction_1-0', None),
#  ('extraction_2-0', None, 'nmr_spectroscopy_2-5'),
#  ('nmr_spectroscopy_2-2', 'extraction_2-0', None),
#  ('nmr_spectroscopy_2-5', 'extraction_2-0', None),
#  ('extraction_3-0', None, 'nmr_spectroscopy_3-5'),
#  ('nmr_spectroscopy_3-2', 'extraction_3-0', None),
#  ('nmr_spectroscopy_3-5', 'extraction_3-0', None),
#  ('extraction_4-0', None, 'nmr_spectroscopy_4-5'),
#  ('nmr_spectroscopy_4-2', 'extraction_4-0', None),
#  ('nmr_spectroscopy_4-5', 'extraction_4-0', None),
#  ('extraction_5-0', None, 'nmr_spectroscopy_5-5'),
#  ('nmr_spectroscopy_5-2', 'extraction_5-0', None),
#  ('nmr_spectroscopy_5-5', 'extraction_5-0', None),
#  ('extraction_6-0', None, 'nmr_spectroscopy_6-5'),
#  ('nmr_spectroscopy_6-2', 'extraction_6-0', None),
#  ('nmr_spectroscopy_6-5', 'extraction_6-0', None),
#  ('extraction_7-0', None, 'nmr_spectroscopy_7-5'),
#  ('nmr_spectroscopy_7-2', 'extraction_7-0', None),
#  ('nmr_spectroscopy_7-5', 'extraction_7-0', None),
#  ('extraction_8-0', None, 'nmr_spectroscopy_8-5'),
#  ('nmr_spectroscopy_8-2', 'extraction_8-0', None),
#  ('nmr_spectroscopy_8-5', 'extraction_8-0', None),
#  ('extraction_9-0', None, 'nmr_spectroscopy_9-5'),
#  ('nmr_spectroscopy_9-2', 'extraction_9-0', None),
#  ('nmr_spectroscopy_9-5', 'extraction_9-0', None),
#  ('extraction_10-0', None, 'nmr_spectroscopy_10-5'),
#  ('nmr_spectroscopy_10-2', 'extraction_10-0', None),
#  ('nmr_spectroscopy_10-5', 'extraction_10-0', None),
#  ('extraction_11-0', None, 'nmr_spectroscopy_11-5'),
#  ('nmr_spectroscopy_11-2', 'extraction_11-0', None),
#  ('nmr_spectroscopy_11-5', 'extraction_11-0', None),
#  ('extraction_12-0', None, 'nmr_spectroscopy_12-5'),
#  ('nmr_spectroscopy_12-2', 'extraction_12-0', None),
#  ('nmr_spectroscopy_12-5', 'extraction_12-0', None),
#  ('extraction_13-0', None, 'nmr_spectroscopy_13-5'),
#  ('nmr_spectroscopy_13-2', 'extraction_13-0', None),
#  ('nmr_spectroscopy_13-5', 'extraction_13-0', None),
#  ('extraction_14-0', None, 'nmr_spectroscopy_14-5'),
#  ('nmr_spectroscopy_14-2', 'extraction_14-0', None),
#  ('nmr_spectroscopy_14-5', 'extraction_14-0', None),
#  ('extraction_15-0', None, 'nmr_spectroscopy_15-5'),
#  ('nmr_spectroscopy_15-2', 'extraction_15-0', None),
#  ('nmr_spectroscopy_15-5', 'extraction_15-0', None),
#  ('extraction_16-0', None, 'nmr_spectroscopy_16-5'),
#  ('nmr_spectroscopy_16-2', 'extraction_16-0', None),
#  ('nmr_spectroscopy_16-5', 'extraction_16-0', None),
#  ('extraction_17-0', None, 'nmr_spectroscopy_17-5'),
#  ('nmr_spectroscopy_17-2', 'extraction_17-0', None),
#  ('nmr_spectroscopy_17-5', 'extraction_17-0', None),
#  ('extraction_18-0', None, 'nmr_spectroscopy_18-5'),
#  ('nmr_spectroscopy_18-2', 'extraction_18-0', None),
#  ('nmr_spectroscopy_18-5', 'extraction_18-0', None),
#  ('extraction_19-0', None, 'nmr_spectroscopy_19-5'),
#  ('nmr_spectroscopy_19-2', 'extraction_19-0', None),
#  ('nmr_spectroscopy_19-5', 'extraction_19-0', None),
#  ('extraction_20-0', None, 'nmr_spectroscopy_20-5'),
#  ('nmr_spectroscopy_20-2', 'extraction_20-0', None),
#  ('nmr_spectroscopy_20-5', 'extraction_20-0', None),
#  ('extraction_21-0', None, 'nmr_spectroscopy_21-5'),
#  ('nmr_spectroscopy_21-2', 'extraction_21-0', None),
#  ('nmr_spectroscopy_21-5', 'extraction_21-0', None),
#  ('extraction_22-0', None, 'nmr_spectroscopy_22-5'),
#  ('nmr_spectroscopy_22-2', 'extraction_22-0', None),
#  ('nmr_spectroscopy_22-5', 'extraction_22-0', None),
#  ('extraction_23-0', None, 'nmr_spectroscopy_23-5'),
#  ('nmr_spectroscopy_23-2', 'extraction_23-0', None),
#  ('nmr_spectroscopy_23-5', 'extraction_23-0', None),
#  ('extraction_24-0', None, 'nmr_spectroscopy_24-5'),
#  ('nmr_spectroscopy_24-2', 'extraction_24-0', None),
#  ('nmr_spectroscopy_24-5', 'extraction_24-0', None),
#  ('extraction_25-0', None, 'nmr_spectroscopy_25-5'),
#  ('nmr_spectroscopy_25-2', 'extraction_25-0', None),
#  ('nmr_spectroscopy_25-5', 'extraction_25-0', None),
#  ('extraction_26-0', None, 'nmr_spectroscopy_26-5'),
#  ('nmr_spectroscopy_26-2', 'extraction_26-0', None),
#  ('nmr_spectroscopy_26-5', 'extraction_26-0', None),
#  ('extraction_27-0', None, 'nmr_spectroscopy_27-5'),
#  ('nmr_spectroscopy_27-2', 'extraction_27-0', None),
#  ('nmr_spectroscopy_27-5', 'extraction_27-0', None),
#  ('extraction_28-0', None, 'nmr_spectroscopy_28-5'),
#  ('nmr_spectroscopy_28-2', 'extraction_28-0', None),
#  ('nmr_spectroscopy_28-5', 'extraction_28-0', None),
#  ('extraction_29-0', None, 'nmr_spectroscopy_29-5'),
#  ('nmr_spectroscopy_29-2', 'extraction_29-0', None),
#  ('nmr_spectroscopy_29-5', 'extraction_29-0', None),
#  ('extraction_30-0', None, 'nmr_spectroscopy_30-5'),
#  ('nmr_spectroscopy_30-2', 'extraction_30-0', None),
#  ('nmr_spectroscopy_30-5', 'extraction_30-0', None),
#  ('extraction_31-0', None, 'nmr_spectroscopy_31-5'),
#  ('nmr_spectroscopy_31-2', 'extraction_31-0', None),
#  ('nmr_spectroscopy_31-5', 'extraction_31-0', None),
#  ('extraction_32-0', None, 'nmr_spectroscopy_32-5'),
#  ('nmr_spectroscopy_32-2', 'extraction_32-0', None),
#  ('nmr_spectroscopy_32-5', 'extraction_32-0', None),
#  ('extraction_33-0', None, 'nmr_spectroscopy_33-5'),
#  ('nmr_spectroscopy_33-2', 'extraction_33-0', None),
#  ('nmr_spectroscopy_33-5', 'extraction_33-0', None),
#  ('extraction_34-0', None, 'nmr_spectroscopy_34-5'),
#  ('nmr_spectroscopy_34-2', 'extraction_34-0', None),
#  ('nmr_spectroscopy_34-5', 'extraction_34-0', None),
#  ('extraction_35-0', None, 'nmr_spectroscopy_35-5'),
#  ('nmr_spectroscopy_35-2', 'extraction_35-0', None),
#  ('nmr_spectroscopy_35-5', 'extraction_35-0', None),
#  ('extraction_36-0', None, 'nmr_spectroscopy_36-5'),
#  ('nmr_spectroscopy_36-2', 'extraction_36-0', None),
#  ('nmr_spectroscopy_36-5', 'extraction_36-0', None),
#  ('extraction_37-0', None, 'nmr_spectroscopy_37-5'),
#  ('nmr_spectroscopy_37-2', 'extraction_37-0', None),
#  ('nmr_spectroscopy_37-5', 'extraction_37-0', None),
#  ('extraction_38-0', None, 'nmr_spectroscopy_38-5'),
#  ('nmr_spectroscopy_38-2', 'extraction_38-0', None),
#  ('nmr_spectroscopy_38-5', 'extraction_38-0', None),
#  ('extraction_39-0', None, 'nmr_spectroscopy_39-5'),
#  ('nmr_spectroscopy_39-2', 'extraction_39-0', None),
#  ('nmr_spectroscopy_39-5', 'extraction_39-0', None),
#  ('extraction_40-0', None, 'nmr_spectroscopy_40-5'),
#  ('nmr_spectroscopy_40-2', 'extraction_40-0', None),
#  ('nmr_spectroscopy_40-5', 'extraction_40-0', None),
#  ('extraction_41-0', None, 'nmr_spectroscopy_41-5'),
#  ('nmr_spectroscopy_41-2', 'extraction_41-0', None),
#  ('nmr_spectroscopy_41-5', 'extraction_41-0', None),
#  ('extraction_42-0', None, 'nmr_spectroscopy_42-5'),
#  ('nmr_spectroscopy_42-2', 'extraction_42-0', None),
#  ('nmr_spectroscopy_42-5', 'extraction_42-0', None),
#  ('extraction_43-0', None, 'nmr_spectroscopy_43-5'),
#  ('nmr_spectroscopy_43-2', 'extraction_43-0', None),
#  ('nmr_spectroscopy_43-5', 'extraction_43-0', None),
#  ('extraction_44-0', None, 'nmr_spectroscopy_44-5'),
#  ('nmr_spectroscopy_44-2', 'extraction_44-0', None),
#  ('nmr_spectroscopy_44-5', 'extraction_44-0', None),
#  ('extraction_45-0', None, 'nmr_spectroscopy_45-5'),
#  ('nmr_spectroscopy_45-2', 'extraction_45-0', None),
#  ('nmr_spectroscopy_45-5', 'extraction_45-0', None),
#  ('extraction_46-0', None, 'nmr_spectroscopy_46-5'),
#  ('nmr_spectroscopy_46-2', 'extraction_46-0', None),
#  ('nmr_spectroscopy_46-5', 'extraction_46-0', None),
#  ('extraction_47-0', None, 'nmr_spectroscopy_47-5'),
#  ('nmr_spectroscopy_47-2', 'extraction_47-0', None),
#  ('nmr_spectroscopy_47-5', 'extraction_47-0', None),
#  ('extraction_48-0', None, 'nmr_spectroscopy_48-5'),
#  ('nmr_spectroscopy_48-2', 'extraction_48-0', None),
#  ('nmr_spectroscopy_48-5', 'extraction_48-0', None),
#  ('extraction_49-0', None, 'nmr_spectroscopy_49-5'),
#  ('nmr_spectroscopy_49-2', 'extraction_49-0', None),
#  ('nmr_spectroscopy_49-5', 'extraction_49-0', None),
#  ('extraction_50-0', None, 'nmr_spectroscopy_50-5'),
#  ('nmr_spectroscopy_50-2', 'extraction_50-0', None),
#  ('nmr_spectroscopy_50-5', 'extraction_50-0', None),
#  ('extraction_51-0', None, 'nmr_spectroscopy_51-5'),
#  ('nmr_spectroscopy_51-2', 'extraction_51-0', None),
#  ('nmr_spectroscopy_51-5', 'extraction_51-0', None),
#  ('extraction_52-0', None, 'nmr_spectroscopy_52-5'),
#  ('nmr_spectroscopy_52-2', 'extraction_52-0', None),
#  ('nmr_spectroscopy_52-5', 'extraction_52-0', None),
#  ('extraction_53-0', None, 'nmr_spectroscopy_53-5'),
#  ('nmr_spectroscopy_53-2', 'extraction_53-0', None),
#  ('nmr_spectroscopy_53-5', 'extraction_53-0', None),
#  ('extraction_54-0', None, 'nmr_spectroscopy_54-5'),
#  ('nmr_spectroscopy_54-2', 'extraction_54-0', None),
#  ('nmr_spectroscopy_54-5', 'extraction_54-0', None),
#  ('extraction_55-0', None, 'nmr_spectroscopy_55-5'),
#  ('nmr_spectroscopy_55-2', 'extraction_55-0', None),
#  ('nmr_spectroscopy_55-5', 'extraction_55-0', None),
#  ('extraction_56-0', None, 'nmr_spectroscopy_56-5'),
#  ('nmr_spectroscopy_56-2', 'extraction_56-0', None),
#  ('nmr_spectroscopy_56-5', 'extraction_56-0', None),
#  ('extraction_57-0', None, 'nmr_spectroscopy_57-5'),
#  ('nmr_spectroscopy_57-2', 'extraction_57-0', None),
#  ('nmr_spectroscopy_57-5', 'extraction_57-0', None),
#  ('extraction_58-0', None, 'nmr_spectroscopy_58-5'),
#  ('nmr_spectroscopy_58-2', 'extraction_58-0', None),
#  ('nmr_spectroscopy_58-5', 'extraction_58-0', None),
#  ('extraction_59-0', None, 'nmr_spectroscopy_59-5'),
#  ('nmr_spectroscopy_59-2', 'extraction_59-0', None),
#  ('nmr_spectroscopy_59-5', 'extraction_59-0', None),
#  ('extraction_60-0', None, 'nmr_spectroscopy_60-5'),
#  ('nmr_spectroscopy_60-2', 'extraction_60-0', None),
#  ('nmr_spectroscopy_60-5', 'extraction_60-0', None),
#  ('extraction_61-0', None, 'nmr_spectroscopy_61-5'),
#  ('nmr_spectroscopy_61-2', 'extraction_61-0', None),
#  ('nmr_spectroscopy_61-5', 'extraction_61-0', None),
#  ('extraction_62-0', None, 'nmr_spectroscopy_62-5'),
#  ('nmr_spectroscopy_62-2', 'extraction_62-0', None),
#  ('nmr_spectroscopy_62-5', 'extraction_62-0', None),
#  ('extraction_63-0', None, 'nmr_spectroscopy_63-5'),
#  ('nmr_spectroscopy_63-2', 'extraction_63-0', None),
#  ('nmr_spectroscopy_63-5', 'extraction_63-0', None),
#  ('extraction_64-0', None, 'nmr_spectroscopy_64-5'),
#  ('nmr_spectroscopy_64-2', 'extraction_64-0', None),
#  ('nmr_spectroscopy_64-5', 'extraction_64-0', None),
#  ('extraction_65-0', None, 'nmr_spectroscopy_65-5'),
#  ('nmr_spectroscopy_65-2', 'extraction_65-0', None),
#  ('nmr_spectroscopy_65-5', 'extraction_65-0', None),
#  ('extraction_66-0', None, 'nmr_spectroscopy_66-5'),
#  ('nmr_spectroscopy_66-2', 'extraction_66-0', None),
#  ('nmr_spectroscopy_66-5', 'extraction_66-0', None),
#  ('extraction_67-0', None, 'nmr_spectroscopy_67-5'),
#  ('nmr_spectroscopy_67-2', 'extraction_67-0', None),
#  ('nmr_spectroscopy_67-5', 'extraction_67-0', None),
#  ('extraction_68-0', None, 'nmr_spectroscopy_68-5'),
#  ('nmr_spectroscopy_68-2', 'extraction_68-0', None),
#  ('nmr_spectroscopy_68-5', 'extraction_68-0', None),
#  ('extraction_69-0', None, 'nmr_spectroscopy_69-5'),
#  ('nmr_spectroscopy_69-2', 'extraction_69-0', None),
#  ('nmr_spectroscopy_69-5', 'extraction_69-0', None)]

# %%
a_graph = treatment_assay.graph
# Out:
# 2020-01-10 16:20:56,797 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )

# %%
len(a_graph.nodes)
# Out:
# 421

# %%
from isatools.isatab import dump_tables_to_dataframes as dumpdf

# %%
isa_investigation = Investigation(studies=[study])

# %%
isa_tables = dumpdf(isa_investigation)
# Out:
# 2020-01-10 16:20:57,099 [INFO]: model.py(graph:1544) >> Building graph for object: Study(
#     identifier=
#     filename=s_study_01.txt
#     title=
#     description=
#     submission_date=
#     public_release_date=
#     contacts=0 Person objects
#     design_descriptors=0 OntologyAnnotation objects
#     publications=0 Publication objects
#     factors=3 StudyFactor objects
#     protocols=4 Protocol objects
#     assays=2 Assay objects
#     sources=10 Source objects
#     samples=140 Sample objects
#     process_sequence=140 Process objects
#     other_material=0 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:57,223 [INFO]: model.py(graph:1544) >> Building graph for object: Study(
#     identifier=
#     filename=s_study_01.txt
#     title=
#     description=
#     submission_date=
#     public_release_date=
#     contacts=0 Person objects
#     design_descriptors=0 OntologyAnnotation objects
#     publications=0 Publication objects
#     factors=3 StudyFactor objects
#     protocols=4 Protocol objects
#     assays=2 Assay objects
#     sources=10 Source objects
#     samples=140 Sample objects
#     process_sequence=140 Process objects
#     other_material=0 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:57,345 [INFO]: model.py(graph:1544) >> Building graph for object: Study(
#     identifier=
#     filename=s_study_01.txt
#     title=
#     description=
#     submission_date=
#     public_release_date=
#     contacts=0 Person objects
#     design_descriptors=0 OntologyAnnotation objects
#     publications=0 Publication objects
#     factors=3 StudyFactor objects
#     protocols=4 Protocol objects
#     assays=2 Assay objects
#     sources=10 Source objects
#     samples=140 Sample objects
#     process_sequence=140 Process objects
#     other_material=0 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:58,889 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 140 paths!
# 2020-01-10 16:20:58,899 [INFO]: isatab.py(write_study_table_files:1330) >> Rendered 140 paths
# 2020-01-10 16:20:58,903 [INFO]: isatab.py(write_study_table_files:1337) >> Writing 140 rows
# 2020-01-10 16:20:58,908 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:59,094 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:59,278 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:20:59,909 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 140 paths!
# 2020-01-10 16:20:59,935 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_follow-up_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:21:00,120 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_follow-up_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:21:00,306 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_follow-up_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# 2020-01-10 16:21:00,917 [INFO]: isatab.py(_all_end_to_end_paths:1152) >> Found 140 paths!

# %%
[type(x) for x in study.assays[1].graph.nodes()]
# Out:
# 2020-01-10 16:21:00,981 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_follow-up_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# [isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  NoneType,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Process,
#  isatools.model.Extract,
#  isatools.model.Extract,
#  isatools.model.Sample,
#  isatools.model.Process,
#  isatools.model.Process]

# %%
[(getattr(el, 'name', None), type(el))for el in treatment_assay.graph.nodes()]
# Out:
# 2020-01-10 16:21:01,175 [INFO]: model.py(graph:1544) >> Building graph for object: Assay(
#     measurement_type=metabolite profiling
#     technology_type=nmr spectroscopy
#     technology_platform=
#     filename=a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt
#     data_files=140 DataFile objects
#     samples=0 Sample objects
#     process_sequence=210 Process objects
#     other_material=140 Material objects
#     characteristic_categories=0 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# [('extraction_0-0', isatools.model.Process),
#  ('extract_0-1', isatools.model.Extract),
#  ('extract_0-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_0-2', isatools.model.Process),
#  (None, NoneType),
#  ('nmr_spectroscopy_0-5', isatools.model.Process),
#  ('extraction_1-0', isatools.model.Process),
#  ('extract_1-1', isatools.model.Extract),
#  ('extract_1-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_1-2', isatools.model.Process),
#  ('nmr_spectroscopy_1-5', isatools.model.Process),
#  ('extraction_2-0', isatools.model.Process),
#  ('extract_2-1', isatools.model.Extract),
#  ('extract_2-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_2-2', isatools.model.Process),
#  ('nmr_spectroscopy_2-5', isatools.model.Process),
#  ('extraction_3-0', isatools.model.Process),
#  ('extract_3-1', isatools.model.Extract),
#  ('extract_3-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_3-2', isatools.model.Process),
#  ('nmr_spectroscopy_3-5', isatools.model.Process),
#  ('extraction_4-0', isatools.model.Process),
#  ('extract_4-1', isatools.model.Extract),
#  ('extract_4-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_4-2', isatools.model.Process),
#  ('nmr_spectroscopy_4-5', isatools.model.Process),
#  ('extraction_5-0', isatools.model.Process),
#  ('extract_5-1', isatools.model.Extract),
#  ('extract_5-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_5-2', isatools.model.Process),
#  ('nmr_spectroscopy_5-5', isatools.model.Process),
#  ('extraction_6-0', isatools.model.Process),
#  ('extract_6-1', isatools.model.Extract),
#  ('extract_6-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_6-2', isatools.model.Process),
#  ('nmr_spectroscopy_6-5', isatools.model.Process),
#  ('extraction_7-0', isatools.model.Process),
#  ('extract_7-1', isatools.model.Extract),
#  ('extract_7-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_7-2', isatools.model.Process),
#  ('nmr_spectroscopy_7-5', isatools.model.Process),
#  ('extraction_8-0', isatools.model.Process),
#  ('extract_8-1', isatools.model.Extract),
#  ('extract_8-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_8-2', isatools.model.Process),
#  ('nmr_spectroscopy_8-5', isatools.model.Process),
#  ('extraction_9-0', isatools.model.Process),
#  ('extract_9-1', isatools.model.Extract),
#  ('extract_9-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_9-2', isatools.model.Process),
#  ('nmr_spectroscopy_9-5', isatools.model.Process),
#  ('extraction_10-0', isatools.model.Process),
#  ('extract_10-1', isatools.model.Extract),
#  ('extract_10-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_10-2', isatools.model.Process),
#  ('nmr_spectroscopy_10-5', isatools.model.Process),
#  ('extraction_11-0', isatools.model.Process),
#  ('extract_11-1', isatools.model.Extract),
#  ('extract_11-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_11-2', isatools.model.Process),
#  ('nmr_spectroscopy_11-5', isatools.model.Process),
#  ('extraction_12-0', isatools.model.Process),
#  ('extract_12-1', isatools.model.Extract),
#  ('extract_12-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_12-2', isatools.model.Process),
#  ('nmr_spectroscopy_12-5', isatools.model.Process),
#  ('extraction_13-0', isatools.model.Process),
#  ('extract_13-1', isatools.model.Extract),
#  ('extract_13-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_13-2', isatools.model.Process),
#  ('nmr_spectroscopy_13-5', isatools.model.Process),
#  ('extraction_14-0', isatools.model.Process),
#  ('extract_14-1', isatools.model.Extract),
#  ('extract_14-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_14-2', isatools.model.Process),
#  ('nmr_spectroscopy_14-5', isatools.model.Process),
#  ('extraction_15-0', isatools.model.Process),
#  ('extract_15-1', isatools.model.Extract),
#  ('extract_15-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_15-2', isatools.model.Process),
#  ('nmr_spectroscopy_15-5', isatools.model.Process),
#  ('extraction_16-0', isatools.model.Process),
#  ('extract_16-1', isatools.model.Extract),
#  ('extract_16-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_16-2', isatools.model.Process),
#  ('nmr_spectroscopy_16-5', isatools.model.Process),
#  ('extraction_17-0', isatools.model.Process),
#  ('extract_17-1', isatools.model.Extract),
#  ('extract_17-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_17-2', isatools.model.Process),
#  ('nmr_spectroscopy_17-5', isatools.model.Process),
#  ('extraction_18-0', isatools.model.Process),
#  ('extract_18-1', isatools.model.Extract),
#  ('extract_18-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_18-2', isatools.model.Process),
#  ('nmr_spectroscopy_18-5', isatools.model.Process),
#  ('extraction_19-0', isatools.model.Process),
#  ('extract_19-1', isatools.model.Extract),
#  ('extract_19-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_19-2', isatools.model.Process),
#  ('nmr_spectroscopy_19-5', isatools.model.Process),
#  ('extraction_20-0', isatools.model.Process),
#  ('extract_20-1', isatools.model.Extract),
#  ('extract_20-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_20-2', isatools.model.Process),
#  ('nmr_spectroscopy_20-5', isatools.model.Process),
#  ('extraction_21-0', isatools.model.Process),
#  ('extract_21-1', isatools.model.Extract),
#  ('extract_21-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_21-2', isatools.model.Process),
#  ('nmr_spectroscopy_21-5', isatools.model.Process),
#  ('extraction_22-0', isatools.model.Process),
#  ('extract_22-1', isatools.model.Extract),
#  ('extract_22-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_22-2', isatools.model.Process),
#  ('nmr_spectroscopy_22-5', isatools.model.Process),
#  ('extraction_23-0', isatools.model.Process),
#  ('extract_23-1', isatools.model.Extract),
#  ('extract_23-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_23-2', isatools.model.Process),
#  ('nmr_spectroscopy_23-5', isatools.model.Process),
#  ('extraction_24-0', isatools.model.Process),
#  ('extract_24-1', isatools.model.Extract),
#  ('extract_24-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_24-2', isatools.model.Process),
#  ('nmr_spectroscopy_24-5', isatools.model.Process),
#  ('extraction_25-0', isatools.model.Process),
#  ('extract_25-1', isatools.model.Extract),
#  ('extract_25-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_25-2', isatools.model.Process),
#  ('nmr_spectroscopy_25-5', isatools.model.Process),
#  ('extraction_26-0', isatools.model.Process),
#  ('extract_26-1', isatools.model.Extract),
#  ('extract_26-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_26-2', isatools.model.Process),
#  ('nmr_spectroscopy_26-5', isatools.model.Process),
#  ('extraction_27-0', isatools.model.Process),
#  ('extract_27-1', isatools.model.Extract),
#  ('extract_27-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_27-2', isatools.model.Process),
#  ('nmr_spectroscopy_27-5', isatools.model.Process),
#  ('extraction_28-0', isatools.model.Process),
#  ('extract_28-1', isatools.model.Extract),
#  ('extract_28-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_28-2', isatools.model.Process),
#  ('nmr_spectroscopy_28-5', isatools.model.Process),
#  ('extraction_29-0', isatools.model.Process),
#  ('extract_29-1', isatools.model.Extract),
#  ('extract_29-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_29-2', isatools.model.Process),
#  ('nmr_spectroscopy_29-5', isatools.model.Process),
#  ('extraction_30-0', isatools.model.Process),
#  ('extract_30-1', isatools.model.Extract),
#  ('extract_30-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_30-2', isatools.model.Process),
#  ('nmr_spectroscopy_30-5', isatools.model.Process),
#  ('extraction_31-0', isatools.model.Process),
#  ('extract_31-1', isatools.model.Extract),
#  ('extract_31-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_31-2', isatools.model.Process),
#  ('nmr_spectroscopy_31-5', isatools.model.Process),
#  ('extraction_32-0', isatools.model.Process),
#  ('extract_32-1', isatools.model.Extract),
#  ('extract_32-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_32-2', isatools.model.Process),
#  ('nmr_spectroscopy_32-5', isatools.model.Process),
#  ('extraction_33-0', isatools.model.Process),
#  ('extract_33-1', isatools.model.Extract),
#  ('extract_33-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_33-2', isatools.model.Process),
#  ('nmr_spectroscopy_33-5', isatools.model.Process),
#  ('extraction_34-0', isatools.model.Process),
#  ('extract_34-1', isatools.model.Extract),
#  ('extract_34-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_34-2', isatools.model.Process),
#  ('nmr_spectroscopy_34-5', isatools.model.Process),
#  ('extraction_35-0', isatools.model.Process),
#  ('extract_35-1', isatools.model.Extract),
#  ('extract_35-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_35-2', isatools.model.Process),
#  ('nmr_spectroscopy_35-5', isatools.model.Process),
#  ('extraction_36-0', isatools.model.Process),
#  ('extract_36-1', isatools.model.Extract),
#  ('extract_36-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_36-2', isatools.model.Process),
#  ('nmr_spectroscopy_36-5', isatools.model.Process),
#  ('extraction_37-0', isatools.model.Process),
#  ('extract_37-1', isatools.model.Extract),
#  ('extract_37-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_37-2', isatools.model.Process),
#  ('nmr_spectroscopy_37-5', isatools.model.Process),
#  ('extraction_38-0', isatools.model.Process),
#  ('extract_38-1', isatools.model.Extract),
#  ('extract_38-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_38-2', isatools.model.Process),
#  ('nmr_spectroscopy_38-5', isatools.model.Process),
#  ('extraction_39-0', isatools.model.Process),
#  ('extract_39-1', isatools.model.Extract),
#  ('extract_39-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_39-2', isatools.model.Process),
#  ('nmr_spectroscopy_39-5', isatools.model.Process),
#  ('extraction_40-0', isatools.model.Process),
#  ('extract_40-1', isatools.model.Extract),
#  ('extract_40-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_40-2', isatools.model.Process),
#  ('nmr_spectroscopy_40-5', isatools.model.Process),
#  ('extraction_41-0', isatools.model.Process),
#  ('extract_41-1', isatools.model.Extract),
#  ('extract_41-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_41-2', isatools.model.Process),
#  ('nmr_spectroscopy_41-5', isatools.model.Process),
#  ('extraction_42-0', isatools.model.Process),
#  ('extract_42-1', isatools.model.Extract),
#  ('extract_42-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_42-2', isatools.model.Process),
#  ('nmr_spectroscopy_42-5', isatools.model.Process),
#  ('extraction_43-0', isatools.model.Process),
#  ('extract_43-1', isatools.model.Extract),
#  ('extract_43-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_43-2', isatools.model.Process),
#  ('nmr_spectroscopy_43-5', isatools.model.Process),
#  ('extraction_44-0', isatools.model.Process),
#  ('extract_44-1', isatools.model.Extract),
#  ('extract_44-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_44-2', isatools.model.Process),
#  ('nmr_spectroscopy_44-5', isatools.model.Process),
#  ('extraction_45-0', isatools.model.Process),
#  ('extract_45-1', isatools.model.Extract),
#  ('extract_45-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_45-2', isatools.model.Process),
#  ('nmr_spectroscopy_45-5', isatools.model.Process),
#  ('extraction_46-0', isatools.model.Process),
#  ('extract_46-1', isatools.model.Extract),
#  ('extract_46-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.2',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_46-2', isatools.model.Process),
#  ('nmr_spectroscopy_46-5', isatools.model.Process),
#  ('extraction_47-0', isatools.model.Process),
#  ('extract_47-1', isatools.model.Extract),
#  ('extract_47-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.3',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_47-2', isatools.model.Process),
#  ('nmr_spectroscopy_47-5', isatools.model.Process),
#  ('extraction_48-0', isatools.model.Process),
#  ('extract_48-1', isatools.model.Extract),
#  ('extract_48-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.4',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_48-2', isatools.model.Process),
#  ('nmr_spectroscopy_48-5', isatools.model.Process),
#  ('extraction_49-0', isatools.model.Process),
#  ('extract_49-1', isatools.model.Extract),
#  ('extract_49-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.blood.5',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_49-2', isatools.model.Process),
#  ('nmr_spectroscopy_49-5', isatools.model.Process),
#  ('extraction_50-0', isatools.model.Process),
#  ('extract_50-1', isatools.model.Extract),
#  ('extract_50-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_50-2', isatools.model.Process),
#  ('nmr_spectroscopy_50-5', isatools.model.Process),
#  ('extraction_51-0', isatools.model.Process),
#  ('extract_51-1', isatools.model.Extract),
#  ('extract_51-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_51-2', isatools.model.Process),
#  ('nmr_spectroscopy_51-5', isatools.model.Process),
#  ('extraction_52-0', isatools.model.Process),
#  ('extract_52-1', isatools.model.Extract),
#  ('extract_52-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_52-2', isatools.model.Process),
#  ('nmr_spectroscopy_52-5', isatools.model.Process),
#  ('extraction_53-0', isatools.model.Process),
#  ('extract_53-1', isatools.model.Extract),
#  ('extract_53-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_53-2', isatools.model.Process),
#  ('nmr_spectroscopy_53-5', isatools.model.Process),
#  ('extraction_54-0', isatools.model.Process),
#  ('extract_54-1', isatools.model.Extract),
#  ('extract_54-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_54-2', isatools.model.Process),
#  ('nmr_spectroscopy_54-5', isatools.model.Process),
#  ('extraction_55-0', isatools.model.Process),
#  ('extract_55-1', isatools.model.Extract),
#  ('extract_55-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_55-2', isatools.model.Process),
#  ('nmr_spectroscopy_55-5', isatools.model.Process),
#  ('extraction_56-0', isatools.model.Process),
#  ('extract_56-1', isatools.model.Extract),
#  ('extract_56-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_56-2', isatools.model.Process),
#  ('nmr_spectroscopy_56-5', isatools.model.Process),
#  ('extraction_57-0', isatools.model.Process),
#  ('extract_57-1', isatools.model.Extract),
#  ('extract_57-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_57-2', isatools.model.Process),
#  ('nmr_spectroscopy_57-5', isatools.model.Process),
#  ('extraction_58-0', isatools.model.Process),
#  ('extract_58-1', isatools.model.Extract),
#  ('extract_58-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_58-2', isatools.model.Process),
#  ('nmr_spectroscopy_58-5', isatools.model.Process),
#  ('extraction_59-0', isatools.model.Process),
#  ('extract_59-1', isatools.model.Extract),
#  ('extract_59-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.liver.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_59-2', isatools.model.Process),
#  ('nmr_spectroscopy_59-5', isatools.model.Process),
#  ('extraction_60-0', isatools.model.Process),
#  ('extract_60-1', isatools.model.Extract),
#  ('extract_60-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_60-2', isatools.model.Process),
#  ('nmr_spectroscopy_60-5', isatools.model.Process),
#  ('extraction_61-0', isatools.model.Process),
#  ('extract_61-1', isatools.model.Extract),
#  ('extract_61-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_61-2', isatools.model.Process),
#  ('nmr_spectroscopy_61-5', isatools.model.Process),
#  ('extraction_62-0', isatools.model.Process),
#  ('extract_62-1', isatools.model.Extract),
#  ('extract_62-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_62-2', isatools.model.Process),
#  ('nmr_spectroscopy_62-5', isatools.model.Process),
#  ('extraction_63-0', isatools.model.Process),
#  ('extract_63-1', isatools.model.Extract),
#  ('extract_63-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-005.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_63-2', isatools.model.Process),
#  ('nmr_spectroscopy_63-5', isatools.model.Process),
#  ('extraction_64-0', isatools.model.Process),
#  ('extract_64-1', isatools.model.Extract),
#  ('extract_64-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-006.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_64-2', isatools.model.Process),
#  ('nmr_spectroscopy_64-5', isatools.model.Process),
#  ('extraction_65-0', isatools.model.Process),
#  ('extract_65-1', isatools.model.Extract),
#  ('extract_65-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_65-2', isatools.model.Process),
#  ('nmr_spectroscopy_65-5', isatools.model.Process),
#  ('extraction_66-0', isatools.model.Process),
#  ('extract_66-1', isatools.model.Extract),
#  ('extract_66-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-007.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_66-2', isatools.model.Process),
#  ('nmr_spectroscopy_66-5', isatools.model.Process),
#  ('extraction_67-0', isatools.model.Process),
#  ('extract_67-1', isatools.model.Extract),
#  ('extract_67-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_67-2', isatools.model.Process),
#  ('nmr_spectroscopy_67-5', isatools.model.Process),
#  ('extraction_68-0', isatools.model.Process),
#  ('extract_68-1', isatools.model.Extract),
#  ('extract_68-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-004.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_68-2', isatools.model.Process),
#  ('nmr_spectroscopy_68-5', isatools.model.Process),
#  ('extraction_69-0', isatools.model.Process),
#  ('extract_69-1', isatools.model.Extract),
#  ('extract_69-4', isatools.model.Extract),
#  ('GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRST.SMP-.heart.1',
#   isatools.model.Sample),
#  ('nmr_spectroscopy_69-2', isatools.model.Process),
#  ('nmr_spectroscopy_69-5', isatools.model.Process)]

# %%
from isatools.model import _build_assay_graph

# %%
gph = _build_assay_graph(treatment_assay.process_sequence)

# %%
[key for key in isa_tables.keys()]
# Out:
# ['s_study_01.txt',
#  'a_follow-up_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt',
#  'a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt']

# %%
isa_tables['a_SINGLE TREATMENT FIRST_ASSAY_GRAPH_000_metabolite profiling_nmr spectroscopy.txt']
# Out:
#                                            Sample Name Protocol REF Performer  \
# 0    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 1    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 2    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 3    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 4    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 5    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 6    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 7    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 8    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 9    GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 10   GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 11   GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 12   GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 13   GRP-test_arm.SBJ-001.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 14   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 15   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 16   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 17   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 18   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 19   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 20   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 21   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 22   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 23   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 24   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 25   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 26   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 27   GRP-test_arm.SBJ-002.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 28   GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 29   GRP-test_arm.SBJ-003.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# ..                                                 ...          ...       ...
# 110  GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 111  GRP-test_arm.SBJ-008.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 112  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 113  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 114  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 115  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 116  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 117  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 118  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 119  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 120  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 121  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 122  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 123  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 124  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 125  GRP-test_arm.SBJ-009.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 126  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 127  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 128  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 129  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 130  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 131  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 132  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 133  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 134  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 135  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 136  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 137  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 138  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
# 139  GRP-test_arm.SBJ-010.CEL-SINGLE_TREATMENT_FIRS...   extraction  Ellipsis
#
#      Extract Name Characteristics[extract type]    Protocol REF.1  \
# 0    extract_45-4                   supernatant  nmr_spectroscopy
# 1    extract_45-1                        pellet  nmr_spectroscopy
# 2    extract_46-4                   supernatant  nmr_spectroscopy
# 3    extract_46-1                        pellet  nmr_spectroscopy
# 4    extract_47-4                   supernatant  nmr_spectroscopy
# 5    extract_47-1                        pellet  nmr_spectroscopy
# 6    extract_48-1                        pellet  nmr_spectroscopy
# 7    extract_48-4                   supernatant  nmr_spectroscopy
# 8    extract_49-1                        pellet  nmr_spectroscopy
# 9    extract_49-4                   supernatant  nmr_spectroscopy
# 10   extract_69-4                   supernatant  nmr_spectroscopy
# 11   extract_69-1                        pellet  nmr_spectroscopy
# 12   extract_59-1                        pellet  nmr_spectroscopy
# 13   extract_59-4                   supernatant  nmr_spectroscopy
# 14   extract_25-1                        pellet  nmr_spectroscopy
# 15   extract_25-4                   supernatant  nmr_spectroscopy
# 16   extract_26-1                        pellet  nmr_spectroscopy
# 17   extract_26-4                   supernatant  nmr_spectroscopy
# 18   extract_27-4                   supernatant  nmr_spectroscopy
# 19   extract_27-1                        pellet  nmr_spectroscopy
# 20   extract_28-1                        pellet  nmr_spectroscopy
# 21   extract_28-4                   supernatant  nmr_spectroscopy
# 22   extract_29-4                   supernatant  nmr_spectroscopy
# 23   extract_29-1                        pellet  nmr_spectroscopy
# 24   extract_65-4                   supernatant  nmr_spectroscopy
# 25   extract_65-1                        pellet  nmr_spectroscopy
# 26   extract_55-4                   supernatant  nmr_spectroscopy
# 27   extract_55-1                        pellet  nmr_spectroscopy
# 28    extract_0-4                   supernatant  nmr_spectroscopy
# 29    extract_0-1                        pellet  nmr_spectroscopy
# ..            ...                           ...               ...
# 110  extract_57-1                        pellet  nmr_spectroscopy
# 111  extract_57-4                   supernatant  nmr_spectroscopy
# 112   extract_5-4                   supernatant  nmr_spectroscopy
# 113   extract_5-1                        pellet  nmr_spectroscopy
# 114   extract_6-1                        pellet  nmr_spectroscopy
# 115   extract_6-4                   supernatant  nmr_spectroscopy
# 116   extract_7-4                   supernatant  nmr_spectroscopy
# 117   extract_7-1                        pellet  nmr_spectroscopy
# 118   extract_8-4                   supernatant  nmr_spectroscopy
# 119   extract_8-1                        pellet  nmr_spectroscopy
# 120   extract_9-4                   supernatant  nmr_spectroscopy
# 121   extract_9-1                        pellet  nmr_spectroscopy
# 122  extract_61-4                   supernatant  nmr_spectroscopy
# 123  extract_61-1                        pellet  nmr_spectroscopy
# 124  extract_51-1                        pellet  nmr_spectroscopy
# 125  extract_51-4                   supernatant  nmr_spectroscopy
# 126  extract_10-1                        pellet  nmr_spectroscopy
# 127  extract_10-4                   supernatant  nmr_spectroscopy
# 128  extract_11-4                   supernatant  nmr_spectroscopy
# 129  extract_11-1                        pellet  nmr_spectroscopy
# 130  extract_12-4                   supernatant  nmr_spectroscopy
# 131  extract_12-1                        pellet  nmr_spectroscopy
# 132  extract_13-4                   supernatant  nmr_spectroscopy
# 133  extract_13-1                        pellet  nmr_spectroscopy
# 134  extract_14-4                   supernatant  nmr_spectroscopy
# 135  extract_14-1                        pellet  nmr_spectroscopy
# 136  extract_62-4                   supernatant  nmr_spectroscopy
# 137  extract_62-1                        pellet  nmr_spectroscopy
# 138  extract_52-1                        pellet  nmr_spectroscopy
# 139  extract_52-4                   supernatant  nmr_spectroscopy
#
#     Parameter Value[instrument] Parameter Value[acquisition_mode]  \
# 0         Bruker AvanceII 1 GHz                        1D 13C NMR
# 1         Bruker AvanceII 1 GHz                        1D 13C NMR
# 2         Bruker AvanceII 1 GHz                        1D 13C NMR
# 3         Bruker AvanceII 1 GHz                        1D 13C NMR
# 4         Bruker AvanceII 1 GHz                        1D 13C NMR
# 5         Bruker AvanceII 1 GHz                        1D 13C NMR
# 6         Bruker AvanceII 1 GHz                        1D 13C NMR
# 7         Bruker AvanceII 1 GHz                        1D 13C NMR
# 8         Bruker AvanceII 1 GHz                        1D 13C NMR
# 9         Bruker AvanceII 1 GHz                        1D 13C NMR
# 10        Bruker AvanceII 1 GHz                        1D 13C NMR
# 11        Bruker AvanceII 1 GHz                        1D 13C NMR
# 12        Bruker AvanceII 1 GHz                        1D 13C NMR
# 13        Bruker AvanceII 1 GHz                        1D 13C NMR
# 14        Bruker AvanceII 1 GHz                        1D 13C NMR
# 15        Bruker AvanceII 1 GHz                        1D 13C NMR
# 16        Bruker AvanceII 1 GHz                        1D 13C NMR
# 17        Bruker AvanceII 1 GHz                        1D 13C NMR
# 18        Bruker AvanceII 1 GHz                        1D 13C NMR
# 19        Bruker AvanceII 1 GHz                        1D 13C NMR
# 20        Bruker AvanceII 1 GHz                        1D 13C NMR
# 21        Bruker AvanceII 1 GHz                        1D 13C NMR
# 22        Bruker AvanceII 1 GHz                        1D 13C NMR
# 23        Bruker AvanceII 1 GHz                        1D 13C NMR
# 24        Bruker AvanceII 1 GHz                        1D 13C NMR
# 25        Bruker AvanceII 1 GHz                        1D 13C NMR
# 26        Bruker AvanceII 1 GHz                        1D 13C NMR
# 27        Bruker AvanceII 1 GHz                        1D 13C NMR
# 28        Bruker AvanceII 1 GHz                        1D 13C NMR
# 29        Bruker AvanceII 1 GHz                        1D 13C NMR
# ..                          ...                               ...
# 110       Bruker AvanceII 1 GHz                        1D 13C NMR
# 111       Bruker AvanceII 1 GHz                        1D 13C NMR
# 112       Bruker AvanceII 1 GHz                        1D 13C NMR
# 113       Bruker AvanceII 1 GHz                        1D 13C NMR
# 114       Bruker AvanceII 1 GHz                        1D 13C NMR
# 115       Bruker AvanceII 1 GHz                        1D 13C NMR
# 116       Bruker AvanceII 1 GHz                        1D 13C NMR
# 117       Bruker AvanceII 1 GHz                        1D 13C NMR
# 118       Bruker AvanceII 1 GHz                        1D 13C NMR
# 119       Bruker AvanceII 1 GHz                        1D 13C NMR
# 120       Bruker AvanceII 1 GHz                        1D 13C NMR
# 121       Bruker AvanceII 1 GHz                        1D 13C NMR
# 122       Bruker AvanceII 1 GHz                        1D 13C NMR
# 123       Bruker AvanceII 1 GHz                        1D 13C NMR
# 124       Bruker AvanceII 1 GHz                        1D 13C NMR
# 125       Bruker AvanceII 1 GHz                        1D 13C NMR
# 126       Bruker AvanceII 1 GHz                        1D 13C NMR
# 127       Bruker AvanceII 1 GHz                        1D 13C NMR
# 128       Bruker AvanceII 1 GHz                        1D 13C NMR
# 129       Bruker AvanceII 1 GHz                        1D 13C NMR
# 130       Bruker AvanceII 1 GHz                        1D 13C NMR
# 131       Bruker AvanceII 1 GHz                        1D 13C NMR
# 132       Bruker AvanceII 1 GHz                        1D 13C NMR
# 133       Bruker AvanceII 1 GHz                        1D 13C NMR
# 134       Bruker AvanceII 1 GHz                        1D 13C NMR
# 135       Bruker AvanceII 1 GHz                        1D 13C NMR
# 136       Bruker AvanceII 1 GHz                        1D 13C NMR
# 137       Bruker AvanceII 1 GHz                        1D 13C NMR
# 138       Bruker AvanceII 1 GHz                        1D 13C NMR
# 139       Bruker AvanceII 1 GHz                        1D 13C NMR
#
#     Parameter Value[pulse_sequence] Performer.1                Raw Data File
# 0                              CPMG    Ellipsis  raw_spectral_data_file_45-6
# 1                              CPMG    Ellipsis  raw_spectral_data_file_45-3
# 2                              CPMG    Ellipsis  raw_spectral_data_file_46-6
# 3                              CPMG    Ellipsis  raw_spectral_data_file_46-3
# 4                              CPMG    Ellipsis  raw_spectral_data_file_47-6
# 5                              CPMG    Ellipsis  raw_spectral_data_file_47-3
# 6                              CPMG    Ellipsis  raw_spectral_data_file_48-3
# 7                              CPMG    Ellipsis  raw_spectral_data_file_48-6
# 8                              CPMG    Ellipsis  raw_spectral_data_file_49-3
# 9                              CPMG    Ellipsis  raw_spectral_data_file_49-6
# 10                             CPMG    Ellipsis  raw_spectral_data_file_69-6
# 11                             CPMG    Ellipsis  raw_spectral_data_file_69-3
# 12                             CPMG    Ellipsis  raw_spectral_data_file_59-3
# 13                             CPMG    Ellipsis  raw_spectral_data_file_59-6
# 14                             CPMG    Ellipsis  raw_spectral_data_file_25-3
# 15                             CPMG    Ellipsis  raw_spectral_data_file_25-6
# 16                             CPMG    Ellipsis  raw_spectral_data_file_26-3
# 17                             CPMG    Ellipsis  raw_spectral_data_file_26-6
# 18                             CPMG    Ellipsis  raw_spectral_data_file_27-6
# 19                             CPMG    Ellipsis  raw_spectral_data_file_27-3
# 20                             CPMG    Ellipsis  raw_spectral_data_file_28-3
# 21                             CPMG    Ellipsis  raw_spectral_data_file_28-6
# 22                             CPMG    Ellipsis  raw_spectral_data_file_29-6
# 23                             CPMG    Ellipsis  raw_spectral_data_file_29-3
# 24                             CPMG    Ellipsis  raw_spectral_data_file_65-6
# 25                             CPMG    Ellipsis  raw_spectral_data_file_65-3
# 26                             CPMG    Ellipsis  raw_spectral_data_file_55-6
# 27                             CPMG    Ellipsis  raw_spectral_data_file_55-3
# 28                             CPMG    Ellipsis   raw_spectral_data_file_0-6
# 29                             CPMG    Ellipsis   raw_spectral_data_file_0-3
# ..                              ...         ...                          ...
# 110                            CPMG    Ellipsis  raw_spectral_data_file_57-3
# 111                            CPMG    Ellipsis  raw_spectral_data_file_57-6
# 112                            CPMG    Ellipsis   raw_spectral_data_file_5-6
# 113                            CPMG    Ellipsis   raw_spectral_data_file_5-3
# 114                            CPMG    Ellipsis   raw_spectral_data_file_6-3
# 115                            CPMG    Ellipsis   raw_spectral_data_file_6-6
# 116                            CPMG    Ellipsis   raw_spectral_data_file_7-6
# 117                            CPMG    Ellipsis   raw_spectral_data_file_7-3
# 118                            CPMG    Ellipsis   raw_spectral_data_file_8-6
# 119                            CPMG    Ellipsis   raw_spectral_data_file_8-3
# 120                            CPMG    Ellipsis   raw_spectral_data_file_9-6
# 121                            CPMG    Ellipsis   raw_spectral_data_file_9-3
# 122                            CPMG    Ellipsis  raw_spectral_data_file_61-6
# 123                            CPMG    Ellipsis  raw_spectral_data_file_61-3
# 124                            CPMG    Ellipsis  raw_spectral_data_file_51-3
# 125                            CPMG    Ellipsis  raw_spectral_data_file_51-6
# 126                            CPMG    Ellipsis  raw_spectral_data_file_10-3
# 127                            CPMG    Ellipsis  raw_spectral_data_file_10-6
# 128                            CPMG    Ellipsis  raw_spectral_data_file_11-6
# 129                            CPMG    Ellipsis  raw_spectral_data_file_11-3
# 130                            CPMG    Ellipsis  raw_spectral_data_file_12-6
# 131                            CPMG    Ellipsis  raw_spectral_data_file_12-3
# 132                            CPMG    Ellipsis  raw_spectral_data_file_13-6
# 133                            CPMG    Ellipsis  raw_spectral_data_file_13-3
# 134                            CPMG    Ellipsis  raw_spectral_data_file_14-6
# 135                            CPMG    Ellipsis  raw_spectral_data_file_14-3
# 136                            CPMG    Ellipsis  raw_spectral_data_file_62-6
# 137                            CPMG    Ellipsis  raw_spectral_data_file_62-3
# 138                            CPMG    Ellipsis  raw_spectral_data_file_52-3
# 139                            CPMG    Ellipsis  raw_spectral_data_file_52-6
#
# [140 rows x 11 columns]
